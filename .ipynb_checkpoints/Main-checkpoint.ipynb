# %% [markdown]
# #Thanksgiving on Twitter#
#
# [TEXT TEXT TEXT]
#
# <img src="http://www.saveur.com/sites/saveur.com/files/import/2013/Feature-Thanksgiving-modern-classics-1200x800.jpg" width=640 height=480/>
#
# <img src="http://a57.foxnews.com/global.fbnstatic.com/static/managed/img/fb2/news/876/493/black-friday-2012-1.jpg?ve=1&tl=1" width=640 height=480/>

# %%
# %matplotlib inline
import re
import json
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
from datetime import datetime 
import pytz
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# #Table of Contents
#
# * [Data](#Data)
#     * [Scrape Tweets from Twitter API](#Scrape-Tweets-from-Twitter-API)
#     * [Combine Twitter Data](#Combine-Twitter-Data)
#     * [Clean Data](#Clean-Data)
#         * [Initial Data Cleaning in Pandas](#Initial-Data-Cleaning-in-Pandas)
# * [Exploratory Data Analysis](#Exploratory-Data-Analysis)

# %% [markdown]
# #Data

# %% [markdown]
# ## Scrape Tweets from Twitter API

# %% [markdown]
# [TEXT TEXT TEXT: processes of obtaining twitter data.
# Time, location and other specifications for data extraction]

# %%
import time, sys, tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %%
#[NEED TO UPDATE WITH THE ACTUAL CODE]
# Go to http://dev.twitter.com and create an app.
# The consumer key and secret will be generated for you after
consumer_key="fyeZKOx2yQorVWIeir6Iefvzd"
consumer_secret="96eaL995tWhqyN2mjdT8IHqK6AEzvcn1qJAaSbjzw62TP5uaxO"

# After the step above, you will be redirected to your app's page.
# Create an access token under the the "Your access token" section
access_token="273534302-uY6aKA3iz9KTTgHsGBPEKln188FKocOfikAnbyuE"
access_token_secret="OfT42aA94rWPec1bqokFR7VygPu8QO6wv1Rdf25sOlKhO"

# List of cities: the numbers are the centers of each city, with square -/+ 0.2
location_list = {'Harvard University, Cambridge' : [-71.1211537 - 0.3, 42.3735321 - 0.3, -71.1211537 + 0.3, 42.3735321 + 0.3], 
                 'MIT, Cambridge' : [-71.096354 - 0.02, 42.360091 - 0.02, -71.096354 + 0.02, 42.360091 + 0.02], 
                 'Newbury Street, Boston' : [-71.0847558 - 0.02, 42.349837 - 0.02, -71.0847558 + 0.02, 42.349837 + 0.02],
                 'Assembly Row, Somerville' :[-71.0907962 - 0.02, 42.3845583 - 0.02, -71.0907962 + 0.02, 42.3845583 + 0.02],
                 'South Station, Boston' : [-71.0629733 - 0.02, 42.3509101 - 0.02, -71.0629733 + 0.02, 42.3509101 + 0.02], 
                 'Airport Logan, Boston' : [-71.011748 - 0.02, 42.3656132 - 0.02, -71.011748 + 0.02, 42.3656132 + 0.02], 
                 'Fenway Park, Boston' : [-71.1622488 - 0.02, 42.3602564 - 0.02, -71.1622488 + 0.02, 42.3602564 + 0.02], 
                 'Beacon Hill, Boston' : [-71.0687328 - 0.02, 42.3588042 - 0.02, -71.0687328 + 0.02, 42.3588042 + 0.02], 

                 }

class JSONListener(StreamListener):
    """ A listener handles tweets are the received from the stream.
    This is a basic listener that just prints received tweets to stdout.
    """
    def __init__(self, fprefix = 'streamer', max_tweets = 5):
        self.counter = 0
        self.fprefix = fprefix
        self.output  = open('../../../Desktop/109data/' + fprefix + '.json', 'wb')
        self.max_tweets = max_tweets
        
    def on_data(self, data):
        if self.counter < self.max_tweets:
            data = data.encode("UTF-8")
            self.output.write(data)
            self.counter += 1

            # Print the information
            status = json.loads(data)
            print '{} Tweets at [Time = {}]'.format(self.counter, status['created_at'])
            return True
        else:
            self.output.close()
            print 'Totally {} tweets collected'.format(self.max_tweets)
            return False
        

        
    def on_error(self, status):
        print 'Error: ' + str(status)

if __name__ == '__main__':
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    # Set Track
    count = 0
    while True:
        listen = JSONListener(fprefix = time.strftime("%d-%m-%Y %H-%M-%S"), max_tweets = 1000)

        stream = Stream(auth, listen)

        start = time.time()
        stream.filter(locations = location_list['Harvard University, Cambridge'], track=['#ECEupgrade'])

        print 'Job completed. Disconnecting stream...'
        print 'Total Time:', time.time() - start

        stream.disconnect()
        count += 1

# %% [markdown]
# ##Combine Twitter Data
#
# After extracting daily tweets into json files, we need to combine all the json files to a master pool.

# %%
import os
tweets_data = []

for data_file_name in os.listdir("raw_data/data/"):
    if data_file_name.endswith(".json"): 
        print data_file_name
        tweets_file = open("raw_data/data/" + data_file_name, "r")
        for line in tweets_file:
            try:
                tweet = json.loads(line)
                print tweet[:100]
                tweets_data.append(tweet)
            except:
                continue
# Out:
# 23-11-2015 14-06-45.json
# 23-11-2015 14-39-39.json
# 23-11-2015 15-12-15.json
# 23-11-2015 15-47-06.json
# 23-11-2015 16-19-42.json
# 23-11-2015 16-51-46.json
# 23-11-2015 17-24-58.json
# 23-11-2015 18-00-14.json
# 23-11-2015 18-33-39.json
# 23-11-2015 19-05-07.json
# 23-11-2015 19-36-23.json
# 23-11-2015 20-03-18.json
# 23-11-2015 20-27-45.json
# 23-11-2015 20-49-59.json
# 23-11-2015 21-12-17.json
# 23-11-2015 21-33-44.json
# 23-11-2015 21-52-59.json
# 23-11-2015 22-10-56.json
# 23-11-2015 22-25-12.json
# 23-11-2015 22-41-59.json
# 23-11-2015 23-01-48.json
# 23-11-2015 23-20-52.json
# 23-11-2015 23-48-50.json
# 24-11-2015 00-09-24.json
# 24-11-2015 00-50-10.json
# 24-11-2015 02-07-11.json
# 24-11-2015 06-02-57.json
# 24-11-2015 07-35-13.json
# 24-11-2015 08-34-07.json
# 24-11-2015 09-20-45.json
# 24-11-2015 10-00-36.json
# 24-11-2015 10-41-10.json
# 24-11-2015 11-19-21.json
# 24-11-2015 11-54-24.json
# 24-11-2015 12-27-24.json
# 24-11-2015 21-57-26.json
# 24-11-2015 22-27-47.json
# 24-11-2015 23-01-56.json
# 24-11-2015 23-39-44.json
# 25-11-2015 00-29-57.json
# 25-11-2015 01-46-00.json
# 25-11-2015 06-04-45.json
# 25-11-2015 07-42-03.json
# 25-11-2015 08-31-54.json
# 25-11-2015 09-18-08.json
# 25-11-2015 09-58-59.json
# 25-11-2015 10-39-38.json
# 25-11-2015 11-15-10.json
# 25-11-2015 11-50-01.json
# 25-11-2015 12-23-12.json
# 25-11-2015 12-57-09.json
# 25-11-2015 13-33-56.json
# 25-11-2015 14-07-02.json
# 25-11-2015 14-40-57.json
# 25-11-2015 15-15-03.json
# 25-11-2015 15-48-13.json
# 25-11-2015 16-20-59.json
# 25-11-2015 16-52-43.json
# 25-11-2015 17-04-25.json
# 25-11-2015 17-40-46.json
# 25-11-2015 18-13-19.json
# 25-11-2015 18-50-50.json
# 25-11-2015 19-25-54.json
# 25-11-2015 20-02-31.json
# 25-11-2015 20-33-23.json
# 25-11-2015 21-08-45.json
# 25-11-2015 21-38-50.json
# 25-11-2015 22-03-38.json
# 25-11-2015 22-33-09.json
# 25-11-2015 23-08-21.json
# 25-11-2015 23-56-11.json
# 26-11-2015 00-46-08.json
# 26-11-2015 02-13-00.json
# 26-11-2015 06-45-50.json
# 26-11-2015 08-23-16.json
# 26-11-2015 09-11-08.json
# 26-11-2015 09-48-21.json
# 26-11-2015 10-19-06.json
# 26-11-2015 10-47-53.json
# 26-11-2015 11-17-05.json
# 26-11-2015 11-44-19.json
# 26-11-2015 12-11-15.json
# 26-11-2015 12-40-19.json
# 26-11-2015 13-06-33.json
# 26-11-2015 13-35-16.json
# 26-11-2015 13-56-02.json
# 26-11-2015 14-22-39.json
# 26-11-2015 14-54-01.json
# 26-11-2015 15-27-28.json
# 26-11-2015 15-58-27.json
# 26-11-2015 16-31-26.json
# 26-11-2015 17-05-57.json
# 26-11-2015 17-35-56.json
# 26-11-2015 18-04-10.json
# 26-11-2015 18-36-33.json
# 26-11-2015 19-09-12.json
# 26-11-2015 19-44-25.json
# 26-11-2015 20-18-10.json
# 26-11-2015 20-51-19.json
# 26-11-2015 21-28-06.json
# 26-11-2015 22-04-04.json
# 26-11-2015 22-37-37.json
# 26-11-2015 23-16-18.json
# 26-11-2015 23-56-07.json
# 27-11-2015 00-58-36.json
# 27-11-2015 02-23-55.json
# 27-11-2015 05-26-55.json
# 27-11-2015 08-02-52.json
# 27-11-2015 09-07-01.json
# 27-11-2015 09-59-27.json
# 27-11-2015 10-44-13.json
# 27-11-2015 11-20-39.json
# 27-11-2015 11-58-49.json
# 27-11-2015 12-36-30.json
# 27-11-2015 13-11-06.json
# 27-11-2015 13-46-00.json
# 27-11-2015 14-19-25.json
# 27-11-2015 14-56-22.json
# 27-11-2015 15-30-56.json
# 27-11-2015 15-59-48.json
# 27-11-2015 16-38-49.json
# 27-11-2015 17-11-55.json
# 27-11-2015 17-45-52.json
# 27-11-2015 18-24-12.json
# 27-11-2015 19-01-37.json
# 27-11-2015 19-39-42.json
# 27-11-2015 20-18-40.json
# 27-11-2015 20-54-34.json
# 27-11-2015 21-31-53.json
# 27-11-2015 22-07-55.json
# 27-11-2015 22-34-43.json
# 27-11-2015 23-12-45.json
# 27-11-2015 23-54-24.json
# 28-11-2015 00-38-41.json
# 28-11-2015 01-41-00.json
# 28-11-2015 03-41-19.json
# 28-11-2015 07-21-12.json
# 28-11-2015 08-46-12.json
# 28-11-2015 09-40-44.json
# 28-11-2015 10-23-57.json
# 28-11-2015 11-06-15.json
# 28-11-2015 11-41-15.json
# 28-11-2015 12-13-35.json
# 28-11-2015 12-43-30.json
# 28-11-2015 13-11-57.json
# 28-11-2015 13-42-51.json
# 28-11-2015 14-15-09.json
# 28-11-2015 14-46-22.json
# 28-11-2015 15-19-51.json
# 28-11-2015 15-54-20.json
# 28-11-2015 16-28-08.json
# 28-11-2015 17-02-58.json
# 28-11-2015 17-36-02.json
# 28-11-2015 18-13-16.json
# 28-11-2015 18-47-59.json
# 28-11-2015 19-24-31.json
# 28-11-2015 20-00-47.json
# 28-11-2015 20-33-46.json
# 28-11-2015 21-10-16.json
# 28-11-2015 21-49-47.json
# 28-11-2015 22-08-41.json
# 29-11-2015 12-49-02.json
# 29-11-2015 13-25-35.json
# 29-11-2015 14-00-03.json
# 29-11-2015 14-31-28.json
# 29-11-2015 15-03-54.json
# 29-11-2015 15-38-35.json
# 30-11-2015 12-28-05.json
# 30-11-2015 13-03-35.json
# 30-11-2015 13-43-17.json

# %%
print 'Number of tweets in total: ', len(tweets_data)
# Out:
# Number of tweets in total:  0

# %% [markdown]
# ##Clean Data

# %% [markdown]
# [CHANGE SO IT MATCHES DATAFRAME]
#
# Each tweet have many features, and we focus on the following features:
#     - user id: the user's tweeter id
#     - followers_count: the number of followers
#     - friends_count: the number of people the user is following
#     - statuses_count: the number of status tweets sent in the past
#     - created_at_u: time the user account is created
#     - admin_place: the place where the account is created? $$$DIDN'T FIND THIS COLUMN$$$
#
#     - created_at_t: time the tweet is created
#     - id: tweet's ide
#     - text: the content of the tweet
#     - truncated: (boolean) whether the text is truncated or not.
#     - in_reply_to_status_id: whether the tweet is a reply ???
#     - retweeted_status: True if the tweet is a retweet
#     - lang: language of the text
#     - timestamp_ms: when the tweet is created.
#
#     - $$$ADDED BY JACK: place.full_name: location of tweets if geo enabled$$$
#     - $$$quoted_status.text: text of quoted tweet$$$
#
# [IS THIS TRUE?]Notice that if it is a retweet, the text of previous tweet will be embeded in the `text`. Thus we use `retweeted_status` as an indicator of whether further parsing is needed.

# %%
#coord_type
# 0: longitude
# 1: latitude
def getCoords(tweet, coord_type):
    if tweet['place'] is None:
        return None;
    coord = tweet['place']['bounding_box']['coordinates'][0]
    result = []
    for i in range(len(coord)):
        result.append(coord[i][coord_type])
    return np.mean(result)

# %%
tweets = pd.DataFrame()
tweets['user_id'] = map(lambda tweet: tweet['user']['id'], tweets_data)
tweets['created_at_t'] = map(lambda tweet: time.ctime(float(tweet['timestamp_ms'])), tweets_data)
tweets['quoted_text'] = map(lambda tweet: tweet['quoted_status']['text'] if (tweet['is_quote_status'] == True) & ('quoted_status' in tweet.keys()) else None, tweets_data)
tweets['tweet_longitude'] = map(lambda tweet: getCoords(tweet, 0), tweets_data)
tweets['tweet_latitude'] = map(lambda tweet: getCoords(tweet, 1), tweets_data)
tweets['followers_count'] = map(lambda tweet: tweet['user']['followers_count'], tweets_data)
tweets['friends_count'] = map(lambda tweet: tweet['user']['friends_count'], tweets_data)
tweets['statuses_count'] = map(lambda tweet: tweet['user']['statuses_count'], tweets_data)
tweets['created_at_u'] = map(lambda tweet: tweet['user']['created_at'], tweets_data)
tweets['tweet_id'] = map(lambda tweet: tweet['id'], tweets_data)
tweets['truncated'] = map(lambda tweet: tweet['truncated'], tweets_data)
tweets['in_reply_to_status_id'] = map(lambda tweet: tweet['in_reply_to_status_id'], tweets_data)
tweets['retweeted_status'] = map(lambda tweet: tweet['retweeted_status'] if 'retweeted_status' in tweet.keys() else None, tweets_data)
tweets['timestamp_ms'] = map(lambda tweet: tweet['timestamp_ms'], tweets_data)
tweets['text'] = map(lambda tweet: tweet['text'], tweets_data)
tweets['lang'] = map(lambda tweet: tweet['lang'], tweets_data)
tweets['country'] = map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data)
tweets['place_full_name'] = map(lambda tweet: tweet['place']['full_name'] if tweet['place'] != None else None, tweets_data)

# tweets['hashtags'] = map(lambda tweet: tweet['entities']['hashtags']['text'], tweets_data)

# %%
tweets.to_csv("raw_data/dftweets.csv", index = False, encoding='utf-8')

# %%
dftouse=pd.read_csv("raw_data/dftweets.csv")
dftouse.head()
# Out:
# /Users/Jing/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (0,3,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#       user_id                     created_at_t quoted_text tweet_longitude  tweet_latitude  followers_count  friends_count  statuses_count                    created_at_u      tweet_id truncated  in_reply_to_status_id  retweeted_status  timestamp_ms                                               text lang        country     place_full_name
# 0  3095695629  Fri Dec 23 03:15:20     47864\n         NaN      -71.683502       42.036932             7424            985           36984  Thu Mar 19 01:33:34 +0000 2015  6.688683e+17     False           6.688680e+17               NaN  1.448306e+12            @DopeAhhAquarius lemme come over bro :(   en  United States  Massachusetts, USA
# 1  2174756318  Fri Dec 23 03:15:38     47864\n         NaN      -71.326858       42.636248              110            159            2199  Mon Nov 04 21:06:33 +0000 2013  6.688683e+17     False                    NaN               NaN  1.448306e+12            I've been in a bad mood since like 2010   en  United States          Lowell, MA
# 2   408976087  Fri Dec 23 03:57:00     47864\n         NaN     -71.0887545       42.313670              514            246           37162  Thu Nov 10 03:50:52 +0000 2011  6.688683e+17     False                    NaN               NaN  1.448306e+12  what's the appropriate age for me to start act...   en  United States          Boston, MA
# 3  1163319366  Fri Dec 23 05:40:30     47864\n         NaN      -71.312617       42.693109              465            604           57037  Sat Feb 09 16:02:36 +0000 2013  6.688683e+17     False           6.688683e+17               NaN  1.448306e+12  @JackSillin @AlexReedWX @WesternMEwx ...I assu...   en  United States          Dracut, MA
# 4  1600099118  Fri Dec 23 05:58:38     47864\n         NaN     -96.3073065       65.838115                3             43           26716  Wed Jul 17 05:04:16 +0000 2013  6.688683e+17     False                    NaN               NaN  1.448306e+12    https://t.co/pEaLZwrJpj https://t.co/MZKFV7H10o  und         Canada              Canada

# %% [markdown]
# ###Sanity Check Data###
# There might be corrupted data during the process of extracting and dumping, and we want to see the frequency and impact of these corrupted records. We found that there are only 2 records that look corrupted, and therefore remove them from the dataframe we work with.

# %%
dftouse.isnull().sum()
# Out:
# user_id                       0
# created_at_t                  0
# quoted_text              154439
# tweet_longitude              78
# tweet_latitude               80
# followers_count               2
# friends_count                 2
# statuses_count                2
# created_at_u                  2
# tweet_id                      2
# truncated                     2
# in_reply_to_status_id    125872
# retweeted_status         166945
# timestamp_ms                  2
# text                          2
# lang                          4
# country                      82
# place_full_name              82
# dtype: int64

# %% [markdown]
# We expect to see lots of NaN's for quoted_text or country/place, as not all tweets contain that data. However, there seems to be two tweets that are missing lots of fields:

# %%
dftouse[dftouse.tweet_id.isnull()]
# Out:
#                                                  user_id created_at_t    quoted_text tweet_longitude  tweet_latitude  followers_count  friends_count  statuses_count created_at_u  tweet_id truncated  in_reply_to_status_id  retweeted_status  timestamp_ms text lang country place_full_name
# 23095                                         Pats #1!!!           en  United States      Quincy, MA             NaN              NaN            NaN             NaN          NaN       NaN       NaN                    NaN               NaN           NaN  NaN  NaN     NaN             NaN
# 95014  And I thought Atlanta was nice... Boston beats...           en  United States   Cambridge, MA             NaN              NaN            NaN             NaN          NaN       NaN       NaN                    NaN               NaN           NaN  NaN  NaN     NaN             NaN

# %% [markdown]
# Therefore, we decide to remove these two tweets from our dataframe, along with the tweets that are missing geographical information, because most of our analyses involves geographical variance. Also, we remove all tweets that are not in English, as we won't be able to accurately classify topics and sentiments for these tweets.

# %%
dftouse["lang"].value_counts()
# Out:
# en     138468
# und     18152
# es       2705
# fr       1590
# pt       1287
# tl        755
# ar        696
# in        464
# de        323
# it        264
# tr        199
# et        198
# ro        188
# ja        167
# nl        158
# no        150
# da        129
# sv        127
# pl        117
# ne         75
# zh         74
# bs         69
# ru         69
# th         58
# fi         52
# sl         51
# hi         47
# sk         43
# lv         40
# hu         36
# is         33
# lt         33
# el         33
# hr         29
# fa         22
# ko         15
# iw          9
# bg          6
# ur          6
# vi          2
# uk          1
# te          1
# dtype: int64

# %%
dftouse = dftouse[dftouse.tweet_id.notnull() & dftouse.place_full_name.notnull()]
dftouse = dftouse[dftouse.lang == "en"]
#dftouse.isnull().sum()

# %% [markdown]
# ###Spark Attempts to Clean Data###
#
# Initially, we tried reading in and cleaning data in Spark, because SPARK SQL gives very clean and nice functionalities for showing multi-layer data. We were successful for individual datasets but failed on the combined data. The problem arises when we are trying to use SPARK SQL to read the whole tweet data, and there is memory issues potentially due to the large data size.
#
# Therefore, we did our initial data cleaning using Pandas, and then convert the dataframe into Spark dataframe for natural language processing.

# %%
# Read in json file: (create a list of tweets)
# with open("raw_data/pre-thanksgiving data/26-11-2015 10-19-06.json") as json_file:    
import os
with open('raw_data/combined.json', 'w') as fp:
    for data_file_name in os.listdir("raw_data/pre-thanksgiving data/"):
        if data_file_name.endswith(".json"): 
            for line in open("raw_data/pre-thanksgiving data/"+data_file_name):
                json.dump(line, fp)

# %%
# tweetdf = sqlsc.read.json("raw_data/combined.json")
tweetdfspark = sqlsc.read.json("raw_data/pre-thanksgiving data/26-11-2015 10-19-06.json")
#tweetdf.show(5)

# %%
# We cache the data to make sure it is only read once from disk
tweetdf.cache()
print "How many tweets do we have?", tweetdf.count()
# Then we use printSchema to lay out the structure of the tweet data
tweetdf.printSchema()
# Out:
# How many tweets do we have? 1000
# root
#  |-- contributors: string (nullable = true)
#  |-- coordinates: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- entities: struct (nullable = true)
#  |    |-- hashtags: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- symbols: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- urls: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- user_mentions: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- screen_name: string (nullable = true)
#  |-- extended_entities: struct (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- favorited: boolean (nullable = true)
#  |-- filter_level: string (nullable = true)
#  |-- geo: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- id_str: string (nullable = true)
#  |-- in_reply_to_screen_name: string (nullable = true)
#  |-- in_reply_to_status_id: long (nullable = true)
#  |-- in_reply_to_status_id_str: string (nullable = true)
#  |-- in_reply_to_user_id: long (nullable = true)
#  |-- in_reply_to_user_id_str: string (nullable = true)
#  |-- is_quote_status: boolean (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- place: struct (nullable = true)
#  |    |-- bounding_box: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- country_code: string (nullable = true)
#  |    |-- full_name: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- place_type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- possibly_sensitive: boolean (nullable = true)
#  |-- quoted_status: struct (nullable = true)
#  |    |-- contributors: string (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- entities: struct (nullable = true)
#  |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- symbols: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- urls: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- user_mentions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |-- extended_entities: struct (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- source_user_id: long (nullable = true)
#  |    |    |    |    |-- source_user_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- video_info: struct (nullable = true)
#  |    |    |    |    |    |-- aspect_ratio: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- duration_millis: long (nullable = true)
#  |    |    |    |    |    |-- variants: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- bitrate: long (nullable = true)
#  |    |    |    |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |-- favorite_count: long (nullable = true)
#  |    |-- favorited: boolean (nullable = true)
#  |    |-- filter_level: string (nullable = true)
#  |    |-- geo: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- in_reply_to_screen_name: string (nullable = true)
#  |    |-- in_reply_to_status_id: long (nullable = true)
#  |    |-- in_reply_to_status_id_str: string (nullable = true)
#  |    |-- in_reply_to_user_id: long (nullable = true)
#  |    |-- in_reply_to_user_id_str: string (nullable = true)
#  |    |-- is_quote_status: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- place: string (nullable = true)
#  |    |-- possibly_sensitive: boolean (nullable = true)
#  |    |-- quoted_status_id: long (nullable = true)
#  |    |-- quoted_status_id_str: string (nullable = true)
#  |    |-- retweet_count: long (nullable = true)
#  |    |-- retweeted: boolean (nullable = true)
#  |    |-- scopes: struct (nullable = true)
#  |    |    |-- followers: boolean (nullable = true)
#  |    |-- source: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |    |-- truncated: boolean (nullable = true)
#  |    |-- user: struct (nullable = true)
#  |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- favourites_count: long (nullable = true)
#  |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |-- followers_count: long (nullable = true)
#  |    |    |-- following: string (nullable = true)
#  |    |    |-- friends_count: long (nullable = true)
#  |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- listed_count: long (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- notifications: string (nullable = true)
#  |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |-- protected: boolean (nullable = true)
#  |    |    |-- screen_name: string (nullable = true)
#  |    |    |-- statuses_count: long (nullable = true)
#  |    |    |-- time_zone: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- utc_offset: long (nullable = true)
#  |    |    |-- verified: boolean (nullable = true)
#  |-- quoted_status_id: long (nullable = true)
#  |-- quoted_status_id_str: string (nullable = true)
#  |-- retweet_count: long (nullable = true)
#  |-- retweeted: boolean (nullable = true)
#  |-- source: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp_ms: string (nullable = true)
#  |-- truncated: boolean (nullable = true)
#  |-- user: struct (nullable = true)
#  |    |-- contributors_enabled: boolean (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- default_profile: boolean (nullable = true)
#  |    |-- default_profile_image: boolean (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- favourites_count: long (nullable = true)
#  |    |-- follow_request_sent: string (nullable = true)
#  |    |-- followers_count: long (nullable = true)
#  |    |-- following: string (nullable = true)
#  |    |-- friends_count: long (nullable = true)
#  |    |-- geo_enabled: boolean (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- is_translator: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- listed_count: long (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- notifications: string (nullable = true)
#  |    |-- profile_background_color: string (nullable = true)
#  |    |-- profile_background_image_url: string (nullable = true)
#  |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |-- profile_background_tile: boolean (nullable = true)
#  |    |-- profile_banner_url: string (nullable = true)
#  |    |-- profile_image_url: string (nullable = true)
#  |    |-- profile_image_url_https: string (nullable = true)
#  |    |-- profile_link_color: string (nullable = true)
#  |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |-- profile_text_color: string (nullable = true)
#  |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |-- protected: boolean (nullable = true)
#  |    |-- screen_name: string (nullable = true)
#  |    |-- statuses_count: long (nullable = true)
#  |    |-- time_zone: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |    |-- utc_offset: long (nullable = true)
#  |    |-- verified: boolean (nullable = true)

# %% [markdown]
# One of the key challenges in data cleaning on tweets is that the desired variables are usually sub-attributes that are a few layers nested inside different categories.
#
# Our solution is to use Spark SQL, which allows us to use SQL-like queries to select, filter and aggregate the Spark Dataframe.
# http://spark.apache.org/docs/latest/sql-programming-guide.html

# %%
# Create temporary table for SQL queries
tweetdf.registerTempTable("tweetdf") 
dftouse = sqlsc.sql("SELECT user.id as uid, user.location as location_u, user.followers_count, user.friends_count, user.statuses_count, user.created_at as created_at_u, created_at as created_at_t, id as tid, text, truncated, in_reply_to_status_id, retweeted, quoted_status.text as quote_text, lang, timestamp_ms, place.full_name as location_t FROM tweetdf")

# %%
dftouse.take(3)
# Out:
# [Row(uid=1652821, location_u=u'boston, ma', followers_count=2060, friends_count=1508, statuses_count=38508, created_at_u=u'Tue Mar 20 17:49:39 +0000 2007', created_at_t=u'Thu Nov 26 15:19:08 +0000 2015', tid=669898187356954624, text=u'That was quick https://t.co/te2gtFO47Q', truncated=False, in_reply_to_status_id=None, retweeted=False, quote_text=u'It hasnt taken long for community members to make #PiZero #RaspberryPi cases for #3DPrinting https://t.co/3FbnFwEcpv https://t.co/OrUCPjNhDM', lang=u'en', timestamp_ms=u'1448551148629', location_t=u'Lowell, MA'),
#  Row(uid=96374440, location_u=u'Springfield, MA', followers_count=1225, friends_count=1686, statuses_count=28033, created_at_u=u'Sat Dec 12 16:43:59 +0000 2009', created_at_t=u'Thu Nov 26 15:19:10 +0000 2015', tid=669898193425948672, text=u"First legal drink with my little sister last night #ThanksgivingEve #tobysilovethisbar @ Toby Keith's\u2026 https://t.co/sfo45GwihA", truncated=False, in_reply_to_status_id=None, retweeted=False, quote_text=None, lang=u'en', timestamp_ms=u'1448551150076', location_t=u'Foxborough, MA'),
#  Row(uid=314797090, location_u=None, followers_count=2131, friends_count=1899, statuses_count=116434, created_at_u=u'Fri Jun 10 20:38:46 +0000 2011', created_at_t=u'Thu Nov 26 15:19:12 +0000 2015', tid=669898201655300096, text=u"@JonnieKruger lmao Na bro \U0001f602. You'll look like a savage though \U0001f480", truncated=False, in_reply_to_status_id=669897772183773184, retweeted=False, quote_text=None, lang=u'en', timestamp_ms=u'1448551152038', location_t=u'Boston, MA')]

# %%
# Clean some variables to usable formats as needed
import datetime
starttime = datetime.datetime(1970,1,1,0,0,0)
def clean_df((uid, location_u, followers_count, friends_count, statuses_count, created_at_u, created_at_t, tid, text, truncated, in_reply_to_status_id, retweeted, quote_text, lang, timestamp_ms, location_t)):
# Date and Time of Tweet
    timestamp = starttime + datetime.timedelta(milliseconds = int(timestamp_ms))
    #add date variable --- J#
    date=timestamp.date()
    return uid, location_u, followers_count, friends_count, statuses_count, created_at_u, created_at_t, tid, text, truncated, in_reply_to_status_id, retweeted, quote_text, lang, timestamp, location_t, date

# %%
dftouse1 = dftouse.map(clean_df)
dftouse1.take(1)
# Out:
# [(1652821,
#   u'boston, ma',
#   2060,
#   1508,
#   38508,
#   u'Tue Mar 20 17:49:39 +0000 2007',
#   u'Thu Nov 26 15:19:08 +0000 2015',
#   669898187356954624,
#   u'That was quick https://t.co/te2gtFO47Q',
#   False,
#   None,
#   False,
#   u'It hasnt taken long for community members to make #PiZero #RaspberryPi cases for #3DPrinting https://t.co/3FbnFwEcpv https://t.co/OrUCPjNhDM',
#   u'en',
#   datetime.datetime(2015, 11, 26, 15, 19, 8, 629000),
#   u'Lowell, MA',
#   datetime.date(2015, 11, 26))]

# %% [markdown]
# <img src="https://media.giphy.com/media/9Y5BbDSkSTiY8/giphy.gif">
# ####---end of the failed attempt---###

# %% [markdown]
# ###Initial Data Cleaning in Pandas

# %% [markdown]
# #####1. Clean Date and Timestamp
# Use microsecond variable to compute the exact timestamp for each tweet.

# %%
import datetime
starttime = datetime.datetime(1970,1,1,0,0,0)
def clean_df(time_ms):
    timestamp = starttime + datetime.timedelta(milliseconds = int(time_ms))
    return timestamp
dftouse['timestamp'] = dftouse['timestamp_ms'].apply(clean_df)
dftouse['date'] = dftouse['timestamp'].apply(lambda r: r.date())
dftouse['time'] = dftouse['timestamp'].apply(lambda r: r.time())

# %%
dftouse.to_csv("raw_data/dftweet_datetime.csv", index = False)

# %%
len(dftouse)
# Out:
# 138396

# %% [markdown]
# #####2. Clean Hashtags

# %% [markdown]
# Beause thanksgiving and shopping may be quoted in different formats in hashtags, we use regular expression to identify hashtags about thanksgiving and shopping. And we define a function `regreform` to formate hashtag texts. We lemmatize other words by using `gensim` package.
#
# Note that lemmatization is type of normalization that treats different inflected forms of a word as a single unit ("work", "working", "works", "worked", "working" => same lemma: "work"):

# %%
#keywords
thxgiving=[r'[\w_]giving',r'turkey']
giving_re = re.compile(r'('+'|'.join(thxgiving)+')', re.VERBOSE | re.IGNORECASE)
shopping=[r'macys',
          r'shop',
          r'nordstrom',
          r'amazon',
          r'blackfriday',
          r'bloomingdales',
          r'bestbuy',
          r'target',
          r'cybermonday',
          r'[\w_]sale']
shop_re=re.compile(r'('+'|'.join(shopping)+')', re.VERBOSE | re.IGNORECASE)

# %%
import gensim
"""
Function
--------
regreform

Reformate hashtags extracted from text and quoted text

Parameters
----------
textlist : a list of hashtag texts.

Output: a list of reformatted hashtags
"""


def regreform(textlist):
    tokens=set()

    for token in textlist:
        
        #add thanksgiving/NN to token list if textlist have 
        #mentioned thanksgiving
        if giving_re.search(token):
            tokens.add('thanksgiving/NN')
            if shop_re.search(token):
                tokens.add('shopping/NN')
        
        #add shopping/NN to token list if textlist have 
        #mentioned shopping
        elif shop_re.search(token):
            tokens.add('shopping/NN')
        else:
            
        #lemmatize other words
            t=gensim.utils.lemmatize(token)
            if len(t)>0:
                tokens.add(t[0])
            else:
                tokens.add(token)
    
    return list(tokens)

# %% [markdown]
# ####3. Extract hashtags, emoticons, and emoji

# %% [markdown]
# Emoticons and emoji are quite popular, and people tend to include them in their tweets. In particular, emoji is very useful for our analysis. For example, 📀 refers DVD. If we are able to replace emoji with the items they represent, we will obtain more information about a tweet.
#
# We found a emoji list with explanation for each emoji [here](http://ftp.unicode.org/Public/emoji/1.0/emoji-data.txt), and we use it to create a emoji dictionary.

# %%
#'http://ftp.unicode.org/Public/emoji/1.0/emoji-data.txt'
f = open('raw_data/emoji-data.txt','r');
mapping = {};
for line in f:
    line = line.decode('utf-8')
    line=re.sub('\(',";",line)
    line=re.sub('\)',";",line)
    linelist=line.split(';')
    mapping[linelist[5]] = linelist[6].strip()
f.close;

# %%
mapping
# Out:
# {u'\U0001f475': u'OLDER WOMAN',
#  u'\U0001f474': u'OLDER MAN',
#  u'\U0001f477': u'CONSTRUCTION WORKER',
#  u'\U0001f31d': u'FULL MOON WITH FACE',
#  u'\U0001f471': u'PERSON WITH BLOND HAIR',
#  u'\u2604': u'COMET',
#  u'\U0001f473': u'MAN WITH TURBAN',
#  u'\U0001f472': u'MAN WITH GUA PI MAO',
#  u'\U0001f47d': u'EXTRATERRESTRIAL ALIEN',
#  u'\U0001f47c': u'BABY ANGEL',
#  u'\U0001f47f': u'IMP',
#  u'\u270a': u'RAISED FIST',
#  u'\U0001f479': u'JAPANESE OGRE',
#  u'\U0001f478': u'PRINCESS',
#  u'\U0001f47b': u'GHOST',
#  u'\U0001f47a': u'JAPANESE GOBLIN',
#  u'\U0001f465': u'BUSTS IN SILHOUETTE',
#  u'\U0001f464': u'BUST IN SILHOUETTE',
#  u'\U0001f467': u'GIRL',
#  u'\U0001f466': u'BOY',
#  u'\u2795': u'HEAVY PLUS SIGN',
#  u'\u2614': u'UMBRELLA WITH RAIN DROPS',
#  u'\u3297': u'CIRCLED IDEOGRAPH CONGRATULATION',
#  u'\U0001f462': u'WOMANS BOOTS',
#  u'\U0001f46d': u'TWO WOMEN HOLDING HANDS',
#  u'\U0001f46c': u'TWO MEN HOLDING HANDS',
#  u'\U0001f46f': u'WOMAN WITH BUNNY EARS',
#  u'\U0001f46e': u'POLICE OFFICER',
#  u'\U0001f469': u'WOMAN',
#  u'\U0001f468': u'MAN',
#  u'\U0001f46b': u'MAN AND WOMAN HOLDING HANDS',
#  u'\U0001f46a': u'FAMILY',
#  u'\U0001f196': u'SQUARED NG',
#  u'\U0001f197': u'SQUARED OK',
#  u'\U0001f194': u'SQUARED ID',
#  u'\U0001f195': u'SQUARED NEW',
#  u'\U0001f192': u'SQUARED COOL',
#  u'\U0001f193': u'SQUARED FREE',
#  u'\U0001f453': u'EYEGLASSES',
#  u'\U0001f191': u'SQUARED CL',
#  u'\U0001f45d': u'POUCH',
#  u'\U0001f45c': u'HANDBAG',
#  u'\U0001f45f': u'ATHLETIC SHOE',
#  u'\U0001f45e': u'MANS SHOE',
#  u'\U0001f19a': u'SQUARED VS',
#  u'\U0001f458': u'KIMONO',
#  u'\U0001f198': u'SQUARED SOS',
#  u'\U0001f199': u'SQUARED UP WITH EXCLAMATION MARK',
#  u'\U0001f445': u'TONGUE',
#  u'\u3030': u'WAVY DASH',
#  u'\U0001f447': u'WHITE DOWN POINTING BACKHAND INDEX',
#  u'\U0001f446': u'WHITE UP POINTING BACKHAND INDEX',
#  u'\U0001f441': u'EYE',
#  u'\U0001f440': u'EYES',
#  u'\U0001f443': u'NOSE',
#  u'\U0001f442': u'EAR',
#  u'\U0001f18e': u'NEGATIVE SQUARED AB',
#  u'\U0001f44c': u'OK HAND SIGN',
#  u'\U0001f44f': u'CLAPPING HANDS SIGN',
#  u'\U0001f44e': u'THUMBS DOWN SIGN',
#  u'\U0001f449': u'WHITE RIGHT POINTING BACKHAND INDEX',
#  u'\U0001f448': u'WHITE LEFT POINTING BACKHAND INDEX',
#  u'\U0001f44b': u'WAVING HAND SIGN',
#  u'\U0001f44a': u'FISTED HAND SIGN',
#  u'\U0001f435': u'MONKEY FACE',
#  u'\U0001f434': u'HORSE FACE',
#  u'\U0001f437': u'PIG FACE',
#  u'\U0001f436': u'DOG FACE',
#  u'\U0001f431': u'CAT FACE',
#  u'\U0001f430': u'RABBIT FACE',
#  u'\U0001f433': u'SPOUTING WHALE',
#  u'\U0001f432': u'DRAGON FACE',
#  u'\U0001f43d': u'PIG NOSE',
#  u'\U0001f43c': u'PANDA FACE',
#  u'\U0001f43f': u'CHIPMUNK',
#  u'\U0001f43e': u'PAW PRINTS',
#  u'\U0001f439': u'HAMSTER FACE',
#  u'\U0001f438': u'FROG FACE',
#  u'\u26cf': u'PICK',
#  u'\U0001f43a': u'WOLF FACE',
#  u'\U0001f425': u'FRONT-FACING BABY CHICK',
#  u'\U0001f424': u'BABY CHICK',
#  u'\U0001f427': u'PENGUIN',
#  u'\U0001f426': u'BIRD',
#  u'\U0001f421': u'BLOWFISH',
#  u'\U0001f420': u'TROPICAL FISH',
#  u'\U0001f423': u'HATCHING CHICK',
#  u'\U0001f422': u'TURTLE',
#  u'\U0001f42d': u'MOUSE FACE',
#  u'\U0001f42c': u'DOLPHIN',
#  u'\U0001f42f': u'TIGER FACE',
#  u'\U0001f42e': u'COW FACE',
#  u'\U0001f429': u'POODLE',
#  u'\U0001f428': u'KOALA',
#  u'\U0001f42b': u'BACTRIAN CAMEL',
#  u'\U0001f42a': u'DROMEDARY CAMEL',
#  u'\U0001f415': u'DOG',
#  u'\U0001f414': u'CHICKEN',
#  u'\U0001f417': u'BOAR',
#  u'\U0001f416': u'PIG',
#  u'\U0001f411': u'SHEEP',
#  u'\U0001f410': u'GOAT',
#  u'\U0001f413': u'ROOSTER',
#  u'\U0001f412': u'MONKEY',
#  u'\U0001f41d': u'HONEYBEE',
#  u'\U0001f41c': u'ANT',
#  u'\U0001f41f': u'FISH',
#  u'\U0001f41e': u'LADY BEETLE',
#  u'\u23ed': u'BLACK RIGHT-POINTING DOUBLE TRIANGLE WITH VERTICAL BAR',
#  u'\U0001f418': u'ELEPHANT',
#  u'\U0001f41b': u'BUG',
#  u'\U0001f41a': u'SPIRAL SHELL',
#  u'\U0001f405': u'TIGER',
#  u'\U0001f404': u'COW',
#  u'\U0001f407': u'RABBIT',
#  u'\U0001f406': u'LEOPARD',
#  u'\U0001f401': u'MOUSE',
#  u'\U0001f400': u'RAT',
#  u'\U0001f403': u'WATER BUFFALO',
#  u'\U0001f402': u'OX',
#  u'\U0001f40d': u'SNAKE',
#  u'\U0001f40c': u'SNAIL',
#  u'\U0001f40f': u'RAM',
#  u'\U0001f40e': u'HORSE',
#  u'\U0001f409': u'DRAGON',
#  u'\U0001f408': u'CAT',
#  u'\U0001f40b': u'WHALE',
#  u'\U0001f40a': u'CROCODILE',
#  u'\U0001f4f5': u'NO MOBILE PHONES',
#  u'\U0001f4f4': u'MOBILE PHONE OFF',
#  u'\U0001f4f7': u'CAMERA',
#  u'\U0001f4f6': u'ANTENNA WITH BARS',
#  u'\u2705': u'WHITE HEAVY CHECK MARK',
#  u'\U0001f463': u'FOOTPRINTS',
#  u'\U0001f4f3': u'VIBRATION MODE',
#  u'\U0001f4f2': u'MOBILE PHONE WITH RIGHTWARDS ARROW AT LEFT',
#  u'\U0001f4fd': u'FILM PROJECTOR',
#  u'\U0001f4fc': u'VIDEOCASSETTE',
#  u'\U0001f4ff': u'PRAYER BEADS',
#  u'\U0001f1ef\U0001f1f5': u'flag for Japan',
#  u'\U0001f4f9': u'VIDEO CAMERA',
#  u'\U0001f4f8': u'CAMERA WITH FLASH',
#  u'\U0001f4fb': u'RADIO',
#  u'\U0001f4fa': u'TELEVISION',
#  u'\U0001f4e5': u'INBOX TRAY',
#  u'\U0001f4e4': u'OUTBOX TRAY',
#  u'\U0001f4e7': u'E-MAIL SYMBOL',
#  u'\U0001f4e6': u'PACKAGE',
#  u'\U0001f4e1': u'SATELLITE ANTENNA',
#  u'\u2694': u'CROSSED SWORDS',
#  u'\U0001f4e3': u'CHEERING MEGAPHONE',
#  u'\u2196': u'NORTH WEST ARROW',
#  u'\U0001f4ed': u'OPEN MAILBOX WITH LOWERED FLAG',
#  u'\U0001f4ec': u'OPEN MAILBOX WITH RAISED FLAG',
#  u'\U0001f4ef': u'POSTAL HORN',
#  u'\U0001f4ee': u'POSTBOX',
#  u'\U0001f4e9': u'ENVELOPE WITH DOWNWARDS ARROW ABOVE',
#  u'\U0001f4e8': u'INCOMING ENVELOPE',
#  u'\U0001f461': u'WOMANS SANDAL',
#  u'\U0001f4ea': u'CLOSED MAILBOX WITH LOWERED FLAG',
#  u'\U0001f4d5': u'CLOSED BOOK',
#  u'\U0001f4d4': u'NOTEBOOK WITH DECORATIVE COVER',
#  u'\U0001f4d7': u'GREEN BOOK',
#  u'\U0001f4d6': u'OPEN BOOK',
#  u'\U0001f4d1': u'BOOKMARK TABS',
#  u'\U0001f4d0': u'TRIANGULAR RULER',
#  u'\U0001f4d3': u'NOTEBOOK',
#  u'\U0001f4d2': u'LEDGER',
#  u'\U0001f4dd': u'MEMO',
#  u'\U0001f4dc': u'SCROLL',
#  u'\U0001f4df': u'PAGER',
#  u'\U0001f4de': u'TELEPHONE RECEIVER',
#  u'\U0001f4d9': u'ORANGE BOOK',
#  u'\U0001f4d8': u'BLUE BOOK',
#  u'\u262f': u'YIN YANG',
#  u'\U0001f4da': u'BOOKS',
#  u'\U0001f4c5': u'CALENDAR',
#  u'\U0001f4c4': u'PAGE FACING UP',
#  u'\U0001f4c7': u'CARD INDEX',
#  u'\U0001f4c6': u'TEAR-OFF CALENDAR',
#  u'\U0001f4c1': u'FILE FOLDER',
#  u'\U0001f4c0': u'DVD',
#  u'\U0001f4c3': u'PAGE WITH CURL',
#  u'\u26c8': u'THUNDER CLOUD AND RAIN',
#  u'\U0001f4cd': u'ROUND PUSHPIN',
#  u'\U0001f4cc': u'PUSHPIN',
#  u'\U0001f4cf': u'STRAIGHT RULER',
#  u'\U0001f4ce': u'PAPERCLIP',
#  u'\U0001f460': u'HIGH-HEELED SHOE',
#  u'\U0001f4c8': u'CHART WITH UPWARDS TREND',
#  u'\U0001f4cb': u'CLIPBOARD',
#  u'\U0001f4ca': u'BAR CHART',
#  u'\U0001f4b5': u'BANKNOTE WITH DOLLAR SIGN',
#  u'\U0001f455': u'T-SHIRT',
#  u'\U0001f4b7': u'BANKNOTE WITH POUND SIGN',
#  u'\U0001f47e': u'ALIEN MONSTER',
#  u'\U0001f4b1': u'CURRENCY EXCHANGE',
#  u'\u26c4': u'SNOWMAN WITHOUT SNOW',
#  u'\U0001f170': u'NEGATIVE SQUARED LATIN CAPITAL LETTER A',
#  u'\U0001f171': u'NEGATIVE SQUARED LATIN CAPITAL LETTER B',
#  u'\U0001f17e': u'NEGATIVE SQUARED LATIN CAPITAL LETTER O',
#  u'\U0001f17f': u'NEGATIVE SQUARED LATIN CAPITAL LETTER P',
#  u'\U0001f4bf': u'OPTICAL DISC',
#  u'\U0001f4be': u'FLOPPY DISK',
#  u'\U0001f4b9': u'CHART WITH UPWARDS TREND AND YEN SIGN',
#  u'\U0001f457': u'DRESS',
#  u'\u264f': u'SCORPIUS',
#  u'\U0001f4ba': u'SEAT',
#  u'\U0001f4a5': u'COLLISION SYMBOL',
#  u'\U0001f4a4': u'SLEEPING SYMBOL',
#  u'\U0001f4a7': u'DROPLET',
#  u'\U0001f456': u'JEANS',
#  u'\u2755': u'WHITE EXCLAMATION MARK ORNAMENT',
#  u'\u26d4': u'NO ENTRY',
#  u'\U0001f4a3': u'BOMB',
#  u'\U0001f4a2': u'ANGER SYMBOL',
#  u'\U0001f4ad': u'THOUGHT BALLOON',
#  u'\U0001f451': u'CROWN',
#  u'\U0001f4af': u'HUNDRED POINTS SYMBOL',
#  u'\U0001f4ae': u'WHITE FLOWER',
#  u'\U0001f4a9': u'PILE OF POO',
#  u'\U0001f4a8': u'DASH SYMBOL',
#  u'\U0001f4ab': u'DIZZY SYMBOL',
#  u'\U0001f450': u'OPEN HANDS SIGN',
#  u'\U0001f495': u'TWO HEARTS',
#  u'\U0001f494': u'BROKEN HEART',
#  u'\U0001f497': u'GROWING HEART',
#  u'\U0001f496': u'SPARKLING HEART',
#  u'\U0001f491': u'COUPLE WITH HEART',
#  u'\U0001f490': u'BOUQUET',
#  u'\U0001f493': u'BEATING HEART',
#  u'\U0001f492': u'WEDDING',
#  u'\U0001f49d': u'HEART WITH RIBBON',
#  u'\U0001f49c': u'PURPLE HEART',
#  u'\U0001f49f': u'HEART DECORATION',
#  u'\U0001f452': u'WOMANS HAT',
#  u'\U0001f499': u'BLUE HEART',
#  u'\U0001f364': u'FRIED SHRIMP',
#  u'\U0001f49b': u'YELLOW HEART',
#  u'\U0001f49a': u'GREEN HEART',
#  u'\U0001f485': u'NAIL POLISH',
#  u'\U0001f484': u'LIPSTICK',
#  u'\U0001f487': u'HAIRCUT',
#  u'\u23f2': u'TIMER CLOCK',
#  u'\U0001f481': u'INFORMATION DESK PERSON',
#  u'\u26f4': u'FERRY',
#  u'\U0001f483': u'DANCER',
#  u'\U0001f482': u'GUARDSMAN',
#  u'\U0001f48d': u'RING',
#  u'\U0001f48c': u'LOVE LETTER',
#  u'\U0001f48f': u'KISS',
#  u'\U0001f48e': u'GEM STONE',
#  u'\U0001f489': u'SYRINGE',
#  u'\U0001f488': u'BARBER POLE',
#  u'\u267f': u'WHEELCHAIR SYMBOL',
#  u'\u25fe': u'BLACK MEDIUM SMALL SQUARE',
#  u'\U0001f575': u'SLEUTH OR SPY',
#  u'\U0001f574': u'MAN IN BUSINESS SUIT LEVITATING',
#  u'\U0001f577': u'SPIDER',
#  u'\U0001f576': u'DARK SUNGLASSES',
#  u'\U0001f570': u'MANTELPIECE CLOCK',
#  u'\U0001f573': u'HOLE',
#  u'\U0001f459': u'BIKINI',
#  u'\U0001f69d': u'MONORAIL',
#  u'\U0001f579': u'JOYSTICK',
#  u'\U0001f578': u'SPIDER WEB',
#  u'\U0001f1e7\U0001f1e6': u'flag for Bosnia & Herzegovina',
#  u'\U0001f565': u'CLOCK FACE TEN-THIRTY',
#  u'\U0001f564': u'CLOCK FACE NINE-THIRTY',
#  u'\U0001f567': u'CLOCK FACE TWELVE-THIRTY',
#  u'\U0001f566': u'CLOCK FACE ELEVEN-THIRTY',
#  u'\U0001f561': u'CLOCK FACE SIX-THIRTY',
#  u'\u2714': u'HEAVY CHECK MARK',
#  u'\U0001f563': u'CLOCK FACE EIGHT-THIRTY',
#  u'\U0001f562': u'CLOCK FACE SEVEN-THIRTY',
#  u'\U0001f6b7': u'NO PEDESTRIANS',
#  u'\U0001f56f': u'CANDLE',
#  u'\U0001f45a': u'WOMANS CLOTHES',
#  u'\u2b1c': u'WHITE LARGE SQUARE',
#  u'\U0001f555': u'CLOCK FACE SIX OCLOCK',
#  u'\U0001f554': u'CLOCK FACE FIVE OCLOCK',
#  u'\U0001f557': u'CLOCK FACE EIGHT OCLOCK',
#  u'\U0001f556': u'CLOCK FACE SEVEN OCLOCK',
#  u'\U0001f551': u'CLOCK FACE TWO OCLOCK',
#  u'\U0001f550': u'CLOCK FACE ONE OCLOCK',
#  u'\U0001f553': u'CLOCK FACE FOUR OCLOCK',
#  u'\U0001f444': u'MOUTH',
#  u'\U0001f55d': u'CLOCK FACE TWO-THIRTY',
#  u'\U0001f55c': u'CLOCK FACE ONE-THIRTY',
#  u'\U0001f55f': u'CLOCK FACE FOUR-THIRTY',
#  u'\u262a': u'STAR AND CRESCENT',
#  u'\U0001f559': u'CLOCK FACE TEN OCLOCK',
#  u'\U0001f558': u'CLOCK FACE NINE OCLOCK',
#  u'\U0001f55b': u'CLOCK FACE TWELVE OCLOCK',
#  u'\U0001f55a': u'CLOCK FACE ELEVEN OCLOCK',
#  u'\U0001f1e7\U0001f1f8': u'flag for Bahamas',
#  u'\u2734': u'EIGHT POINTED BLACK STAR',
#  u'\U0001f6b6': u'PEDESTRIAN',
#  u'\U0001f54d': u'SYNAGOGUE',
#  u'\U0001f54c': u'MOSQUE',
#  u'\u263a': u'WHITE SMILING FACE',
#  u'\U0001f549': u'OM SYMBOL',
#  u'9\u20e3': u'keycap DIGIT NINE',
#  u'\u27bf': u'DOUBLE CURLY LOOP',
#  u'\U0001f54a': u'DOVE OF PEACE',
#  u'\U0001f535': u'LARGE BLUE CIRCLE',
#  u'\U0001f534': u'LARGE RED CIRCLE',
#  u'\U0001f537': u'LARGE BLUE DIAMOND',
#  u'\U0001f536': u'LARGE ORANGE DIAMOND',
#  u'\u26c5': u'SUN BEHIND CLOUD',
#  u'\u2744': u'SNOWFLAKE',
#  u'\U0001f533': u'WHITE SQUARE BUTTON',
#  u'\U0001f532': u'BLACK SQUARE BUTTON',
#  u'\U0001f53d': u'DOWN-POINTING SMALL RED TRIANGLE',
#  u'\U0001f53c': u'UP-POINTING SMALL RED TRIANGLE',
#  u'\u264a': u'GEMINI',
#  u'\U0001f539': u'SMALL BLUE DIAMOND',
#  u'\u2663': u'BLACK CLUB SUIT',
#  u'\U0001f53b': u'DOWN-POINTING RED TRIANGLE',
#  u'\U0001f53a': u'UP-POINTING RED TRIANGLE',
#  u'\U0001f525': u'FIRE',
#  u'\U0001f44d': u'THUMBS UP SIGN',
#  u'\U0001f527': u'WRENCH',
#  u'\U0001f526': u'ELECTRIC TORCH',
#  u'\U0001f521': u'INPUT SYMBOL FOR LATIN SMALL LETTERS',
#  u'\u2754': u'WHITE QUESTION MARK ORNAMENT',
#  u'\U0001f523': u'INPUT SYMBOL FOR SYMBOLS',
#  u'\U0001f522': u'INPUT SYMBOL FOR NUMBERS',
#  u'\U0001f52d': u'TELESCOPE',
#  u'\U0001f52c': u'MICROSCOPE',
#  u'\U0001f52f': u'SIX POINTED STAR WITH MIDDLE DOT',
#  u'\U0001f52e': u'CRYSTAL BALL',
#  u'\U0001f529': u'NUT AND BOLT',
#  u'\U0001f528': u'HAMMER',
#  u'\U0001f52b': u'PISTOL',
#  u'\U0001f52a': u'HOCHO',
#  u'\U0001f515': u'BELL WITH CANCELLATION STROKE',
#  u'\U0001f514': u'BELL',
#  u'\U0001f517': u'LINK SYMBOL',
#  u'\U0001f516': u'BOOKMARK',
#  u'\U0001f511': u'KEY',
#  u'\u2764': u'HEAVY BLACK HEART',
#  u'\U0001f513': u'OPEN LOCK',
#  u'\U0001f512': u'LOCK',
#  u'\U0001f51d': u'TOP WITH UPWARDS ARROW ABOVE',
#  u'\U0001f51c': u'SOON WITH RIGHTWARDS ARROW ABOVE',
#  u'\U0001f51f': u'KEYCAP TEN',
#  u'\U0001f51e': u'NO ONE UNDER EIGHTEEN SYMBOL',
#  u'\U0001f519': u'BACK WITH LEFTWARDS ARROW ABOVE',
#  u'\U0001f518': u'RADIO BUTTON',
#  u'\U0001f51b': u'ON WITH EXCLAMATION MARK WITH LEFT RIGHT ARROW ABOVE',
#  u'\U0001f51a': u'END WITH LEFTWARDS ARROW ABOVE',
#  u'\U0001f505': u'LOW BRIGHTNESS SYMBOL',
#  u'\U0001f504': u'ANTICLOCKWISE DOWNWARDS AND UPWARDS OPEN CIRCLE ARROWS',
#  u'\U0001f507': u'SPEAKER WITH CANCELLATION STROKE',
#  u'\U0001f506': u'HIGH BRIGHTNESS SYMBOL',
#  u'\u26f5': u'SAILBOAT',
#  u'\U0001f500': u'TWISTED RIGHTWARDS ARROWS',
#  u'\U0001f503': u'CLOCKWISE DOWNWARDS AND UPWARDS OPEN CIRCLE ARROWS',
#  u'\U0001f502': u'CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS WITH CIRCLED ONE OVERLAY',
#  u'\U0001f50d': u'LEFT-POINTING MAGNIFYING GLASS',
#  u'\U0001f0cf': u'PLAYING CARD BLACK JOKER',
#  u'\U0001f50f': u'LOCK WITH INK PEN',
#  u'\U0001f50e': u'RIGHT-POINTING MAGNIFYING GLASS',
#  u'\U0001f509': u'SPEAKER WITH ONE SOUND WAVE',
#  u'\U0001f508': u'SPEAKER',
#  u'\U0001f50b': u'BATTERY',
#  u'\U0001f50a': u'SPEAKER WITH THREE SOUND WAVES',
#  u'\U0001f648': u'SEE-NO-EVIL MONKEY',
#  u'\U0001f69e': u'MOUNTAIN RAILWAY',
#  u'\u2b07': u'DOWNWARDS BLACK ARROW',
#  u'\U0001f1f1\U0001f1f7': u'flag for Liberia',
#  u'\U0001f5fd': u'STATUE OF LIBERTY',
#  u'\U0001f5fc': u'TOKYO TOWER',
#  u'\U0001f5ff': u'MOYAI',
#  u'\U0001f5fe': u'SILHOUETTE OF JAPAN',
#  u'\u270f': u'PENCIL',
#  u'\U0001f5fa': u'WORLD MAP',
#  u'\U0001f6b3': u'NO BICYCLES',
#  u'\U0001f6c1': u'BATHTUB',
#  u'\u2615': u'HOT BEVERAGE',
#  u'\U0001f69b': u'ARTICULATED LORRY',
#  u'\U0001f5e3': u'SPEAKING HEAD IN SILHOUETTE',
#  u'\U0001f6b1': u'NON-POTABLE WATER SYMBOL',
#  u'\U0001f5ef': u'RIGHT ANGER BUBBLE',
#  u'\U0001f69a': u'DELIVERY TRUCK',
#  u'\U0001f1f9\U0001f1f4': u'flag for Tonga',
#  u'\U0001f685': u'HIGH-SPEED TRAIN WITH BULLET NOSE',
#  u'\U0001f698': u'ONCOMING AUTOMOBILE',
#  u'\U0001f5d1': u'WASTEBASKET',
#  u'\U0001f5d3': u'SPIRAL CALENDAR PAD',
#  u'\U0001f5d2': u'SPIRAL NOTE PAD',
#  u'\U0001f419': u'OCTOPUS',
#  u'\U0001f5dc': u'COMPRESSION',
#  u'\u26aa': u'MEDIUM WHITE CIRCLE',
#  u'\U0001f687': u'METRO',
#  u'\U0001f6b2': u'BICYCLE',
#  u'\U0001f5c4': u'FILE CABINET',
#  u'\U0001f004': u'MAHJONG TILE RED DRAGON',
#  u'\U0001f686': u'TRAIN',
#  u'\U0001f5c3': u'CARD FILE BOX',
#  u'\U0001f5c2': u'CARD INDEX DIVIDERS',
#  u'\U0001f681': u'HELICOPTER',
#  u'\U0001f680': u'ROCKET',
#  u'\U0001f1e7\U0001f1ed': u'flag for Bahrain',
#  u'\U0001f1ee\U0001f1f9': u'flag for Italy',
#  u'\U0001f5b1': u'THREE BUTTON MOUSE',
#  u'\U0001f683': u'RAILWAY CAR',
#  u'\U0001f63c': u'CAT FACE WITH WRY SMILE',
#  u'\U0001f5b2': u'TRACKBALL',
#  u'\U0001f5bc': u'FRAME WITH PICTURE',
#  u'\U0001f682': u'STEAM LOCOMOTIVE',
#  u'\U0001f6bd': u'TOILET',
#  u'\U0001f5a5': u'DESKTOP COMPUTER',
#  u'\U0001f68d': u'ONCOMING BUS',
#  u'\U0001f1f3\U0001f1f7': u'flag for Nauru',
#  u'\U0001f43b': u'BEAR FACE',
#  u'\U0001f34f': u'GREEN APPLE',
#  u'\U0001f5a8': u'PRINTER',
#  u'\U0001f595': u'REVERSED HAND WITH MIDDLE FINGER EXTENDED',
#  u'\U0001f1f1\U0001f1f0': u'flag for Sri Lanka',
#  u'\U0001f596': u'RAISED HAND WITH PART BETWEEN MIDDLE AND RING FINGERS',
#  u'\u2665': u'BLACK HEART SUIT',
#  u'\U0001f590': u'RAISED HAND WITH FINGERS SPLAYED',
#  u'\U0001f501': u'CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS',
#  u'\U0001f6bc': u'BABY SYMBOL',
#  u'\u26ea': u'CHURCH',
#  u'\u23ec': u'BLACK DOWN-POINTING DOUBLE TRIANGLE',
#  u'\U0001f688': u'LIGHT RAIL',
#  u'\U0001f5dd': u'OLD KEY',
#  u'\U0001f587': u'LINKED PAPERCLIPS',
#  u'\U0001f6c2': u'PASSPORT CONTROL',
#  u'\U0001f68b': u'TRAM CAR',
#  u'\U0001f58d': u'LOWER LEFT CRAYON',
#  u'\U0001f58c': u'LOWER LEFT PAINTBRUSH',
#  u'\u26fa': u'TENT',
#  u'\U0001f58b': u'LOWER LEFT FOUNTAIN PEN',
#  u'\U0001f58a': u'LOWER LEFT BALLPOINT PEN',
#  u'\U0001f3b6': u'MULTIPLE MUSICAL NOTES',
#  u'\U0001f3b7': u'SAXOPHONE',
#  u'\U0001f3b4': u'FLOWER PLAYING CARDS',
#  u'\U0001f3b5': u'MUSICAL NOTE',
#  u'\U0001f3b2': u'GAME DIE',
#  u'\U0001f3b3': u'BOWLING',
#  u'\U0001f3b0': u'SLOT MACHINE',
#  u'\u2b06': u'UPWARDS BLACK ARROW',
#  u'\U0001f3be': u'TENNIS RACQUET AND BALL',
#  u'\U0001f3bf': u'SKI AND SKI BOOT',
#  u'\U0001f3bc': u'MUSICAL SCORE',
#  u'\U0001f3bd': u'RUNNING SHIRT WITH SASH',
#  u'\U0001f3ba': u'TRUMPET',
#  u'\U0001f3bb': u'VIOLIN',
#  u'\U0001f3b8': u'GUITAR',
#  u'\U0001f3b9': u'MUSICAL KEYBOARD',
#  u'\U0001f3a6': u'CINEMA',
#  u'\U0001f3a7': u'HEADPHONE',
#  u'\u2693': u'ANCHOR',
#  u'\U0001f3a5': u'MOVIE CAMERA',
#  u'\U0001f3a2': u'ROLLER COASTER',
#  u'\U0001f3a3': u'FISHING POLE AND FISH',
#  u'\U0001f3a0': u'CAROUSEL HORSE',
#  u'\U0001f3a1': u'FERRIS WHEEL',
#  u'\U0001f3ae': u'VIDEO GAME',
#  u'\u2618': u'SHAMROCK',
#  u'\U0001f3ac': u'CLAPPER BOARD',
#  u'\U0001f3ad': u'PERFORMING ARTS',
#  u'\U0001f3aa': u'CIRCUS TENT',
#  u'\U0001f3ab': u'TICKET',
#  u'\U0001f3a8': u'ARTIST PALETTE',
#  u'\U0001f3a9': u'TOP HAT',
#  u'\U0001f396': u'MILITARY MEDAL',
#  u'\U0001f397': u'REMINDER RIBBON',
#  u'\u2122': u'TRADE MARK SIGN',
#  u'\U0001f392': u'SCHOOL SATCHEL',
#  u'\U0001f393': u'GRADUATION CAP',
#  u'\U0001f390': u'WIND CHIME',
#  u'\U0001f391': u'MOON VIEWING CEREMONY',
#  u'\U0001f39e': u'FILM FRAMES',
#  u'\U0001f39f': u'ADMISSION TICKETS',
#  u'\U0001f39a': u'LEVEL SLIDER',
#  u'\U0001f39b': u'CONTROL KNOBS',
#  u'\U0001f399': u'STUDIO MICROPHONE',
#  u'\U0001f386': u'FIREWORKS',
#  u'\U0001f387': u'FIREWORK SPARKLER',
#  u'\U0001f384': u'CHRISTMAS TREE',
#  u'\U0001f385': u'FATHER CHRISTMAS',
#  u'\U0001f382': u'BIRTHDAY CAKE',
#  u'\U0001f383': u'JACK-O-LANTERN',
#  u'\U0001f380': u'RIBBON',
#  u'\U0001f381': u'WRAPPED PRESENT',
#  u'\U0001f38e': u'JAPANESE DOLLS',
#  u'\u2638': u'WHEEL OF DHARMA',
#  u'\U0001f38c': u'CROSSED FLAGS',
#  u'\U0001f38d': u'PINE DECORATION',
#  u'\U0001f38a': u'CONFETTI BALL',
#  u'\u203c': u'DOUBLE EXCLAMATION MARK',
#  u'\U0001f388': u'BALLOON',
#  u'\U0001f389': u'PARTY POPPER',
#  u'\U0001f635': u'DIZZY FACE',
#  u'\U0001f3f7': u'LABEL',
#  u'\U0001f3f4': u'WAVING BLACK FLAG',
#  u'\U0001f3f5': u'ROSETTE',
#  u'\U0001f631': u'FACE SCREAMING IN FEAR',
#  u'\U0001f3f3': u'WAVING WHITE FLAG',
#  u'\U0001f3f0': u'EUROPEAN CASTLE',
#  u'\U0001f632': u'ASTONISHED FACE',
#  u'\U0001f3fe': u'EMOJI MODIFIER FITZPATRICK TYPE-5',
#  u'\u2648': u'ARIES',
#  u'\U0001f3fc': u'EMOJI MODIFIER FITZPATRICK TYPE-3',
#  u'\U0001f3fd': u'EMOJI MODIFIER FITZPATRICK TYPE-4',
#  u'\U0001f3fa': u'AMPHORA',
#  u'\U0001f3fb': u'EMOJI MODIFIER FITZPATRICK TYPE-1-2',
#  u'\U0001f3f8': u'BADMINTON RACQUET AND SHUTTLECOCK',
#  u'\u274e': u'NEGATIVE SQUARED CROSS MARK',
#  u'\U0001f3e6': u'BANK',
#  u'\U0001f3e7': u'AUTOMATED TELLER MACHINE',
#  u'\u26d3': u'CHAINS',
#  u'\U0001f3e5': u'HOSPITAL',
#  u'\U0001f3e2': u'OFFICE BUILDING',
#  u'\U0001f3e3': u'JAPANESE POST OFFICE',
#  u'\U0001f3e0': u'HOUSE BUILDING',
#  u'\U0001f3e1': u'HOUSE WITH GARDEN',
#  u'\U0001f3ee': u'IZAKAYA LANTERN',
#  u'\U0001f3ef': u'JAPANESE CASTLE',
#  u'\U0001f3ec': u'DEPARTMENT STORE',
#  u'\U0001f3ed': u'FACTORY',
#  u'\U0001f3ea': u'CONVENIENCE STORE',
#  u'\U0001f3eb': u'SCHOOL',
#  u'\U0001f3e8': u'HOTEL',
#  u'\U0001f3e9': u'LOVE HOTEL',
#  u'\U0001f3d6': u'BEACH WITH UMBRELLA',
#  u'\U0001f3d7': u'BUILDING CONSTRUCTION',
#  u'\U0001f3d4': u'SNOW CAPPED MOUNTAIN',
#  u'\U0001f3d5': u'CAMPING',
#  u'\U0001f3d2': u'ICE HOCKEY STICK AND PUCK',
#  u'\U0001f3d3': u'TABLE TENNIS PADDLE AND BALL',
#  u'\U0001f3d0': u'VOLLEYBALL',
#  u'\U0001f3d1': u'FIELD HOCKEY STICK AND BALL',
#  u'\U0001f3de': u'NATIONAL PARK',
#  u'\u2668': u'HOT SPRINGS',
#  u'\U0001f3dc': u'DESERT',
#  u'\U0001f3dd': u'DESERT ISLAND',
#  u'\U0001f3da': u'DERELICT HOUSE BUILDING',
#  u'\U0001f3db': u'CLASSICAL BUILDING',
#  u'\U0001f3d8': u'HOUSE BUILDINGS',
#  u'\U0001f3d9': u'CITYSCAPE',
#  u'\u23f1': u'STOPWATCH',
#  u'\U0001f3c7': u'HORSE RACING',
#  u'\u26f3': u'FLAG IN HOLE',
#  u'\U0001f3c5': u'SPORTS MEDAL',
#  u'\U0001f3c2': u'SNOWBOARDER',
#  u'\U0001f3c3': u'RUNNER',
#  u'\U0001f3c0': u'BASKETBALL AND HOOP',
#  u'\U0001f3c1': u'CHEQUERED FLAG',
#  u'\U0001f3ce': u'RACING CAR',
#  u'\U0001f3cf': u'CRICKET BAT AND BALL',
#  u'\U0001f3cc': u'GOLFER',
#  u'\U0001f3cd': u'RACING MOTORCYCLE',
#  u'\U0001f3ca': u'SWIMMER',
#  u'\U0001f3cb': u'WEIGHT LIFTER',
#  u'\U0001f3c8': u'AMERICAN FOOTBALL',
#  u'\U0001f3c9': u'RUGBY FOOTBALL',
#  u'\U0001f336': u'HOT PEPPER',
#  u'\U0001f337': u'TULIP',
#  u'\u2603': u'SNOWMAN',
#  u'\U0001f335': u'CACTUS',
#  u'\U0001f332': u'EVERGREEN TREE',
#  u'\U0001f333': u'DECIDUOUS TREE',
#  u'\U0001f330': u'CHESTNUT',
#  u'\U0001f331': u'SEEDLING',
#  u'\u2709': u'ENVELOPE',
#  u'\U0001f33f': u'HERB',
#  u'\U0001f33c': u'BLOSSOM',
#  u'\U0001f33d': u'EAR OF MAIZE',
#  u'\U0001f33a': u'HIBISCUS',
#  u'\U0001f33b': u'SUNFLOWER',
#  u'\U0001f338': u'CHERRY BLOSSOM',
#  u'\U0001f339': u'ROSE',
#  u'\U0001f326': u'WHITE SUN BEHIND CLOUD WITH RAIN',
#  u'\U0001f327': u'CLOUD WITH RAIN',
#  u'\U0001f324': u'WHITE SUN WITH SMALL CLOUD',
#  u'\U0001f325': u'WHITE SUN BEHIND CLOUD',
#  u'\U0001f6e1': u'SHIELD',
#  u'\U0001f6e0': u'HAMMER AND WRENCH',
#  u'\U0001f320': u'SHOOTING STAR',
#  u'\U0001f321': u'THERMOMETER',
#  u'\U0001f32e': u'TACO',
#  u'\U0001f32f': u'BURRITO',
#  u'\U0001f32c': u'WIND BLOWING FACE',
#  u'\U0001f32d': u'HOT DOG',
#  u'\U0001f32a': u'CLOUD WITH TORNADO',
#  u'\U0001f32b': u'FOG',
#  u'\U0001f328': u'CLOUD WITH SNOW',
#  u'\U0001f329': u'CLOUD WITH LIGHTNING',
#  u'\U0001f316': u'WANING GIBBOUS MOON SYMBOL',
#  u'\U0001f317': u'LAST QUARTER MOON SYMBOL',
#  u'\u2623': u'BIOHAZARD SIGN',
#  u'\U0001f315': u'FULL MOON SYMBOL',
#  u'\U0001f312': u'WAXING CRESCENT MOON SYMBOL',
#  u'\U0001f313': u'FIRST QUARTER MOON SYMBOL',
#  u'\U0001f310': u'GLOBE WITH MERIDIANS',
#  u'\U0001f311': u'NEW MOON SYMBOL',
#  u'\U0001f31e': u'SUN WITH FACE',
#  u'\U0001f31f': u'GLOWING STAR',
#  u'\U0001f31c': u'LAST QUARTER MOON WITH FACE',
#  u'\u25aa': u'BLACK SMALL SQUARE',
#  u'\U0001f31a': u'NEW MOON WITH FACE',
#  u'\U0001f31b': u'FIRST QUARTER MOON WITH FACE',
#  u'\U0001f318': u'WANING CRESCENT MOON SYMBOL',
#  u'\U0001f319': u'CRESCENT MOON',
#  u'\U0001f306': u'CITYSCAPE AT DUSK',
#  u'\U0001f307': u'SUNSET OVER BUILDINGS',
#  u'\U0001f304': u'SUNRISE OVER MOUNTAINS',
#  u'\U0001f305': u'SUNRISE',
#  u'\U0001f302': u'CLOSED UMBRELLA',
#  u'\U0001f303': u'NIGHT WITH STARS',
#  u'\U0001f300': u'CYCLONE',
#  u'\U0001f301': u'FOGGY',
#  u'\U0001f30e': u'EARTH GLOBE AMERICAS',
#  u'\U0001f30f': u'EARTH GLOBE ASIA-AUSTRALIA',
#  u'\U0001f30c': u'MILKY WAY',
#  u'\U0001f30d': u'EARTH GLOBE EUROPE-AFRICA',
#  u'\U0001f30a': u'WATER WAVE',
#  u'\U0001f30b': u'VOLCANO',
#  u'\U0001f308': u'RAINBOW',
#  u'\U0001f309': u'BRIDGE AT NIGHT',
#  u'\U0001f376': u'SAKE BOTTLE AND CUP',
#  u'\U0001f377': u'WINE GLASS',
#  u'\U0001f374': u'FORK AND KNIFE',
#  u'\U0001f375': u'TEACUP WITHOUT HANDLE',
#  u'\U0001f372': u'POT OF FOOD',
#  u'\U0001f373': u'COOKING',
#  u'\U0001f370': u'SHORTCAKE',
#  u'\U0001f371': u'BENTO BOX',
#  u'\U0001f37e': u'BOTTLE WITH POPPING CORK',
#  u'\U0001f37f': u'POPCORN',
#  u'\U0001f37c': u'BABY BOTTLE',
#  u'\U0001f37d': u'FORK AND KNIFE WITH PLATE',
#  u'\U0001f37a': u'BEER MUG',
#  u'\U0001f37b': u'CLINKING BEER MUGS',
#  u'\U0001f378': u'COCKTAIL GLASS',
#  u'\U0001f379': u'TROPICAL DRINK',
#  u'\U0001f366': u'SOFT ICE CREAM',
#  u'\U0001f367': u'SHAVED ICE',
#  u'\u2653': u'PISCES',
#  u'\U0001f365': u'FISH CAKE WITH SWIRL DESIGN',
#  u'\U0001f362': u'ODEN',
#  u'\U0001f363': u'SUSHI',
#  u'\U0001f360': u'ROASTED SWEET POTATO',
#  u'\U0001f361': u'DANGO',
#  u'\U0001f36e': u'CUSTARD',
#  u'\U0001f36f': u'HONEY POT',
#  u'\U0001f36c': u'CANDY',
#  u'\U0001f36d': u'LOLLIPOP',
#  u'\U0001f36a': u'COOKIE',
#  u'\U0001f36b': u'CHOCOLATE BAR',
#  u'\U0001f368': u'ICE CREAM',
#  u'\U0001f369': u'DOUGHNUT',
#  u'\U0001f356': u'MEAT ON BONE',
#  u'\U0001f357': u'POULTRY LEG',
#  u'\U0001f354': u'HAMBURGER',
#  u'\U0001f355': u'SLICE OF PIZZA',
#  u'\U0001f352': u'CHERRIES',
#  u'\U0001f353': u'STRAWBERRY',
#  u'\U0001f350': u'PEAR',
#  u'\U0001f351': u'PEACH',
#  u'\U0001f35e': u'BREAD',
#  u'\U0001f35f': u'FRENCH FRIES',
#  u'\U0001f35c': u'STEAMING BOWL',
#  u'\U0001f35d': u'SPAGHETTI',
#  u'\U0001f35a': u'COOKED RICE',
#  u'\U0001f35b': u'CURRY AND RICE',
#  u'\U0001f358': u'RICE CRACKER',
#  u'\U0001f359': u'RICE BALL',
#  u'\U0001f346': u'AUBERGINE',
#  u'\U0001f347': u'GRAPES',
#  u'\U0001f344': u'MUSHROOM',
#  u'\U0001f345': u'TOMATO',
#  u'\U0001f342': u'FALLEN LEAF',
#  u'\U0001f343': u'LEAF FLUTTERING IN WIND',
#  u'\U0001f340': u'FOUR LEAF CLOVER',
#  u'\U0001f341': u'MAPLE LEAF',
#  u'\U0001f34e': u'RED APPLE',
#  u'\u26f8': u'ICE SKATE',
#  u'\U0001f34c': u'BANANA',
#  u'\U0001f34d': u'PINEAPPLE',
#  u'\U0001f34a': u'TANGERINE',
#  u'\U0001f34b': u'LEMON',
#  u'\U0001f348': u'MELON',
#  u'\U0001f349': u'WATERMELON',
#  u'\U0001f1ef\U0001f1f4': u'flag for Jordan',
#  u'7\u20e3': u'keycap DIGIT SEVEN',
#  u'\U0001f911': u'MONEY-MOUTH FACE',
#  u'\U0001f1eb\U0001f1ef': u'flag for Fiji',
#  u'\u2708': u'AIRPLANE',
#  u'\u260e': u'BLACK TELEPHONE',
#  u'\U0001f1eb\U0001f1f7': u'flag for France',
#  u'\U0001f1eb\U0001f1f4': u'flag for Faroe Islands',
#  u'\U0001f1eb\U0001f1f2': u'flag for Micronesia',
#  u'\u2197': u'NORTH EAST ARROW',
#  u'\U0001f1eb\U0001f1f0': u'flag for Falkland Islands',
#  u'\u2699': u'GEAR',
#  u'\U0001f4f1': u'MOBILE PHONE',
#  u'\U0001f1e7\U0001f1ea': u'flag for Belgium',
#  u'\U0001f4f0': u'NEWSPAPER',
#  u'\U0001f6cc': u'SLEEPING ACCOMMODATION',
#  u'\U0001f1f2\U0001f1fe': u'flag for Malaysia',
#  u'\U0001f1ed\U0001f1fa': u'flag for Hungary',
#  u'\U0001f6cf': u'BED',
#  u'\U0001f1f2\U0001f1ff': u'flag for Mozambique',
#  u'\u2728': u'SPARKLES',
#  u'\u262e': u'PEACE SYMBOL',
#  u'\U0001f1f9\U0001f1f2': u'flag for Turkmenistan',
#  u'\U0001f6a1': u'AERIAL TRAMWAY',
#  u'\U0001f1f0\U0001f1fc': u'flag for Kuwait',
#  u'\U0001f6c5': u'LEFT LUGGAGE',
#  u'\U0001f1ea\U0001f1e8': u'flag for Ecuador',
#  u'\U0001f1f2\U0001f1fb': u'flag for Maldives',
#  u'\U0001f1ee\U0001f1f7': u'flag for Iran',
#  u'\U0001f1f9\U0001f1e8': u'flag for Turks & Caicos Islands',
#  u'\U0001f1ee\U0001f1ea': u'flag for Ireland',
#  u'\u264e': u'LIBRA',
#  u'\u2b50': u'WHITE MEDIUM STAR',
#  u'\U0001f6a0': u'MOUNTAIN CABLEWAY',
#  u'\U0001f1f9\U0001f1fb': u'flag for Tuvalu',
#  u'\U0001f1f2\U0001f1f7': u'flag for Mauritania',
#  u'\U0001f6e4': u'RAILWAY TRACK',
#  u'\U0001f1fa\U0001f1f2': u'flag for U.S. Outlying Islands',
#  u'\U0001f1f1\U0001f1e7': u'flag for Lebanon',
#  u'\u26e9': u'SHINTO SHRINE',
#  u'\u23eb': u'BLACK UP-POINTING DOUBLE TRIANGLE',
#  u'1\u20e3': u'keycap DIGIT ONE',
#  u'\U0001f6a3': u'ROWBOAT',
#  u'\u26f9': u'PERSON WITH BALL',
#  u'\U0001f6b0': u'POTABLE WATER SYMBOL',
#  u'\U0001f1f2\U0001f1f1': u'flag for Mali',
#  u'\U0001f4e0': u'FAX MACHINE',
#  u'\U0001f236': u'SQUARED CJK UNIFIED IDEOGRAPH-6709',
#  u'\U0001f237': u'SQUARED CJK UNIFIED IDEOGRAPH-6708',
#  u'\U0001f234': u'SQUARED CJK UNIFIED IDEOGRAPH-5408',
#  u'\U0001f235': u'SQUARED CJK UNIFIED IDEOGRAPH-6E80',
#  u'\U0001f232': u'SQUARED CJK UNIFIED IDEOGRAPH-7981',
#  u'\U0001f233': u'SQUARED CJK UNIFIED IDEOGRAPH-7A7A',
#  u'\U0001f4e2': u'PUBLIC ADDRESS LOUDSPEAKER',
#  u'\U0001f23a': u'SQUARED CJK UNIFIED IDEOGRAPH-55B6',
#  u'\U0001f238': u'SQUARED CJK UNIFIED IDEOGRAPH-7533',
#  u'\U0001f239': u'SQUARED CJK UNIFIED IDEOGRAPH-5272',
#  u'\U0001f22f': u'SQUARED CJK UNIFIED IDEOGRAPH-6307',
#  u'\u231b': u'HOURGLASS',
#  u'\U0001f1e9\U0001f1ea': u'flag for Germany',
#  u'\U0001f1f7\U0001f1fa': u'flag for Russia',
#  u'\U0001f1f7\U0001f1f8': u'flag for Serbia',
#  u'\U0001f1f7\U0001f1fc': u'flag for Rwanda',
#  u'\U0001f1f5\U0001f1f0': u'flag for Pakistan',
#  u'\U0001f45b': u'PURSE',
#  u'\U0001f21a': u'SQUARED CJK UNIFIED IDEOGRAPH-7121',
#  u'\U0001f1f8\U0001f1fd': u'flag for Sint Maarten',
#  u'\U0001f1f7\U0001f1f4': u'flag for Romania',
#  u'\U0001f1f5\U0001f1fc': u'flag for Palau',
#  u'\U0001f1f7\U0001f1ea': u'flag for R\xe9union',
#  u'\u2733': u'EIGHT SPOKED ASTERISK',
#  u'\U0001f6a5': u'HORIZONTAL TRAFFIC LIGHT',
#  u'\U0001f202': u'SQUARED KATAKANA SA',
#  u'\U0001f4eb': u'CLOSED MAILBOX WITH RAISED FLAG',
#  u'\U0001f510': u'CLOSED LOCK WITH KEY',
#  u'\U0001f201': u'SQUARED KATAKANA KOKO',
#  u'\u2639': u'WHITE FROWNING FACE',
#  u'\U0001f917': u'HUGGING FACE',
#  u'\U0001f1fd\U0001f1f0': u'flag for Kosovo',
#  u'\u303d': u'PART ALTERNATION MARK',
#  u'\U0001f1fb\U0001f1f3': u'flag for Vietnam',
#  u'\u26be': u'BASEBALL',
#  u'\U0001f1f3\U0001f1ff': u'flag for New Zealand',
#  u'\U0001f1f1\U0001f1fb': u'flag for Latvia',
#  u'\U0001f696': u'ONCOMING TAXI',
#  u'\u2649': u'TAURUS',
#  u'\U0001f6ac': u'SMOKING SYMBOL',
#  u'\U0001f1f3\U0001f1f4': u'flag for Norway',
#  u'\U0001f1f3\U0001f1f1': u'flag for Netherlands',
#  u'\u26ce': u'OPHIUCHUS',
#  u'\U0001f1f3\U0001f1ee': u'flag for Nicaragua',
#  u'\u2753': u'BLACK QUESTION MARK ORNAMENT',
#  u'\U0001f1f3\U0001f1ec': u'flag for Nigeria',
#  u'\U0001f1f3\U0001f1eb': u'flag for Norfolk Island',
#  u'\U0001f1f3\U0001f1ea': u'flag for Niger',
#  u'\U0001f1f2\U0001f1eb': u'flag for St. Martin',
#  u'\U0001f1f3\U0001f1e8': u'flag for New Caledonia',
#  u'\U0001f1f3\U0001f1e6': u'flag for Namibia',
#  u'\U0001f1f9\U0001f1eb': u'flag for French Southern Territories',
#  u'\U0001f1ff\U0001f1f2': u'flag for Zambia',
#  u'\u2763': u'HEAVY HEART EXCLAMATION MARK ORNAMENT',
#  u'\U0001f1e7\U0001f1ef': u'flag for Benin',
#  u'\U0001f250': u'CIRCLED IDEOGRAPH ADVANTAGE',
#  u'\U0001f251': u'CIRCLED IDEOGRAPH ACCEPT',
#  u'\U0001f6af': u'DO NOT LITTER SYMBOL',
#  u'\U0001f981': u'LION FACE',
#  u'\U0001f6a4': u'SPEEDBOAT',
#  u'\U0001f1f9\U0001f1e9': u'flag for Chad',
#  u'\U0001f1ff\U0001f1fc': u'flag for Zimbabwe',
#  u'\u23f0': u'ALARM CLOCK',
#  u'\U0001f627': u'ANGUISHED FACE',
#  u'\U0001f1ff\U0001f1e6': u'flag for South Africa',
#  u'\U0001f684': u'HIGH-SPEED TRAIN',
#  u'\U0001f1f4\U0001f1f2': u'flag for Oman',
#  u'\u2702': u'BLACK SCISSORS',
#  u'\U0001f5f3': u'BALLOT BOX WITH BALLOT',
#  u'\U0001f1f8\U0001f1e9': u'flag for Sudan',
#  u'\U0001f1f5\U0001f1f1': u'flag for Poland',
#  u'\U0001f6e2': u'OIL DRUM',
#  u'\U0001f1f8\U0001f1f2': u'flag for San Marino',
#  u'\U0001f626': u'FROWNING FACE WITH OPEN MOUTH',
#  u'\u2712': u'BLACK NIB',
#  u'\U0001f1e7\U0001f1f4': u'flag for Bolivia',
#  u'\U0001f4db': u'NAME BADGE',
#  u'\u2697': u'ALEMBIC',
#  u'\u2199': u'SOUTH WEST ARROW',
#  u'\u231a': u'WATCH',
#  u'\U0001f1f0\U0001f1f5': u'flag for North Korea',
#  u'\U0001f1f0\U0001f1f7': u'flag for South Korea',
#  u'\U0001f6a9': u'TRIANGULAR FLAG ON POST',
#  u'\U0001f1f0\U0001f1f2': u'flag for Comoros',
#  u'\U0001f1f0\U0001f1f3': u'flag for St. Kitts & Nevis',
#  u'\u21a9': u'LEFTWARDS ARROW WITH HOOK',
#  u'\U0001f1f0\U0001f1fe': u'flag for Cayman Islands',
#  u'\U0001f3b1': u'BILLIARDS',
#  u'\U0001f68a': u'TRAM',
#  u'\U0001f1e7\U0001f1f7': u'flag for Brazil',
#  u'\U0001f1f1\U0001f1fa': u'flag for Luxembourg',
#  u'\U0001f61c': u'FACE WITH STUCK-OUT TONGUE AND WINKING EYE',
#  u'\U0001f1f0\U0001f1ec': u'flag for Kyrgyzstan',
#  u'\U0001f1f0\U0001f1ed': u'flag for Cambodia',
#  u'\U0001f1f0\U0001f1ee': u'flag for Kiribati',
#  u'\U0001f1f0\U0001f1ea': u'flag for Kenya',
#  u'\U0001f1fa\U0001f1e6': u'flag for Ukraine',
#  u'\U0001f6a8': u'POLICE CARS REVOLVING LIGHT',
#  u'\U0001f1fc\U0001f1eb': u'flag for Wallis & Futuna',
#  u'\U0001f1f5\U0001f1f3': u'flag for Pitcairn Islands',
#  u'\U0001f1ec\U0001f1f9': u'flag for Guatemala',
#  u'\U0001f6ec': u'AIRPLANE ARRIVING',
#  u'\U0001f4c2': u'OPEN FILE FOLDER',
#  u'\U0001f6ce': u'BELLHOP BELL',
#  u'\u264c': u'LEO',
#  u'\U0001f1fc\U0001f1f8': u'flag for Samoa',
#  u'\U0001f6ab': u'NO ENTRY SIGN',
#  u'\U0001f1f8\U0001f1ed': u'flag for St. Helena',
#  u'\U0001f1f8\U0001f1ee': u'flag for Slovenia',
#  u'\U0001f1f8\U0001f1ef': u'flag for Svalbard & Jan Mayen',
#  u'\U0001f1f8\U0001f1e8': u'flag for Seychelles',
#  u'\U0001f1ec\U0001f1fe': u'flag for Guyana',
#  u'\U0001f1f8\U0001f1ea': u'flag for Sweden',
#  u'\U0001f4c9': u'CHART WITH DOWNWARDS TREND',
#  u'\U0001f1f8\U0001f1e6': u'flag for Saudi Arabia',
#  u'\U0001f1f8\U0001f1e7': u'flag for Solomon Islands',
#  u'\U0001f3a4': u'MICROPHONE',
#  u'0\u20e3': u'keycap DIGIT ZERO',
#  u'\U0001f1f8\U0001f1fe': u'flag for Syria',
#  u'\U0001f1f8\U0001f1ff': u'flag for Swaziland',
#  u'\U0001f1f8\U0001f1f8': u'flag for South Sudan',
#  u'\U0001f1f8\U0001f1f9': u'flag for S\xe3o Tom\xe9 & Pr\xedncipe',
#  u'\u26f7': u'SKIER',
#  u'\U0001f1f8\U0001f1fb': u'flag for El Salvador',
#  u'\U0001f1f8\U0001f1f4': u'flag for Somalia',
#  u'\U0001f1f8\U0001f1f7': u'flag for Suriname',
#  u'\U0001f1f8\U0001f1f0': u'flag for Slovakia',
#  u'\U0001f6a6': u'VERTICAL TRAFFIC LIGHT',
#  u'\U0001f6aa': u'DOOR',
#  u'\U0001f1f8\U0001f1f3': u'flag for Senegal',
#  u'\u2b05': u'LEFTWARDS BLACK ARROW',
#  u'\U0001f1fa\U0001f1f8': u'flag for United States',
#  u'\U0001f4b4': u'BANKNOTE WITH YEN SIGN',
#  u'\u270d': u'WRITING HAND',
#  u'\U0001f1ed\U0001f1f7': u'flag for Croatia',
#  u'2\u20e3': u'keycap DIGIT TWO',
#  u'\U0001f4b6': u'BANKNOTE WITH EURO SIGN',
#  u'\U0001f1ec\U0001f1f6': u'flag for Equatorial Guinea',
#  u'\U0001f3af': u'DIRECT HIT',
#  u'\u271d': u'LATIN CROSS',
#  u'\u269c': u'FLEUR-DE-LIS',
#  u'\U0001f4b0': u'MONEY BAG',
#  u'\U0001f6e9': u'SMALL AIRPLANE',
#  u'\U0001f4b3': u'CREDIT CARD',
#  u'\U0001f1f8\U0001f1ec': u'flag for Singapore',
#  u'\U0001f4b2': u'HEAVY DOLLAR SIGN',
#  u'\U0001f1ec\U0001f1ea': u'flag for Georgia',
#  u'\U0001f4bd': u'MINIDISC',
#  u'\U0001f1ec\U0001f1eb': u'flag for French Guiana',
#  u'\u25b6': u'BLACK RIGHT-POINTING TRIANGLE',
#  u'\u2139': u'INFORMATION SOURCE',
#  u'\U0001f6a2': u'SHIP',
#  u'\U0001f694': u'ONCOMING POLICE CAR',
#  u'\U0001f1ec\U0001f1ed': u'flag for Ghana',
#  u'\U0001f918': u'SIGN OF THE HORNS',
#  u'\U0001f1e7\U0001f1e9': u'flag for Bangladesh',
#  u'\U0001f5de': u'ROLLED-UP NEWSPAPER',
#  u'\U0001f62c': u'GRIMACING FACE',
#  u'\U0001f1fb\U0001f1fa': u'flag for Vanuatu',
#  u'\U0001f4b8': u'MONEY WITH WINGS',
#  u'\u2b55': u'HEAVY LARGE CIRCLE',
#  u'\U0001f4bb': u'PERSONAL COMPUTER',
#  u'\U0001f1fa\U0001f1ff': u'flag for Uzbekistan',
#  u'\U0001f697': u'AUTOMOBILE',
#  u'\U0001f6eb': u'AIRPLANE DEPARTURE',
#  u'\u23ea': u'BLACK LEFT-POINTING DOUBLE TRIANGLE',
#  u'\U0001f690': u'MINIBUS',
#  u'\U0001f4a6': u'SPLASHING SWEAT SYMBOL',
#  u'\U0001f63a': u'SMILING CAT FACE WITH OPEN MOUTH',
#  u'\U0001f5fb': u'MOUNT FUJI',
#  u'\U0001f476': u'BABY',
#  u'\U0001f4a1': u'ELECTRIC LIGHT BULB',
#  u'\u23fa': u'BLACK CIRCLE FOR RECORD',
#  u'\U0001f912': u'FACE WITH THERMOMETER',
#  u'\U0001f1f9\U0001f1ed': u'flag for Thailand',
#  u'\U0001f4a0': u'DIAMOND SHAPE WITH A DOT INSIDE',
#  u'\U0001f1e8\U0001f1fc': u'flag for Cura\xe7ao',
#  u'\u2602': u'UMBRELLA',
#  u'\u270c': u'VICTORY HAND',
#  u'\U0001f1ea\U0001f1ed': u'flag for Western Sahara',
#  u'\U0001f691': u'AMBULANCE',
#  u'\u2797': u'HEAVY DIVISION SIGN',
#  u'\U0001f4ac': u'SPEECH BALLOON',
#  u'\U0001f1f9\U0001f1f7': u'flag for Turkey',
#  u'\U0001f6bf': u'SHOWER',
#  u'\U0001f1e7\U0001f1ee': u'flag for Burundi',
#  u'\U0001f645': u'FACE WITH NO GOOD GESTURE',
#  u'\u2622': u'RADIOACTIVE SIGN',
#  u'\U0001f644': u'FACE WITH ROLLING EYES',
#  u'\xa9': u'COPYRIGHT SIGN',
#  u'\u25ab': u'WHITE SMALL SQUARE',
#  u'\U0001f647': u'PERSON BOWING DEEPLY',
#  u'\U0001f646': u'FACE WITH OK GESTURE',
#  u'\U0001f1f5\U0001f1eb': u'flag for French Polynesia',
#  u'\U0001f641': u'SLIGHTLY FROWNING FACE',
#  u'\U0001f4aa': u'FLEXED BICEPS',
#  u'\u26bd': u'SOCCER BALL',
#  u'\U0001f1ee\U0001f1f3': u'flag for India',
#  u'\U0001f640': u'WEARY CAT FACE',
#  u'\U0001f1e8\U0001f1f7': u'flag for Costa Rica',
#  u'\U0001f1fb\U0001f1e6': u'flag for Vatican City',
#  u'\U0001f643': u'UPSIDE-DOWN FACE',
#  u'\U0001f642': u'SLIGHTLY SMILING FACE',
#  u'\u274c': u'CROSS MARK',
#  u'\u23cf': u'EJECT SYMBOL',
#  u'\U0001f6ad': u'NO SMOKING SYMBOL',
#  u'\U0001f64d': u'PERSON FROWNING',
#  u'\u2652': u'AQUARIUS',
#  u'\U0001f1f5\U0001f1ea': u'flag for Peru',
#  u'\U0001f1f9\U0001f1f1': u'flag for Timor-Leste',
#  u'\U0001f38f': u'CARP STREAMER',
#  u'\U0001f1e7\U0001f1ec': u'flag for Bulgaria',
#  u'\U0001f64f': u'PERSON WITH FOLDED HANDS',
#  u'\U0001f1e8\U0001f1ec': u'flag for Congo - Brazzaville',
#  u'\U0001f64e': u'PERSON WITH POUTING FACE',
#  u'\U0001f1e8\U0001f1ed': u'flag for Switzerland',
#  u'\U0001f649': u'HEAR-NO-EVIL MONKEY',
#  u'\u23ef': u'BLACK RIGHT-POINTING TRIANGLE WITH DOUBLE VERTICAL BAR',
#  u'\U0001f38b': u'TANABATA TREE',
#  u'\U0001f1f0\U0001f1ff': u'flag for Kazakhstan',
#  u'\U0001f1f5\U0001f1ed': u'flag for Philippines',
#  u'\U0001f1f9\U0001f1f0': u'flag for Tokelau',
#  u'\U0001f64b': u'HAPPY PERSON RAISING ONE HAND',
#  u'\u25fb': u'WHITE MEDIUM SQUARE',
#  u'\U0001f64a': u'SPEAK-NO-EVIL MONKEY',
#  u'\u26fd': u'FUEL PUMP',
#  u'\U0001f1e8\U0001f1e9': u'flag for Congo - Kinshasa',
#  u'\U0001f49e': u'REVOLVING HEARTS',
#  u'\U0001f634': u'SLEEPING FACE',
#  u'\U0001f693': u'POLICE CAR',
#  u'\U0001f1e8\U0001f1eb': u'flag for Central African Republic',
#  u'\U0001f637': u'FACE WITH MEDICAL MASK',
#  u'\U0001f498': u'HEART WITH ARROW',
#  u'\U0001f1f5\U0001f1ec': u'flag for Papua New Guinea',
#  u'\U0001f1f9\U0001f1f3': u'flag for Tunisia',
#  u'\u2692': u'HAMMER AND PICK',
#  u'\u2198': u'SOUTH EAST ARROW',
#  u'\u261d': u'WHITE UP POINTING INDEX',
#  u'\u2b1b': u'BLACK LARGE SQUARE',
#  u'\U0001f630': u'FACE WITH OPEN MOUTH AND COLD SWEAT',
#  u'\U0001f64c': u'PERSON RAISING BOTH HANDS IN CELEBRATION',
#  u'\U0001f633': u'FLUSHED FACE',
#  u'\U0001f1ef\U0001f1ea': u'flag for Jersey',
#  u'\U0001f5e1': u'DAGGER KNIFE',
#  u'\U0001f69c': u'TRACTOR',
#  u'\U0001f454': u'NECKTIE',
#  u'\xae': u'REGISTERED SIGN',
#  u'\U0001f63d': u'KISSING CAT FACE WITH CLOSED EYES',
#  u'\U0001f486': u'FACE MASSAGE',
#  u'\U0001f3ff': u'EMOJI MODIFIER FITZPATRICK TYPE-6',
#  u'\U0001f63f': u'CRYING CAT FACE',
#  u'\U0001f480': u'SKULL',
#  u'\u25c0': u'BLACK LEFT-POINTING TRIANGLE',
#  u'\U0001f63e': u'POUTING CAT FACE',
#  u'\u2747': u'SPARKLE',
#  u'\u2049': u'EXCLAMATION QUESTION MARK',
#  u'\U0001f639': u'CAT FACE WITH TEARS OF JOY',
#  u'\u264d': u'VIRGO',
#  u'\U0001f638': u'GRINNING CAT FACE WITH SMILING EYES',
#  u'\U0001f1ed\U0001f1f0': u'flag for Hong Kong',
#  u'\U0001f1ed\U0001f1f3': u'flag for Honduras',
#  u'\U0001f1ed\U0001f1f2': u'flag for Heard & McDonald Islands',
#  u'\U0001f699': u'RECREATIONAL VEHICLE',
#  ...}

# %%
#source: http://marcobonzanini.com/2015/03/09/mining-twitter-data-with-python-part-2/
    
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\[/\\OpP] # Mouth
    )"""

#we are not interested in url, and @ mentions

hash_tags= r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)"

html=r'<[^>]+>'

url=r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+'

mention=r'(?:@[?\w_]+)'

regex1=r"\.{2,}"

regex2=r"\-{2,}"

#emoji
try:
    # UCS-4
    emoji_re = re.compile(u'([\U00002600-\U000027BF])|([\U0001f300-\U0001f64F])|([\U0001f680-\U0001f6FF])')
except re.error:
    # UCS-2
    emoji_re = re.compile(u'([\u2600-\u27BF])|([\uD83C][\uDF00-\uDFFF])|([\uD83D][\uDC00-\uDE4F])|([\uD83D][\uDE80-\uDEFF])')


regex_str = [
    emoticons_str,
    html, # HTML tags
    mention, # @-mentions
    hash_tags, # hash-tags
    url, # URLs
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    regex1,
    regex2,
    r'(?:\S)' # anything else
]


remove_str=[
    emoticons_str,
    html, # HTML tags
    mention, # @-mentions ????
    url, # URLs
    regex1,
    regex2,
]
    

tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
remove_re = re.compile(r'('+'|'.join(remove_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
hash_tags_re = re.compile(hash_tags, re.VERBOSE | re.IGNORECASE)

# %%
"""
Function
--------
tokenize

Convert text to tokens, if the text has emoji,
convert emoji to text using `mapping`, and save as a list.

Parameters
----------
s: text

Output
---------
tokens: tokens of a text, including emoji 
emojitext: list of texts represented by emoji
"""

def tokenize(s):
    emojitext=set([])
    #find all emoji
    for utuple in emoji_re.findall(s):
        for i in utuple:
            if len(i)>0:
                try:
    #use the emoji dictionary to find what the emoji represent
                    emojitext.add(mapping[i])
                except KeyError:
                    continue
    
    #find all tokens
    tokens=tokens_re.findall(s)
    
    if len(emojitext)>0:
        tokens=tokens+(list(emojitext))
    
    return tokens,list(emojitext)

# %%
"""
Function
--------
preprocess

Combine text and quoted_text to one,
Remove url, html tag, @-mentions from the combined text,
Extract hashtags  and emoticons from the combined text.

Parameters
----------
s: text

Output
---------
s: return a string without url, html tag, and @-mentions
s_tokens: return a list of tokens
emoticons: return a list of emoticons
hashtags: return a list of hashtags
"""

def preprocess(s):
        s=s.decode('utf-8')
        tokens,emoji = tokenize(s)
        #get the lower case
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
        
        #get the list of emoticons
        emo= filter(None,[token if emoticon_re.search(token) else None for token in tokens])
        
        #get the list of hashtags
        ht=filter(None,[token[1:] if hash_tags_re.search(token) else None for token in tokens])
        hashtags = regreform(ht)    
        
        #remove @ and html tag, url, emoticons_str,emoji
        s_clean=emoji_re.sub(',',s)
        s_clean=remove_re.sub('',s_clean)
        
        #add the list of texts represented by emoji to clean text
        emoji.append(s_clean)
        s_clean='.'.join(emoji)
        t_c,e_c = tokenize(s_clean)
        s_tokens = [token.lower() for token in t_c]
        return s_clean, s_tokens,emo,hashtags

# %%
dftokens=dftouse.reset_index()

dftokens['sent']=dftokens['text'].apply(lambda r: preprocess(r) if (len(str(r))>0) & (isinstance(r, str)) else '' )
#dftokens.take(2)
dftokens.head()
# Out:
#    index     user_id                     created_at_t quoted_text tweet_longitude  tweet_latitude  followers_count  friends_count  statuses_count                    created_at_u      tweet_id truncated  in_reply_to_status_id  retweeted_status  timestamp_ms                                               text lang        country     place_full_name               timestamp        date             time                                               sent
# 0      0  3095695629  Fri Dec 23 03:15:20     47864\n         NaN      -71.683502       42.036932             7424            985           36984  Thu Mar 19 01:33:34 +0000 2015  6.688683e+17     False           6.688680e+17               NaN  1.448306e+12            @DopeAhhAquarius lemme come over bro :(   en  United States  Massachusetts, USA 2015-11-23 19:06:44.120  2015-11-23  19:06:44.120000  ( lemme come over bro , [lemme, come, over, br...
# 1      1  2174756318  Fri Dec 23 03:15:38     47864\n         NaN      -71.326858       42.636248              110            159            2199  Mon Nov 04 21:06:33 +0000 2013  6.688683e+17     False                    NaN               NaN  1.448306e+12            I've been in a bad mood since like 2010   en  United States          Lowell, MA 2015-11-23 19:06:44.138  2015-11-23  19:06:44.138000  (I've been in a bad mood since like 2010, [i'v...
# 2      2   408976087  Fri Dec 23 03:57:00     47864\n         NaN     -71.0887545       42.313670              514            246           37162  Thu Nov 10 03:50:52 +0000 2011  6.688683e+17     False                    NaN               NaN  1.448306e+12  what's the appropriate age for me to start act...   en  United States          Boston, MA 2015-11-23 19:06:46.620  2015-11-23  19:06:46.620000  (what's the appropriate age for me to start ac...
# 3      3  1163319366  Fri Dec 23 05:40:30     47864\n         NaN      -71.312617       42.693109              465            604           57037  Sat Feb 09 16:02:36 +0000 2013  6.688683e+17     False           6.688683e+17               NaN  1.448306e+12  @JackSillin @AlexReedWX @WesternMEwx ...I assu...   en  United States          Dracut, MA 2015-11-23 19:06:52.830  2015-11-23  19:06:52.830000  (   I assume your dad works at your school?), ...
# 4      6   107886768  Fri Dec 23 06:25:10     47864\n         NaN     -96.3073065       65.838115              961           1198           85936  Sun Jan 24 03:02:09 +0000 2010  6.688683e+17     False                    NaN               NaN  1.448306e+12  @kady I'm watching River (BBC) on netflix, I t...   en         Canada              Canada 2015-11-23 19:06:55.510  2015-11-23  19:06:55.510000  ( I'm watching River (BBC) on netflix, I think...

# %% [markdown]
# Update the dataframe to store hashtag tokens and emoticans separately.

# %%
splitcol = lambda x: pd.Series([i for i in x])
text_s = dftokens['sent'].apply(splitcol)
text_s.rename(columns={0:'s_clean',1:'s_tokens',2:'s_emo',3:'s_hashtags'},inplace=True)
text_s.head()
# Out:
#                                              s_clean                                           s_tokens s_emo s_hashtags
# 0                               lemme come over bro                            [lemme, come, over, bro]  [:(]         []
# 1            I've been in a bad mood since like 2010  [i've, been, in, a, bad, mood, since, like, 2010]    []         []
# 2  what's the appropriate age for me to start act...  [what's, the, appropriate, age, for, me, to, s...    []         []
# 3           I assume your dad works at your school?)  [i, assume, your, dad, works, at, your, school...    []         []
# 4   I'm watching River (BBC) on netflix, I think ...  [i'm, watching, river, (, bbc, ), on, netflix,...    []         []

# %%
dftokens['quoted']=dftokens['quoted_text'].apply(lambda r: preprocess(r) if (len(str(r))>0) & (isinstance(r, str)) else '' )
#dftokens.take(2)
text_q = dftokens['quoted'].apply(splitcol)
text_q.rename(columns={0:'q_clean',1:'q_tokens',2:'q_emo',3:'q_hashtags'},inplace=True)

# %%
dftokens1 = pd.concat([dftokens, text_s, text_q], axis=1)
dftokens1.to_csv("raw_data/dftokens.csv", index = False, encoding='utf-8')
#dftokens.to_json("raw_data/dftokens.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-56bb40c97e27> in <module>()
# ----> 1 dftokens1 = pd.concat([dftokens, text_s, text_q], axis=1)
#       2 dftokens1.to_csv("raw_data/dftokens.csv", index = False, encoding='utf-8')
#       3 #dftokens.to_json("raw_data/dftokens.json")
#
# NameError: name 'pd' is not defined

# %%
dftokens=pd.read_csv("raw_data/dftokens.csv")
dftokens.head()
# Out:
#    index     user_id                     created_at_t quoted_text  tweet_longitude  tweet_latitude  followers_count  friends_count  statuses_count                    created_at_u      tweet_id truncated  in_reply_to_status_id  retweeted_status  timestamp_ms                                               text lang        country     place_full_name                timestamp        date             time                                               sent quoted  \
# 0      0  3095695629  Fri Dec 23 03:15:20     47864\n         NaN       -71.683502       42.036932             7424            985           36984  Thu Mar 19 01:33:34 +0000 2015  6.688683e+17     False           6.688680e+17               NaN  1.448306e+12            @DopeAhhAquarius lemme come over bro :(   en  United States  Massachusetts, USA  2015-11-23 19:06:44.120  2015-11-23  19:06:44.120000  ( lemme come over bro , [lemme, come, over, br...    NaN
# 1      1  2174756318  Fri Dec 23 03:15:38     47864\n         NaN       -71.326858       42.636248              110            159            2199  Mon Nov 04 21:06:33 +0000 2013  6.688683e+17     False                    NaN               NaN  1.448306e+12            I've been in a bad mood since like 2010   en  United States          Lowell, MA  2015-11-23 19:06:44.138  2015-11-23  19:06:44.138000  (I've been in a bad mood since like 2010, [i'v...    NaN
# 2      2   408976087  Fri Dec 23 03:57:00     47864\n         NaN       -71.088755       42.313670              514            246           37162  Thu Nov 10 03:50:52 +0000 2011  6.688683e+17     False                    NaN               NaN  1.448306e+12  what's the appropriate age for me to start act...   en  United States          Boston, MA  2015-11-23 19:06:46.620  2015-11-23  19:06:46.620000  (what's the appropriate age for me to start ac...    NaN
# 3      3  1163319366  Fri Dec 23 05:40:30     47864\n         NaN       -71.312617       42.693109              465            604           57037  Sat Feb 09 16:02:36 +0000 2013  6.688683e+17     False           6.688683e+17               NaN  1.448306e+12  @JackSillin @AlexReedWX @WesternMEwx ...I assu...   en  United States          Dracut, MA  2015-11-23 19:06:52.830  2015-11-23  19:06:52.830000  (   I assume your dad works at your school?), ...    NaN
# 4      6   107886768  Fri Dec 23 06:25:10     47864\n         NaN       -96.307306       65.838115              961           1198           85936  Sun Jan 24 03:02:09 +0000 2010  6.688683e+17     False                    NaN               NaN  1.448306e+12  @kady I'm watching River (BBC) on netflix, I t...   en         Canada              Canada  2015-11-23 19:06:55.510  2015-11-23  19:06:55.510000  ( I'm watching River (BBC) on netflix, I think...    NaN
#
#                                              s_clean                                           s_tokens s_emo s_hashtags q_clean q_tokens q_emo q_hashtags
# 0                               lemme come over bro                            [lemme, come, over, bro]  [:(]         []     NaN      NaN   NaN        NaN
# 1            I've been in a bad mood since like 2010  [i've, been, in, a, bad, mood, since, like, 2010]    []         []     NaN      NaN   NaN        NaN
# 2  what's the appropriate age for me to start act...  [what's, the, appropriate, age, for, me, to, s...    []         []     NaN      NaN   NaN        NaN
# 3           I assume your dad works at your school?)  [i, assume, your, dad, works, at, your, school...    []         []     NaN      NaN   NaN        NaN
# 4   I'm watching River (BBC) on netflix, I think ...  [i'm, watching, river, (, bbc, ), on, netflix,...    []         []     NaN      NaN   NaN        NaN

# %% [markdown]
# ##Exploratory Data Analysis

# %% [markdown]
# Nowe we first convert the dataframe into Spark, and perform some exploratory analysis.
#
# Before we move on to dive into the topic analysis, we want to first do some exploratory analyses. We create a new column called `hashtag`, which is the topic marked by the users.

# %%
import findspark
findspark.init()

import pyspark
conf = (pyspark.SparkConf()
    .setMaster('local')
    .setAppName('pyspark')
    .set("spark.executor.memory", "2g"))
sc = pyspark.SparkContext(conf=conf)

# %%
from pyspark.sql import SQLContext
sqlsc=SQLContext(sc)

# %%
dftokens_spark = sqlsc.createDataFrame(dftokens)

# %%
# dftokens_spark1 = sqlsc.read.json("raw_data/dftokens.json")
# dftokens_spark1.cache()
# print "How many tweets do we have?", dftokens_spark.count()
# Then we use printSchema to lay out the structure of the tweet data
# dftokens_spark1.printSchema()

# %%
# dftokens_spark1 = sqlsc.read.format("com.databricks.spark.csv").option("header", "true").load("raw_data/dftokens.csv")
# dftokens_spark1.take(5)

# %%
dftokens_spark.printSchema()
# Out:
# root
#  |-- index: long (nullable = true)
#  |-- user_id: long (nullable = true)
#  |-- quoted_text: double (nullable = true)
#  |-- followers_count: long (nullable = true)
#  |-- friends_count: long (nullable = true)
#  |-- statuses_count: double (nullable = true)
#  |-- created_at_u: string (nullable = true)
#  |-- created_at_t: string (nullable = true)
#  |-- tweet_id: double (nullable = true)
#  |-- truncated: boolean (nullable = true)
#  |-- in_reply_to_status_id: double (nullable = true)
#  |-- retweeted_status: double (nullable = true)
#  |-- timestamp_ms: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- place_full_name: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- sent: string (nullable = true)
#  |-- quoted: double (nullable = true)
#  |-- s_clean: string (nullable = true)
#  |-- s_tokens: string (nullable = true)
#  |-- s_emo: string (nullable = true)
#  |-- s_hashtags: string (nullable = true)
#  |-- q_clean: double (nullable = true)
#  |-- q_tokens: double (nullable = true)
#  |-- q_emo: double (nullable = true)
#  |-- q_hashtags: double (nullable = true)

# %% [markdown]
# Problem spotted: all the lists are converted to a string
#
# Solution: convert
#
# Here: try to fix the columns
# Workaround: extract the single column and use split

# %%
import ast
# def string_to_list(r):
#     return ast.literal_eval(r)
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType

string_to_list = udf(lambda r: ast.literal_eval(r), ArrayType(StringType()))

dftokens_spark1 = dftokens_spark.withColumn("s_hashtags_list", string_to_list(dftokens_spark.s_hashtags))
dftokens_spark1 = dftokens_spark1.withColumn("s_token_list", string_to_list(dftokens_spark1.s_tokens))
dftokens_spark1 = dftokens_spark1.withColumn("s_emo_list", string_to_list(dftokens_spark1.s_emo))
dftokens_spark1 = dftokens_spark1.withColumn("q_hashtags_list", string_to_list(dftokens_spark1.q_hashtags))
dftokens_spark1 = dftokens_spark1.withColumn("q_token_list", string_to_list(dftokens_spark1.q_tokens))
dftokens_spark1 = dftokens_spark1.withColumn("q_emo_list", string_to_list(dftokens_spark1.q_emo))

# %%
dftokens_spark2 = dftokens_spark.withColumn("s_emo_list", string_to_list(dftokens_spark.s_emo))

# %%
dftokens_spark2.show(10)
# Out:
# +-----+----------+-----------+---------------+-------------+--------------+--------------------+--------------------+--------------------+---------+---------------------+----------------+----------------+--------------------+----+-------------+------------------+--------------------+----------+--------------------+------+--------------------+--------------------+------+--------------------+-------+--------+-----+----------+----------+
# |index|   user_id|quoted_text|followers_count|friends_count|statuses_count|        created_at_u|        created_at_t|            tweet_id|truncated|in_reply_to_status_id|retweeted_status|    timestamp_ms|                text|lang|      country|   place_full_name|           timestamp|      date|                sent|quoted|             s_clean|            s_tokens| s_emo|          s_hashtags|q_clean|q_tokens|q_emo|q_hashtags|s_emo_list|
# +-----+----------+-----------+---------------+-------------+--------------+--------------------+--------------------+--------------------+---------+---------------------+----------------+----------------+--------------------+----+-------------+------------------+--------------------+----------+--------------------+------+--------------------+--------------------+------+--------------------+-------+--------+-----+----------+----------+
# |    0|3095695629|        NaN|           7424|          985|       36984.0|Thu Mar 19 01:33:...|Mon Nov 23 19:06:...|6.688682990409999...|    false| 6.688679847030000...|             NaN|1.44830560412E12|@DopeAhhAquarius ...|  en|United States|Massachusetts, USA|2015-11-23 19:06:...|2015-11-23|('  lemme come ov...|   NaN|  lemme come over...|['lemme', 'come',...|[':(']|                  []|    NaN|     NaN|  NaN|       NaN|      [:(]|
# |    1|2174756318|        NaN|            110|          159|        2199.0|Mon Nov 04 21:06:...|Mon Nov 23 19:06:...|    6.68868299116E17|    false|                  NaN|             NaN|1.44830560414E12|I've been in a ba...|  en|United States|        Lowell, MA|2015-11-23 19:06:...|2015-11-23|("I've been in a ...|   NaN|I've been in a ba...|["i've", 'been', ...|    []|                  []|    NaN|     NaN|  NaN|       NaN|        []|
# |    2| 408976087|        NaN|            514|          246|       37162.0|Thu Nov 10 03:50:...|Mon Nov 23 19:06:...|    6.68868309526E17|    false|                  NaN|             NaN|1.44830560662E12|what's the approp...|  en|United States|        Boston, MA|2015-11-23 19:06:...|2015-11-23|("what's the appr...|   NaN|what's the approp...|["what's", 'the',...|    []|                  []|    NaN|     NaN|  NaN|       NaN|        []|
# |    3|1163319366|        NaN|            465|          604|       57037.0|Sat Feb 09 16:02:...|Mon Nov 23 19:06:...|6.688683355729999...|    false|     6.68868264362E17|             NaN|1.44830561283E12|@JackSillin @Alex...|  en|United States|        Dracut, MA|2015-11-23 19:06:...|2015-11-23|('       I assume...|   NaN|       I assume y...|['i', 'assume', '...|    []|                  []|    NaN|     NaN|  NaN|       NaN|        []|
# |    6| 107886768|        NaN|            961|         1198|       85936.0|Sun Jan 24 03:02:...|Mon Nov 23 19:06:...|    6.68868346814E17|    false|                  NaN|             NaN|1.44830561551E12|@kady I'm watchin...|  en|       Canada|            Canada|2015-11-23 19:06:...|2015-11-23|("  I'm watching ...|   NaN|  I'm watching Ri...|["i'm", 'watching...|    []|                  []|    NaN|     NaN|  NaN|       NaN|        []|
# |    8|  24843264|        NaN|            133|          382|        1109.0|Tue Mar 17 05:06:...|Mon Nov 23 19:07:...|6.688683760729999...|    false|                  NaN|             NaN|1.44830562249E12|baby take a look ...|  en|United States|        Boston, MA|2015-11-23 19:07:...|2015-11-23|("baby take a loo...|   NaN|baby take a look ...|['baby', 'take', ...|    []|                  []|    NaN|     NaN|  NaN|       NaN|        []|
# |   10| 345494332|        NaN|           1198|          266|       83987.0|Sat Jul 30 18:00:...|Mon Nov 23 19:07:...|    6.68868398412E17|    false| 6.688682833710000...|             NaN|1.44830562781E12|@keepingupwitKIS ...|  en|United States|        Malden, MA|2015-11-23 19:07:...|2015-11-23|('  Lmfaooo I hav...|   NaN|  Lmfaooo I have ...|['lmfaooo', 'i', ...|    []|                  []|    NaN|     NaN|  NaN|       NaN|        []|
# |   12|4204521803|       null|             20|           67|         153.0|Mon Nov 16 20:40:...|Mon Nov 23 19:07:...|     6.6886840217E17|    false|                  NaN|             NaN|1.44830562871E12|No, seasons chang...|  en|United States|       Norwood, MA|2015-11-23 19:07:...|2015-11-23|("No, seasons cha...|  null|No, seasons chang...|['no', ',', 'seas...|    []|                  []|   null|    null| null|      null|        []|
# |   14|1157622540|        NaN|           1293|         1322|        1702.0|Thu Feb 07 16:40:...|Mon Nov 23 19:07:...|6.688684232670000...|    false|                  NaN|             NaN|1.44830563374E12|Have you picked o...|  en|United States|       Melrose, MA|2015-11-23 19:07:...|2015-11-23|('Have you picked...|   NaN|Have you picked o...|['have', 'you', '...|    []|['melrosema/NN', ...|    NaN|     NaN|  NaN|       NaN|        []|
# |   16| 351892410|        NaN|            215|          283|        6176.0|Tue Aug 09 21:34:...|Mon Nov 23 19:07:...|    6.68868432088E17|    false|                  NaN|             NaN|1.44830563584E12|Listen, I love ch...|  en|United States|     Braintree, MA|2015-11-23 19:07:...|2015-11-23|("Listen, I love ...|   NaN|Listen, I love ch...|['listen', ',', '...|    []|                  []|    NaN|     NaN|  NaN|       NaN|        []|
# +-----+----------+-----------+---------------+-------------+--------------+--------------------+--------------------+--------------------+---------+---------------------+----------------+----------------+--------------------+----+-------------+------------------+--------------------+----------+--------------------+------+--------------------+--------------------+------+--------------------+-------+--------+-----+----------+----------+
# only showing top 10 rows

# %%
ast.literal_eval(u"[':(', ':)']")
# Out:
# [':(', ':)']

# %%
dftokens_spark1.show(10)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-167-e28b61c23e6d> in <module>()
# ----> 1 dftokens_spark1.show(10)
#
# /usr/local/opt/apache-spark/libexec/python/pyspark/sql/dataframe.pyc in show(self, n, truncate)
#     254         +---+-----+
#     255         """
# --> 256         print(self._jdf.showString(n, truncate))
#     257
#     258     def __repr__(self):
#
# /usr/local/opt/apache-spark/libexec/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     536         answer = self.gateway_client.send_command(command)
#     537         return_value = get_return_value(answer, self.gateway_client,
# --> 538                 self.target_id, self.name)
#     539
#     540         for temp_arg in temp_args:
#
# /usr/local/opt/apache-spark/libexec/python/pyspark/sql/utils.pyc in deco(*a, **kw)
#      34     def deco(*a, **kw):
#      35         try:
# ---> 36             return f(*a, **kw)
#      37         except py4j.protocol.Py4JJavaError as e:
#      38             s = e.java_exception.toString()
#
# /usr/local/opt/apache-spark/libexec/python/lib/py4j-0.8.2.1-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     298                 raise Py4JJavaError(
#     299                     'An error occurred while calling {0}{1}{2}.\n'.
# --> 300                     format(target_id, '.', name), value)
#     301             else:
#     302                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o971.showString.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 71.0 failed 1 times, most recent failure: Lost task 0.0 in stage 71.0 (TID 65, localhost): org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/worker.py", line 111, in main
#     process()
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/worker.py", line 106, in process
#     serializer.dump_stream(func(split_index, iterator), outfile)
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/serializers.py", line 263, in dump_stream
#     vs = list(itertools.islice(iterator, batch))
#   File "/usr/local/opt/apache-spark/libexec/python/pyspark/sql/functions.py", line 1417, in <lambda>
#     func = lambda _, it: map(lambda x: returnType.toInternal(f(*x)), it)
#   File "<ipython-input-166-05c6474b851f>", line 7, in <lambda>
#   File "/Users/fqian/anaconda/lib/python2.7/ast.py", line 80, in literal_eval
#     return _convert(node_or_string)
#   File "/Users/fqian/anaconda/lib/python2.7/ast.py", line 79, in _convert
#     raise ValueError('malformed string')
# ValueError: malformed string
#
# 	at org.apache.spark.api.python.PythonRDD$$anon$1.read(PythonRDD.scala:138)
# 	at org.apache.spark.api.python.PythonRDD$$anon$1.<init>(PythonRDD.scala:179)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:97)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:66)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:88)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:214)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1145)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:615)
# 	at java.lang.Thread.run(Thread.java:745)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1280)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1268)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1267)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:47)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1267)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:697)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:697)
# 	at scala.Option.foreach(Option.scala:236)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:697)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:1493)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1455)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1444)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:567)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1813)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1826)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1839)
# 	at org.apache.spark.sql.execution.SparkPlan.executeTake(SparkPlan.scala:215)
# 	at org.apache.spark.sql.execution.Limit.executeCollect(basicOperators.scala:207)
# 	at org.apache.spark.sql.DataFrame$$anonfun$collect$1.apply(DataFrame.scala:1386)
# 	at org.apache.spark.sql.DataFrame$$anonfun$collect$1.apply(DataFrame.scala:1386)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:56)
# 	at org.apache.spark.sql.DataFrame.withNewExecutionId(DataFrame.scala:1904)
# 	at org.apache.spark.sql.DataFrame.collect(DataFrame.scala:1385)
# 	at org.apache.spark.sql.DataFrame.head(DataFrame.scala:1315)
# 	at org.apache.spark.sql.DataFrame.take(DataFrame.scala:1378)
# 	at org.apache.spark.sql.DataFrame.showString(DataFrame.scala:178)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:57)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:606)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:231)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:379)
# 	at py4j.Gateway.invoke(Gateway.java:259)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:133)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:207)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/worker.py", line 111, in main
#     process()
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/worker.py", line 106, in process
#     serializer.dump_stream(func(split_index, iterator), outfile)
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/serializers.py", line 263, in dump_stream
#     vs = list(itertools.islice(iterator, batch))
#   File "/usr/local/opt/apache-spark/libexec/python/pyspark/sql/functions.py", line 1417, in <lambda>
#     func = lambda _, it: map(lambda x: returnType.toInternal(f(*x)), it)
#   File "<ipython-input-166-05c6474b851f>", line 7, in <lambda>
#   File "/Users/fqian/anaconda/lib/python2.7/ast.py", line 80, in literal_eval
#     return _convert(node_or_string)
#   File "/Users/fqian/anaconda/lib/python2.7/ast.py", line 79, in _convert
#     raise ValueError('malformed string')
# ValueError: malformed string
#
# 	at org.apache.spark.api.python.PythonRDD$$anon$1.read(PythonRDD.scala:138)
# 	at org.apache.spark.api.python.PythonRDD$$anon$1.<init>(PythonRDD.scala:179)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:97)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:66)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:88)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:214)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1145)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:615)
# 	... 1 more

# %% [markdown]
# Extract hashtags and frequencies

# %%
hashcount=dftokens_spark1.flatMap(lambda l:l.s_hashtags_list).map(lambda h: (h.split("/")[0],1)).reduceByKey(lambda a,b: a+b)
hashcount_nonempty = hashcount.takeOrdered(100,key = lambda x: -x[1])[1:]
# hashcount=dftokens_spark.flatMap(lambda l:l.s_hashtags[1:-1].replace("'","").split(", ")).map(lambda h: (h.split("/")[0],1)).reduceByKey(lambda a,b: a+b)
# hashcount_nonempty = hashcount.takeOrdered(100,key = lambda x: -x[1])[1:]
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-149-6ec57e01cb27> in <module>()
#       1 hashcount=dftokens_spark1.flatMap(lambda l:l.s_hashtags_list).map(lambda h: (h.split("/")[0],1)).reduceByKey(lambda a,b: a+b)
# ----> 2 hashcount_nonempty = hashcount.takeOrdered(100,key = lambda x: -x[1])[1:]
#       3 # hashcount=dftokens_spark.flatMap(lambda l:l.s_hashtags[1:-1].replace("'","").split(", ")).map(lambda h: (h.split("/")[0],1)).reduceByKey(lambda a,b: a+b)
#       4 # hashcount_nonempty = hashcount.takeOrdered(100,key = lambda x: -x[1])[1:]
#
# /usr/local/opt/apache-spark/libexec/python/pyspark/rdd.pyc in takeOrdered(self, num, key)
#    1247             return heapq.nsmallest(num, a + b, key)
#    1248
# -> 1249         return self.mapPartitions(lambda it: [heapq.nsmallest(num, it, key)]).reduce(merge)
#    1250
#    1251     def take(self, num):
#
# /usr/local/opt/apache-spark/libexec/python/pyspark/rdd.pyc in reduce(self, f)
#     797             yield reduce(f, iterator, initial)
#     798
# --> 799         vals = self.mapPartitions(func).collect()
#     800         if vals:
#     801             return reduce(f, vals)
#
# /usr/local/opt/apache-spark/libexec/python/pyspark/rdd.pyc in collect(self)
#     771         """
#     772         with SCCallSiteSync(self.context) as css:
# --> 773             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     774         return list(_load_from_socket(port, self._jrdd_deserializer))
#     775
#
# /usr/local/opt/apache-spark/libexec/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     536         answer = self.gateway_client.send_command(command)
#     537         return_value = get_return_value(answer, self.gateway_client,
# --> 538                 self.target_id, self.name)
#     539
#     540         for temp_arg in temp_args:
#
# /usr/local/opt/apache-spark/libexec/python/pyspark/sql/utils.pyc in deco(*a, **kw)
#      34     def deco(*a, **kw):
#      35         try:
# ---> 36             return f(*a, **kw)
#      37         except py4j.protocol.Py4JJavaError as e:
#      38             s = e.java_exception.toString()
#
# /usr/local/opt/apache-spark/libexec/python/lib/py4j-0.8.2.1-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     298                 raise Py4JJavaError(
#     299                     'An error occurred while calling {0}{1}{2}.\n'.
# --> 300                     format(target_id, '.', name), value)
#     301             else:
#     302                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 63.0 failed 1 times, most recent failure: Lost task 0.0 in stage 63.0 (TID 58, localhost): org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/worker.py", line 111, in main
#     process()
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/worker.py", line 106, in process
#     serializer.dump_stream(func(split_index, iterator), outfile)
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/serializers.py", line 263, in dump_stream
#     vs = list(itertools.islice(iterator, batch))
#   File "/usr/local/opt/apache-spark/libexec/python/pyspark/sql/functions.py", line 1417, in <lambda>
#     func = lambda _, it: map(lambda x: returnType.toInternal(f(*x)), it)
#   File "<ipython-input-148-bd201fed4b2d>", line 7, in <lambda>
#   File "/Users/fqian/anaconda/lib/python2.7/ast.py", line 80, in literal_eval
#     return _convert(node_or_string)
#   File "/Users/fqian/anaconda/lib/python2.7/ast.py", line 79, in _convert
#     raise ValueError('malformed string')
# ValueError: malformed string
#
# 	at org.apache.spark.api.python.PythonRDD$$anon$1.read(PythonRDD.scala:138)
# 	at org.apache.spark.api.python.PythonRDD$$anon$1.<init>(PythonRDD.scala:179)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:97)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.api.python.PythonRDD$WriterThread$$anonfun$run$3.apply(PythonRDD.scala:249)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1699)
# 	at org.apache.spark.api.python.PythonRDD$WriterThread.run(PythonRDD.scala:208)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1280)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1268)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1267)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:47)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1267)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:697)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:697)
# 	at scala.Option.foreach(Option.scala:236)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:697)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:1493)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1455)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1444)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:567)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1813)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1826)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1839)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1910)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:905)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:147)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:108)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:306)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:904)
# 	at org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:373)
# 	at org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)
# 	at sun.reflect.GeneratedMethodAccessor32.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:606)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:231)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:379)
# 	at py4j.Gateway.invoke(Gateway.java:259)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:133)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:207)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/worker.py", line 111, in main
#     process()
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/worker.py", line 106, in process
#     serializer.dump_stream(func(split_index, iterator), outfile)
#   File "/usr/local/opt/apache-spark/libexec/python/lib/pyspark.zip/pyspark/serializers.py", line 263, in dump_stream
#     vs = list(itertools.islice(iterator, batch))
#   File "/usr/local/opt/apache-spark/libexec/python/pyspark/sql/functions.py", line 1417, in <lambda>
#     func = lambda _, it: map(lambda x: returnType.toInternal(f(*x)), it)
#   File "<ipython-input-148-bd201fed4b2d>", line 7, in <lambda>
#   File "/Users/fqian/anaconda/lib/python2.7/ast.py", line 80, in literal_eval
#     return _convert(node_or_string)
#   File "/Users/fqian/anaconda/lib/python2.7/ast.py", line 79, in _convert
#     raise ValueError('malformed string')
# ValueError: malformed string
#
# 	at org.apache.spark.api.python.PythonRDD$$anon$1.read(PythonRDD.scala:138)
# 	at org.apache.spark.api.python.PythonRDD$$anon$1.<init>(PythonRDD.scala:179)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:97)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:99)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:38)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:297)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:264)
# 	at org.apache.spark.api.python.PythonRDD$WriterThread$$anonfun$run$3.apply(PythonRDD.scala:249)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1699)
# 	at org.apache.spark.api.python.PythonRDD$WriterThread.run(PythonRDD.scala:208)

# %%
hashcount_plot = pd.DataFrame(hashcount_nonempty)
hashcount_plot.columns = ['hashtag', 'count']
hashcount_plot.head()

# %%
plt.figure(figsize=(15,10))  
sns.barplot(x='count', y='hashtag', data=hashcount_plot[:15], palette="Blues_d")
plt.xlabel("Count")
plt.ylabel("Hashtag")

# %%
#extract hashtags
# subdf=dftokens_spark['s_hashtags'].flatMap(lambda l:l[2])
# hashtags=subdf.map(lambda w: (w,1)).reduceByKey(lambda a,b: a+b)
# hashtags.takeOrdered(10,key = lambda x: -x[1])

# %%
print "How many tweets have hash tags?", dftokens.map(lambda l:l[4]).reduce(lambda a,b:a+b)
print "How many tweets have emoji?", dftokens.map(lambda l:l[3]).reduce(lambda a,b:a+b)
# Out:
# How many tweets have hash tags? 258
# How many tweets have emoji? 8

# %% [markdown]
# Since hashtags may contain more than one word, we do XXXX? In addition, some words may have different spellings, such as Thanksgiving v.s. thxgiving. We XXX the hashtags and find that around XXX of topics.

# %%
#clean hashtags

# %% [markdown]
# After cleaning the hashtags, we can plot the of tweets for the top XXX topics over time, and we can also compare the top XXX topics of the locals and visitors.

# %%
#plot - all tweets

# %%
#plot - by location

# %% [markdown]
# In addition, we take a look at the distribution of the users by looking at the number of its followers, friends, and statuses per year. We find out that XXXX. We define active users as users that have more than xxx followers, xx friends, or XXX statuses per year.

# %%
#identify users vs active users.

# %% [markdown]
# We also compare the topics discussed by active users v.s. less active users.

# %%
#plot - users v.s. active users.

# %% [markdown]
# One thing we need to keep in mind is that tweets are usually very short, which sometimes do not capture anything that is substantial. Thus, we compare the number of tweets at each length over time.

# %%
#tweets length analysis

# %% [markdown]
# After the exploratory analysis, we find there are XXX topics discuss during the thanksgiving period.

# %% [markdown]
# ### Natural Language processing

# %% [markdown]
# Our next step is to take the text of the tweets and process this text to extract grammar and semantic meaning from it.
#
# The tweets language is very informal, which makes parsing very hard. We made XXX. In general ,we still use the very standard sentence parsing techniques from `pattern` to help use identify noun and adjectives.
#
# **Note that many tweets have hashtags, we remove these contents and only keep texts of a tweet.**
#
# We will use a simialr function as `get_parts` from homework 5 to get the nouns of the text.

# %% [markdown]
# We create a list of what we consider punctuation below, and obtain our stopwords from the `sklearn` stopwords list.

# %%
from pattern.en import parse
from pattern.en import pprint
from pattern.vector import stem, PORTER, LEMMA
punctuation = list('.,;:!?()[]{}`''\"@#$^&*+-|=~_')

# %%
from sklearn.feature_extraction import text 
stopwords=text.ENGLISH_STOP_WORDS

# %% [markdown]
# #### Parsing language

# %% [markdown]
# We compile two regular expressions we will use. The first matched two or more dots in an ellipsis, while the second matches too or more dashes. We'll assume a single dot is a sentence separator while an single dash means a hyphenated word which is important to keep.

# %%
import re
regex1=re.compile(r"\.{2,}")
regex2=re.compile(r"\-{2,}")

# %% [markdown]
# The function get_parts below takes in an input tweet and returns a tuple of nouns and adjectives. Each member of the tuple is a list of lists. For instance the first member is a list, whose members are lists of nouns. Each such member is mined from a sentence. Some sentences will not have any representation as they dont pass the battery of conditions we impose below. Indeed if any sentence has no adjectives or no nouns we remove it. The idea eventually is to treat each such sentence as a tweet, with the nouns used to find the topic (using LDA), and the adjectives used to do sentiment analysis (via Naive Bayes).

# %% [markdown]
# `get_parts` does the following:
#
# - First we substitute anything more than two dots or two dashes by a space so the letters on either side are treated as separate words
# - Then we use pattern to parse the text into sentences. The sentences are tokenized into words, and lemmatized, which means that we convert words into their basic form, for [example](https://github.com/piskvorky/topic_modeling_tutorial/blob/master/1%20-%20Streamed%20Corpora.ipynb):
#
# > "work", "working", "works", "worked", "working" => same lemma: "work"
#
# - The words are associated with tags from the [Penn Treebank](http://www.clips.ua.ac.be/pages/mbsp-tags) in the parse process. This enables us to identify parts-of-speech.

# %%
def get_parts(thetext):
    thetext=re.sub(regex1, ' ', thetext)
    thetext=re.sub(regex2, ' ', thetext)
    nouns=[]
    descriptives=[]
    for i,sentence in enumerate(parse(thetext, tokenize=True, lemmata=True).split()):
        nouns.append([])
        descriptives.append([])
        for token in sentence:
            #print token
            if len(token[4]) >0:
                if token[1] in ['JJ', 'JJR', 'JJS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    descriptives[i].append(token[4])
                elif token[1] in ['NN', 'NNS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    nouns[i].append(token[4])
    out=zip(nouns, descriptives)
    nouns2=[]
    descriptives2=[]
    for n,d in out:
        if len(n)!=0 and len(d)!=0:
            nouns2.append(n)
            descriptives2.append(d)
    return nouns2, descriptives2

# %% [markdown]
# #### Run `get_parts` on the `text` column of the dataframe

# %%
tweet_parts = dftokens_spark.map(lambda x: get_parts(x.text))

# %% [markdown]
# We'll take the first three to see what our code looks like.

# %%
tweet_parts.take(3)
# Out:
# [([], []),
#  ([[u'mood']], [[u'bad']]),
#  ([[u'age', u'adult']], [[u'appropriate']])]

# %% [markdown]
# We use collect to collect in a python list all of our results.

# %%
# %%time
parseout=tweet_parts.collect()
# Out:
# CPU times: user 950 ms, sys: 312 ms, total: 1.26 s
# Wall time: 7min 2s

# %% [markdown]
# ##Topic Analysis

# %% [markdown]
# We applied two methods to analyze topics.
#
# 1. LDA
# 2. k-nearest term (lab 8)
#
# Since XXX tweets have a length that is shorter than XXX, we decide to ????

# %% [markdown]
# We want to find out what a particular sentence of a tweet talks about. We look at the nouns of the sentence to do this. The nouns are the first elements of all the tuples we created. We flatten the outer list which holds all the lists corresponding to one given tweet out, because we now want to treat each accepted sentence in a tweet as a separate mini-tweet.

# %% [markdown]
# The generative model for LDA is one in which a document comes from a mixture of topics. Each topic can be thought of as a cluster. We need some data which has very clear and strong cluster membership to clearly delineate the clusters. Thus we need to treat the text at a granularity where at-least some sentences have strong cluster membership. For a tweet, for example, some sentences may talk only about thanksgiving food, and some sentences may talk only about shopping, and its important to have these so that the topics (clusters) can be clearly established. Thus a sentence is a reasonable granularity, while a paragraph may be too big.
#
# We use Spark's `flatMap` to do this.

# %%
ldadatardd=sc.parallelize([ele[0] for ele in parseout]).flatMap(lambda l: l)
ldadatardd.cache()
ldadatardd.take(5)
# Out:
# [[u'mood'], [u'age', u'adult'], [u'netflix'], [u'bit', u'amp'], [u'goody']]

# %% [markdown]
# #### Creating the vocabulary

# %% [markdown]
# We have a set of "documents" for the LDA, each corresponding to the nouns in a sentence in all the tweets, lets go about compiling the complete vocabulary that these documents use. We need to do this so that we can set up the documents in the form of a corpus, where each document is a sparse vector of the size of the vocabulary, with a number in the slot for the word indicating how many times that word appeared in a document.
# So the first thing we want to do is to collect all the words. One more flattening does the job but will have duplicates

# %%
ldadatardd.flatMap(lambda word: word).take(15)
# Out:
# [u'mood',
#  u'age',
#  u'adult',
#  u'netflix',
#  u'bit',
#  u'amp',
#  u'goody',
#  u'order',
#  u'cheese',
#  u'pizza',
#  u'friend',
#  u'cop',
#  u'job',
#  u'movie',
#  u'hotel']

# %% [markdown]
# Then, in the usual word-count style we reduce to get the word numbers and then just drop these numbers as we dont care for them. We zipWithIndex the words to give them an index which we'll use as the place index in the corpus vector.

# %%
vocabtups = (ldadatardd.flatMap(lambda word: word)
             .map(lambda word: (word, 1))
             .reduceByKey(lambda a, b: a + b)
             .map(lambda (x,y): x)
             .zipWithIndex()
).cache()

# %% [markdown]
# We use Spark's collectAsMap to output the vocabulary vocab with the words as keys. We also use map to invert this dictionary and get id2word which maps the index to the word. This dictionary is then used by Gensim.

# %%
vocab=vocabtups.collectAsMap()
id2word=vocabtups.map(lambda (x,y): (y,x)).collectAsMap()

# %% [markdown]
# The size of our vocabulary:

# %%
len(vocab.keys())
# Out:
# 25738

# %% [markdown]
# ### Create a Corpus in bag of words form

# %% [markdown]
# Now we create the lazy RDD `documents`.  `documents`  will be a list of lists that reflects the entire set of sentences. Each one of the member lists consists of a set of tuples `(index, count)` where `index` is the index of the corresponding word in the vocabulary and `count` is the number of times it occured in the sentence.
#
# `documents` will look something like:
#
# ```
# [[(5912, 1), (3809, 1), (14131, 1), (3876, 1)],
# [(3266, 1), (3652, 1), (11644, 1), (2296, 1), (27516, 1), (8382, 1)],
#  [(17217, 1), (22979, 1), (11210, 1), (18736, 1), (3893, 1), (21307, 1)],
#  ...,
#  [(23980, 1), (24730, 1), (22979, 1), (20012, 1), (11206, 2)]]
# ```

# %%
from collections import defaultdict
def constructDict(wordlist):
    result = defaultdict(int)
    for word in wordlist:
        result[word] += 1
    return list(result.iteritems())

documents = ldadatardd.map(lambda x: [vocab[i] for i in x]).map(lambda x: constructDict(x))

# %% [markdown]
# We `collect` and store in the variable `corpus`.

# %%
corpus=documents.collect()

# %% [markdown]
# ### Unsupervised topic extraction with LDA

# %% [markdown]
# We now run the LDA algorithm on the nouns only. The nouns typically reflect the themes of a tweet sentence and including other parts of speech adds noise.
#
# We'll explore different number of topics, since the tweets are collected without theme bias, and they should intuitivly belong to different topics. However, out wish is there are at least two specific kind of topics generated: *thanksgiving reunion* and *thanksgiving shopping*, since the data is collected before, during and after thanksgiving holidays and it is our intuition to study thanksgiving's influence on tweets. Of course there will be some mixing and such. The decision is rarely ever completely clean.
#
# Remember that LDA is an unsupervised algorithm, so there is no "performance" to measure. But we would like the two clusters we are looking for to correspond to our intuition that one should cover the thanksgiving reunion (including food) and one the another qualities of the shopping. Or something similar.
#
# But again remember that there is no reason that this intuition is correct. Since these clusters are "latent" factors. But if they do coincide with topics/classes/clusters in our data, LDA is more useful.
#
# We run LDA using a method called "variational inference", which can be updated online. We run it in chunks of 20,000 documents, hoping that topics have converged by then. This makes subsequent training faster.

# %% [markdown]
# #### Carry out LDA

# %% [markdown]
# #### 1. number of topics = 2

# %%
import gensim
lda2 = gensim.models.ldamodel.LdaModel(corpus = corpus, id2word = id2word, num_topics = 5, update_every=1, chunksize=20000, passes=1)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy

# %% [markdown]
# #### Interpret the topics you get with LDA

# %%
lda2.print_topics()
# Out:
# [(0,
#   u'0.043*amp + 0.034*today + 0.023*person + 0.017*friend + 0.016*way + 0.014*gt + 0.012*game + 0.011*girl + 0.010*day + 0.008*school'),
#  (1,
#   u'0.053*fit + 0.042*job + 0.034*sale + 0.024*thank + 0.024*shit + 0.020*year + 0.014*team + 0.013*love + 0.008*work + 0.006*song'),
#  (2,
#   u'0.122*job + 0.039*time + 0.029*click + 0.021*life + 0.019*guy + 0.010*amp + 0.009*ass + 0.009*family + 0.008*person + 0.007*boy'),
#  (3,
#   u'0.036*day + 0.019*home + 0.017*man + 0.017*night + 0.010*bitch + 0.009*nigga + 0.007*movie + 0.007*game + 0.006*house + 0.006*video'),
#  (4,
#   u'0.022*thing + 0.017*thanksgiving + 0.011*birthday + 0.010*tonight + 0.009*week + 0.008*person + 0.007*game + 0.007*tho + 0.007*year + 0.006*sister')]

# %%
for bow in corpus[0:900:15]:
    print bow
    print lda2.get_document_topics(bow)
    print " ".join([id2word[e[0]] for e in bow])
    print "=========================================="
# Out:
# [(5472, 1)]
# [(0, 0.59969727549977081), (1, 0.10003550539828936), (2, 0.10004772642913838), (3, 0.10020793126841744), (4, 0.10001156140438401)]
# mood
# ==========================================
# [(22974, 1), (23787, 1), (23205, 1), (15246, 1), (24511, 1)]
# [(0, 0.69355508317683945), (1, 0.033498720782898214), (2, 0.035087984878939535), (3, 0.20392893284998975), (4, 0.033929278311333008)]
# soup dad mom nana chicken
# ==========================================
# [(3136, 1), (12064, 1), (15267, 1), (18096, 1)]
# [(0, 0.55340196802884534), (1, 0.32458982771448514), (2, 0.041162415545078969), (3, 0.040426902562371123), (4, 0.040418886149219492)]
# men woman family days-sec
# ==========================================
# [(19666, 1)]
# [(0, 0.59957839179361327), (1, 0.10010260152301874), (2, 0.10010296227581844), (3, 0.10010558797801589), (4, 0.10011045642953376)]
# t_is_superman
# ==========================================
# [(5984, 1), (8227, 1), (10461, 1), (2271, 1)]
# [(0, 0.46612585857131517), (1, 0.042927080141974258), (2, 0.41063622777459524), (3, 0.040198006522002373), (4, 0.04011282699011294)]
# folk rail transit amp
# ==========================================
# [(23002, 1), (10309, 1)]
# [(0, 0.2811383946426938), (1, 0.51814340556969052), (2, 0.066896180115276413), (3, 0.066928342814450051), (4, 0.066893676857889231)]
# thank espnly
# ==========================================
# [(6598, 1), (19594, 1), (22091, 1), (19639, 1), (22712, 1), (2169, 1), (10910, 1)]
# [(0, 0.025150289525139757), (1, 0.17261002305727549), (2, 0.076945427425351334), (3, 0.7000293783702799), (4, 0.025264881621953533)]
# life prison cell pustule ignorance inside contempt
# ==========================================
# [(6188, 1)]
# [(0, 0.10000500715930878), (1, 0.10124760023655244), (2, 0.59867950403534109), (3, 0.10000373560236353), (4, 0.10006415296643409)]
# job
# ==========================================
# [(17846, 1)]
# [(0, 0.10007046374281688), (1, 0.10001797788657762), (2, 0.59988379082900534), (3, 0.1000129663375699), (4, 0.10001480120403032)]
# report
# ==========================================
# [(7252, 1), (3211, 1), (14236, 1)]
# [(0, 0.050057432782338332), (1, 0.050065177816978175), (2, 0.79974229517137452), (3, 0.050065449368213187), (4, 0.050069644861095872)]
# darling msbreezydoesit iamerikestrada
# ==========================================
# [(3947, 1), (6188, 1), (2093, 1)]
# [(0, 0.05186376179028291), (1, 0.050570890673519782), (2, 0.79554655119964646), (3, 0.0511463423069679), (4, 0.050872454029582966)]
# hour job person
# ==========================================
# [(14475, 1)]
# [(0, 0.1001178103462622), (1, 0.10005697384202011), (2, 0.1000998097522033), (3, 0.10002626691844287), (4, 0.59969913914107142)]
# interview
# ==========================================
# [(17846, 1)]
# [(0, 0.10007050943150343), (1, 0.10001797885561911), (2, 0.59988374257618537), (3, 0.10001296710277147), (4, 0.10001480203392069)]
# report
# ==========================================
# [(14570, 1)]
# [(0, 0.10020349113549985), (1, 0.10022938660934608), (2, 0.1002268585660209), (3, 0.10023185443678456), (4, 0.59910840925234865)]
# ellekingmusic
# ==========================================
# [(15528, 1), (23585, 1), (17638, 1), (5198, 1), (22519, 1)]
# [(0, 0.64695263731886399), (1, 0.033361424635559252), (2, 0.033364737504002678), (3, 0.033463496953754009), (4, 0.25285770358782006)]
# game bit methink touchdown ððð
# ==========================================
# [(2271, 1), (13156, 1), (7383, 1), (3039, 1)]
# [(0, 0.19446530515606825), (1, 0.4594411414471809), (2, 0.040922110548024568), (3, 0.26488949992783717), (4, 0.040281942920889192)]
# amp support community home
# ==========================================
# [(16744, 1)]
# [(0, 0.59604572095217445), (1, 0.10392427691467274), (2, 0.1000100299782101), (3, 0.10000942769846494), (4, 0.10001054445647779)]
# parody
# ==========================================
# [(23029, 1)]
# [(0, 0.5985772824287442), (1, 0.10045939358585433), (2, 0.10036193205655473), (3, 0.10007521897890879), (4, 0.1005261729499379)]
# girl
# ==========================================
# [(94, 1)]
# [(0, 0.10000333318270413), (1, 0.59997504893937437), (2, 0.1000057871772316), (3, 0.1000002204827326), (4, 0.10001561021795734)]
# fit
# ==========================================
# [(17811, 1)]
# [(0, 0.10036959925057713), (1, 0.10224493748442852), (2, 0.59453101901110095), (3, 0.10267821190976134), (4, 0.10017623234413212)]
# snow
# ==========================================
# [(3585, 1), (14953, 1)]
# [(0, 0.06689168342113723), (1, 0.7328924879246711), (2, 0.066695733579316172), (3, 0.06680237892271354), (4, 0.066717716152162029)]
# fuck album
# ==========================================
# [(24657, 1), (16283, 1), (9069, 1), (17223, 1)]
# [(0, 0.042746819654705753), (1, 0.83185063953395644), (2, 0.042907314491299406), (3, 0.041242974897486899), (4, 0.041252251422551484)]
# season website wait lesson
# ==========================================
# [(24928, 2), (23798, 1), (3039, 1)]
# [(0, 0.45121806528453823), (1, 0.040015495254182507), (2, 0.040011206047737835), (3, 0.4285967099975978), (4, 0.040158523415943635)]
# anniversary day home
# ==========================================
# [(22457, 1), (16098, 1), (15074, 1), (8662, 1)]
# [(0, 0.25923057924971649), (1, 0.044317096797870534), (2, 0.040180025118703472), (3, 0.040751322101942759), (4, 0.61552097673176676)]
# piece president bernie2016 shit
# ==========================================
# [(20145, 1), (24275, 1), (23933, 1), (10022, 1)]
# [(0, 0.25585593659272521), (1, 0.42404846510327321), (2, 0.04081753943336263), (3, 0.040494489246064393), (4, 0.23878356962457453)]
# emission ray appearance skin
# ==========================================
# [(13039, 1), (12000, 1), (5207, 1), (20676, 1), (11687, 1)]
# [(0, 0.86648611900055794), (1, 0.033361958380517129), (2, 0.03342469184242803), (3, 0.033364066682112205), (4, 0.033363164094384841)]
# debt lplconf today society financialindependance
# ==========================================
# [(18204, 1)]
# [(0, 0.10021734558176391), (1, 0.10024701719748857), (2, 0.59902605818348942), (3, 0.100246473816255), (4, 0.10026310522100318)]
# district
# ==========================================
# [(15345, 1)]
# [(0, 0.59653369928017363), (1, 0.10002567327345818), (2, 0.10005273080986984), (3, 0.10027891736543811), (4, 0.10310897927106018)]
# issue
# ==========================================
# [(1943, 1)]
# [(0, 0.10012712402788626), (1, 0.10002455323220498), (2, 0.59978044375585016), (3, 0.10005030576936021), (4, 0.10001757321469835)]
# guy
# ==========================================
# [(9689, 1), (23002, 1), (6778, 1)]
# [(0, 0.050073764294430716), (1, 0.79976399609186821), (2, 0.050142772207441545), (3, 0.050017167981033117), (4, 0.05000229942522625)]
# justinbieber thank love
# ==========================================
# [(8672, 1), (22457, 1), (16093, 1)]
# [(0, 0.050213334639997845), (1, 0.33158383388302137), (2, 0.050220797766513788), (3, 0.051964237237946166), (4, 0.51601779647252077)]
# tradition piece minority
# ==========================================
# [(17486, 1), (21263, 1)]
# [(0, 0.068369680151029275), (1, 0.40893466362737191), (2, 0.066816424147325484), (3, 0.38899213412239159), (4, 0.06688709795188176)]
# 1:40 pls
# ==========================================
# [(4964, 1), (10444, 1), (10489, 1), (22392, 1), (21785, 1), (7903, 1)]
# [(0, 0.028609764904995432), (1, 0.028614997179857129), (2, 0.88553954019191539), (3, 0.028617693907569377), (4, 0.028618003815662676)]
# leoljwatson stemple deh ooman kayakin1 angelawalters01
# ==========================================
# [(24140, 1), (2087, 1)]
# [(0, 0.066667373770475977), (1, 0.066667465487474875), (2, 0.7333286068415531), (3, 0.066669033734063576), (4, 0.066667520166432348)]
# muse ð
# ==========================================
# [(3202, 1), (19363, 1), (1158, 1), (14279, 1), (10413, 1), (11230, 1), (6555, 1), (4989, 1), (3518, 1)]
# [(0, 0.020589151927018413), (1, 0.15655262426404343), (2, 0.58710097130544658), (3, 0.080768921783163528), (4, 0.15498833072032808)]
# crew preparation beverage drink kick-ass â¦ menu veggiegalaxy round
# ==========================================
# [(18594, 1)]
# [(0, 0.10000141849831967), (1, 0.59765544002820659), (2, 0.10122193059831622), (3, 0.10000882106689471), (4, 0.10111238980826284)]
# friendship
# ==========================================
# [(10010, 1), (22189, 1)]
# [(0, 0.3653018667284067), (1, 0.066790436560154182), (2, 0.066788916750250935), (3, 0.06687476701285773), (4, 0.43424401294833048)]
# diet 24-year-old
# ==========================================
# [(23836, 1)]
# [(0, 0.10012973474932869), (1, 0.10001473556477679), (2, 0.59936467135037974), (3, 0.10028655447661024), (4, 0.10020430385890446)]
# time
# ==========================================
# [(24657, 1), (6757, 1)]
# [(0, 0.32132587624941422), (1, 0.47476329121994537), (2, 0.06746064394199057), (3, 0.067920867197265034), (4, 0.068529321391384776)]
# season team
# ==========================================
# [(2271, 1), (1653, 1), (14479, 1)]
# [(0, 0.30686696498565924), (1, 0.050441447234443798), (2, 0.050386388427531972), (3, 0.54210955246959924), (4, 0.050195646882765885)]
# amp coffee pizza
# ==========================================
# [(5516, 1), (2093, 1)]
# [(0, 0.070365117977944813), (1, 0.06772878808446979), (2, 0.067695451991023045), (3, 0.067394412672101917), (4, 0.72681622927446055)]
# deserve person
# ==========================================
# [(15528, 1), (23138, 1), (8471, 1)]
# [(0, 0.051559901758531264), (1, 0.050156015111584261), (2, 0.29912397511920596), (3, 0.54827622622505845), (4, 0.050883881785620241)]
# game xbone haircut
# ==========================================
# [(7242, 1)]
# [(0, 0.10118269952377953), (1, 0.10015704551029518), (2, 0.10014058292675039), (3, 0.10112721787634001), (4, 0.59739245416283482)]
# week
# ==========================================
# [(17777, 1), (7195, 1)]
# [(0, 0.066853943099329308), (1, 0.067068136863639952), (2, 0.42118194564892303), (3, 0.066675363413892866), (4, 0.37822061097421478)]
# rant sense
# ==========================================
# [(23785, 1), (829, 1), (24041, 1), (18461, 1), (1273, 1)]
# [(0, 0.2380529124359958), (1, 0.035640415737366343), (2, 0.42064780371427873), (3, 0.033468720815206666), (4, 0.27219014729715246)]
# labor company brand apparel shortage
# ==========================================
# [(6188, 1)]
# [(0, 0.10000500732884438), (1, 0.10124853204276323), (2, 0.59867856966917776), (3, 0.10000373572873333), (4, 0.10006415523048119)]
# job
# ==========================================
# [(20284, 1), (4919, 1)]
# [(0, 0.38944902719269298), (1, 0.06677658605296681), (2, 0.066724072870610121), (3, 0.40981252854503358), (4, 0.067237785338696468)]
# ð bridge
# ==========================================
# [(14882, 1), (14779, 1), (24301, 1), (25422, 1)]
# [(0, 0.041349005198040342), (1, 0.83691616525455115), (2, 0.041168499236093274), (3, 0.04003556181420611), (4, 0.040530768497109237)]
# car wap queen trap
# ==========================================
# [(8212, 1)]
# [(0, 0.10002161104313838), (1, 0.10005165517306208), (2, 0.10025068311018376), (3, 0.1000360670903189), (4, 0.59963998358329695)]
# voice
# ==========================================
# [(16601, 2)]
# [(0, 0.066699634733623128), (1, 0.066672010621188091), (2, 0.067241805949681197), (3, 0.0667627978746579), (4, 0.73262375082084974)]
# thing
# ==========================================
# [(18953, 1), (15330, 1), (15324, 1), (23205, 1), (2271, 2)]
# [(0, 0.73605257171219041), (1, 0.17790537367682982), (2, 0.028654979469784372), (3, 0.028744374380340332), (4, 0.028642700760855015)]
# sis yr ya mom amp
# ==========================================
# [(23443, 1)]
# [(0, 0.10005175017633161), (1, 0.59994488038677107), (2, 0.10000111681773066), (3, 0.10000109433797048), (4, 0.10000115828119624)]
# youth
# ==========================================
# [(23798, 1), (1943, 1)]
# [(0, 0.067421182305166125), (1, 0.066732601782279341), (2, 0.39519810114045628), (3, 0.40388924752456201), (4, 0.066758867247536199)]
# day guy
# ==========================================
# [(6188, 1)]
# [(0, 0.10000500988286543), (1, 0.10126262440512325), (2, 0.59866443880398834), (3, 0.10000373763254011), (4, 0.10006418927548291)]
# job
# ==========================================
# [(16744, 1)]
# [(0, 0.59603458770642892), (1, 0.10393540651628633), (2, 0.10001003119647814), (3, 0.10000942884340971), (4, 0.10001054573739698)]
# parody
# ==========================================
# [(23798, 1), (2511, 1)]
# [(0, 0.72735075816385786), (1, 0.06682211763035277), (2, 0.06674653707299473), (3, 0.07220410389054735), (4, 0.066876483242247403)]
# day ð³ð¢ð§ð©
# ==========================================
# [(232, 1), (16496, 1), (16995, 1), (10277, 1)]
# [(0, 0.34016484269621328), (1, 0.35349713579809466), (2, 0.04029065783255837), (3, 0.040085830319092519), (4, 0.22596153335404118)]
# nature dude hard freak
# ==========================================
# [(2010, 2), (6188, 1), (9230, 1)]
# [(0, 0.040004151744767992), (1, 0.040109962776304367), (2, 0.83987965456148239), (3, 0.040000433388619756), (4, 0.040005797528825375)]
# dialysis job click
# ==========================================
# [(2154, 1), (7587, 1), (5207, 1)]
# [(0, 0.55635088598189419), (1, 0.05003212236785623), (2, 0.050028185189724544), (3, 0.050018599455776795), (4, 0.29357020700474823)]
# stair leg today
# ==========================================
# [(24458, 1), (8698, 1)]
# [(0, 0.066700806013425054), (1, 0.066680905920940642), (2, 0.46990705216027701), (3, 0.32990314484802341), (4, 0.066808091057333763)]
# tip lady
# ==========================================

# %% [markdown]
# ##Comparing the topic with hashtags

# %% [markdown]
# Discuss the results of two topic analysis, and then compare the results with the one we get from simply using hash tags.
#
# e.g. plot charts we did for exploratory analysis.

# %% [markdown]
# ##Sentiment Analysis
#
# We want to analyze the sentiment of each tweet. However, it is not an easy task. In genearl, there are three approaches that we can measure the sentiment:
#
# 1. identify words used in a tweet that are positive or negative, and then compute the ratio of positive words to total number of opinioned words.
#
# 2. manually label a set of tweets, and conduct supervised machine learning algorithims, such as KNN or Naive Bayes classifiers.
#
# 3. use existent sentiment analysis packages, such as `sentiment` from `pattern`.
#
# Each approach has its pros and cons. The first approach is straight forward but may only achieve relative low accuracy. The second approach may impove the accuracy, but it requires us to go through a fair amount of tweets and decide whether they are positive or negative. The accuracy relies on how well these tweets are classified, which is not an easy tasks and requires expertise in linguistics. The third approach is the easiest. However, we cannot tune parameters, and we do not know whether the mechanics behind works well for tweets, which are quite different from formal languages.
#
# Constrained by the amount of time we have, we decide to start with first approach and then compare its result with the result of third approach.
# Each approach has its pros and cons. The first approach is straight forward but may only achieve relative low accuracy. The secoEach approach has its pros and cons. The first approach is straight forward but may only achieve relative low accuracy. The second approach may impove the accuracy, but it requires us to go through a fair amount of tweets and decide whether they are positive or negative. The accuracy relies on how well these tweets are classified, which is not an easy tasks and requires expertise in linguistics. The third approach is the easiest. However, we cannot tune parameters, and we do not know whether the mechanics behind works well for tweets, which are quite different from formal languages.

# %% [markdown]
# ###1. Word Match
#
# We find a list of positive and negative words that have been used in many opinion mining and senitment analysis [papers](https://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html#datasets).
#
# The list of positive and negative words has around 6800 words and is quite comprehensive.

# %%
import nltk;
from nltk.stem.snowball import SnowballStemmer;
stemmer = SnowballStemmer("english");

# %%
#reading in positive words
f = open('raw_data/positive-words.txt','r');
poslist = set([]);
for line in f:
    line = line.strip();
    # print "Original: %s" %(line);
    line = stemmer.stem(line);
    # print "After Stemming: %s" %(line);
    poslist |= set([line]);
f.close;

# %%
#reading in negative words
neglist = set([]);
f = open('raw_data/negative-words.txt','r');
for line in f:
    line = line.strip();
    #print "Original: %s" %(line);
    line = stemmer.stem(line);
    # print "After Stemming: %s" %(line);
    neglist |= set([line]);
f.close;

# %% [markdown]
# We use the `SnowballStemmer` method from `nltk` package to find sterm of a word.
#
# Then, we match the sterm of words in a tweet with words in negative or positive word list, and calculate the occurence of positive and negative words. If there is a positive word, then we add 1 to sentiment value of the tweet. If there is a negative word, then we substract 1 from total value. At the end, we compute the ratio of sentiment value to total occurences of positive or negative words as the sentiment of the tweet. Thus, the sentiment of a tweet range from -1 to 1.
#
# If a tweet does not have any matched positive or negative words, we assume it is neutral and will get a 0 value.

# %%
#https://github.com/ravikiranj/twitter-sentiment-analyzer/blob/master/simpleDemo.py

#people sometimes like to type a word with a lot of repetitions.
def replaceTwoOrMore(s):
    #look for 2 or more repetitions of character
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL) 
    return pattern.sub(r"\1\1", s)

# %%
"""
Function
--------
wordmatch

match tokens of a tweet with positive or negative words, and 
calculate the sentiment of the tweet.

Parameters
----------
textlist : a list of tokens of a tweet.

Output
----------
a list of reformatted hashtags
"""

def wordmatch(tokenlist,pos,neg):
    tokens= tokenlist[1:-1].replace("'","").split(", ")
    tokens = [replaceTwoOrMore(word) for word in tokens];
    tokens = [word.strip("#") for word in tokens if word not in stopwords];
    tokens = [stemmer.stem(word.decode('utf-8')) for word in tokens if word not in punctuation];
    pos_count = [1 for word in tokens if word in pos];
    neg_count = [-1 for word in tokens if word in neg];
    count=len(pos_count)+len(neg_count)
    total=np.float(np.sum(pos_count)+np.sum(neg_count))
    if count == 0.0:
        return 0
    else:
        return total/count

# %%
subdftokens=dftokens[['user_id','timestamp','s_clean','s_tokens','s_emo','q_clean','q_tokens','q_emo']]
senti=subdftokens.apply(lambda r:wordmatch(r.s_tokens,poslist,neglist),axis=1)
#subdftokens['s_senti']=subdftokens['s_tokens'].apply(lambda r:wordmatch(r,poslist2,neglist2))

# %%
plt.hist(senti)
# Out:
# (array([ 20790.,     76.,   1170.,   3386.,    585.,  50186.,   5594.,
#           1838.,    880.,  53891.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# It seems that roughly half of the tweets are positive and half of them are neutral.
#
# However, is the positive or negative words list enough for tweets sentimental analysis?
#
# Not necessarily. Twitter language is like text message, and people tend to use abbreviations. We found a list of common abbreviations on this [website](http://www.illumasolutions.com/omg-plz-lol-idk-idc-btw-brb-jk.htm). Then, we pick some common abbreviations that indicate one's emotions/attitude, and add them to our positive and negative words list.

# %%
#positive abbreviations
textlangpos =['lol','lmao','lmfao','tff','rofl']
#negative abbreviations
textlangneg = ['stfu','pita','eol']

poslist2=poslist.union(textlangpos)
neglist2=neglist.union(textlangneg)

# %%
senti2=subdftokens.apply(lambda r:wordmatch(r.s_tokens,poslist2,neglist2),axis=1)
plt.hist(senti2)
# Out:
# (array([ 20198.,     77.,   1170.,   3420.,    598.,  49380.,   5809.,
#           1912.,    920.,  54912.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <a list of 10 Patch objects>)

# %%
print "Total Sentiment Shift:",np.sum(senti2-senti)
print "Average Sentiment Shift:",np.mean(senti2-senti)
# Out:
# Total Sentiment Shift: 1728.05
# Average Sentiment Shift: 0.0124862712795

# %%
subdftokens['s_senti']=subdftokens['s_tokens'].apply(lambda r:wordmatch(r,poslist2,neglist2))
# Out:
# /Users/Jing/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# Take a look at some tweets and their estimated sentiment. We did a good job for simple tweets, such as 'happy birthday brotha #osuforlife'. However, when a tweet has both positive and negative words, `wordmatch` did poorly. For example, the tweet, "It's very hard for me to trust on people's words," gets a sentiment value of 0.
#
# At the same time, we also notice that we was not able to take out all the emoticons.

# %%
subdftokens[['s_clean','s_senti','s_emo']]
# Out:
#                                                   s_clean   s_senti s_emo
# 0                                    lemme come over bro   1.000000  [:(]
# 1                 I've been in a bad mood since like 2010  0.000000    []
# 2       what's the appropriate age for me to start act...  1.000000    []
# 3                I assume your dad works at your school?)  1.000000    []
# 4        I'm watching River (BBC) on netflix, I think ...  0.000000    []
# 5                    baby take a look at what you've done  0.000000    []
# 6       LOUDLY CRYING FACE.FACE WITH TEARS OF JOY. Lmf... -0.333333    []
# 7                       No, seasons change, people don't   1.000000    []
# 8       Have you picked out your #ThanksgivingWine?\n ...  1.000000    []
# 9       Listen, I love cheese. I do. But if you order ...  0.600000    []
# 10      #Construction #Job alert: Senior Construction ...  1.000000    []
# 11         Ok. Between classes And when done an assign...  1.000000    []
# 12      You can keep going forever on , says  #jo304 n...  0.000000    []
# 13      #ChestnutHill, MA #Hospitality #Job: Baker - N...  1.000000    []
# 14      Can you recommend anyone for this #job? Senior...  1.000000    []
# 15      They're filming  new Ben Affleck movie 'Live b...  1.000000    []
# 16       WHERE DID U TAKE THIS WHERE CAN WE SEE IT I N...  1.000000    []
# 17      Asking for cats for christmas. especially this...  0.000000    []
# 18       glow 'Champagne Pop'  blush in 'Blissful'  di...  0.333333    []
# 19      Nat'l Family Caregivers Month is most importan...  1.000000    []
# 20      It's never too cold for Ron's! Stop in for a c...  0.500000    []
# 21      Listen &amp; Share my new track 'POOR MILLIONA... -1.000000    []
# 22       F*ck the police coming straight from the unde...  0.000000    []
# 23      A thoughtful conservative response to last wee...  0.200000    []
# 24      When friends got your back when you're at the ...  1.000000    []
# 25      We're #hiring! Click to apply: Project Manager...  1.000000    []
# 26         I also tweet, etc. at lunch, and if I have ...  0.000000    []
# 27      PANDA FACE.CHIPMUNK.40 degrees &amp; still hot...  1.000000    []
# 28      FACE WITH TEARS OF JOY.I get sick so my mom, m...  0.000000    []
# 29         Lunching with Robinson Ladies! @ Soall Bistro   0.000000    []
# ...                                                   ...       ...   ...
# 138366  Interested in a #Healthcare #job near #Beverly...  1.000000    []
# 138367  Find your peace, please.  I'm living a life of...  1.000000    []
# 138368   It's very hard for me to trust on people's words  0.000000    []
# 138369  FACE WITH TEARS OF JOY. and  nana likes me bet...  1.000000    []
# 138370   U shld watch theHistory channel; u'd b amazed...  0.500000    []
# 138371  I drunkenly bought a washer and dryer online t...  0.000000    []
# 138372  My response to "I have no idea what I'm doing ...  1.000000    []
# 138373  Join the Macy's Retail team! See our latest #S...  1.000000    []
# 138374                "Please, no more pictures, hailey"   0.000000    []
# 138375                  happy birthday brotha #osuforlife  1.000000    []
# 138376  FACE WITH ROLLING EYES.I have dish room this w...  0.000000    []
# 138377  I Just had Lunch at Teranga restaurant a the c...  1.000000    []
# 138378  What a great day back at Baker! Reminder: Tues...  1.000000    []
# 138379  RAINBOW.SUN BEHIND CLOUD.50 shades of zill,️, ...  0.000000    []
# 138380  Basically my sneeze if it were more high pitched   0.000000    []
# 138381  Help Desk/ Desktop Analyst- Frisco, TX - Kelly...  1.000000    []
# 138382  BOTTLE WITH POPPING CORK.EMOJI MODIFIER FITZPA...  1.000000    []
# 138383  Every month I look forward to receiving a chai...  0.000000    []
# 138384  We're #hiring! Click to apply: Seasonal - Logi...  1.000000    []
# 138385         when we realized we have the bio project    1.000000    []
# 138386  BASKETBALL AND HOOP.Sending best wishes to all...  1.000000    []
# 138387                      SKULL.Eberg is so fucked up , -1.000000    []
# 138388  HUNDRED POINTS SYMBOL.Just cause she'll suck y... -0.200000    []
# 138389  Can you recommend anyone for this #Retail #job...  1.000000    []
# 138390  Join the Fresenius Medical Care team! See our ...  1.000000    []
# 138391      just learned that Tuva is a country. #college  1.000000    []
# 138392  Send boy here. People i know will take care of...  0.000000    []
# 138393   well i noticed that Twitter was asking me if ...  0.000000    []
# 138394  We're #hiring! Read about our latest #job open...  1.000000    []
# 138395                                    Well now a days  0.000000    []
#
# [138396 rows x 3 columns]

# %% [markdown]
# ####Comparing Sentiment Results with Emoji used in Text
#
# Since people use emoticons to express their emotions, we decide to conduct a sentiment analysis on emoticons as well

# %%
#define the emoticons that represent positive, negative, and neutral emotions.

pos_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]] # Mouth
    )"""

neg_str =r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [\(\[] # Mouth
    )"""

neutral_str =r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [/\\OpP] # Mouth
    )"""


neutral_re= re.compile(r'^'+neutral_str+'$', re.VERBOSE | re.IGNORECASE)
neg_re= re.compile(r'^'+neg_str+'$', re.VERBOSE | re.IGNORECASE)
pos_re= re.compile(r'^'+pos_str+'$', re.VERBOSE | re.IGNORECASE)



def proccessemo(text):
    
    if len(text)>2:
        emoticons=text[1:-1].replace("'","").split(", ")
        pos=[1 for emo in emoticons if pos_re.search(emo)]
        neg=[-1 for emo in emoticons if neg_re.search(emo)]
        neutral=[0 for emo in emoticons if neutral_re.search(emo)]
        count=len(pos)+len(neg)+len(neutral)
        total=np.float(np.sum(pos)+np.sum(neg)+np.sum(neutral))
        if count==0.0:
            return 0
        else:
            return total/count
    else:
        return None

# %%
subdftokens['s_emo_senti']=subdftokens['s_emo'].apply(lambda r: proccessemo(r))
# Out:
# /Users/Jing/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
subdf=subdftokens[['s_clean','s_emo','s_senti','s_emo_senti']].dropna()
subdf['diff']=subdf.s_senti-subdf.s_emo_senti
print "Total number of tweets that are compared:", subdf.shape[0]
print "Average difference between Emoji Sentiment and Text Sentiment", np.mean(subdf['diff'])
print "Standard error", np.std(subdf['diff'])
plt.hist(subdf['diff'])
# Out:
# Total number of tweets that are compared: 2114
# Average difference between Emoji Sentiment and Text Sentiment -0.217621750687
# Standard error 0.834468514555
# (array([ 109.,   25.,  524.,  131.,   25.,  953.,   29.,  243.,   18.,   57.]),
#  array([-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# We are able to extract emoticons from 2113 tweets.
#
# 1000 tweets' texts and emoticons express the sentiment.
#
# Another 1000 of tweets whose text and emoticons are telling different stories. After we take a closer look at these tweets, emoticons seen to provide more information about the sentiment of the tweets. Therefore, we decide to combined the sentiment score of texts and emotional score of emoticons. Since emoticons allow people to directly express their sentiment, we decide to place equal weight to sentiment of emoticons and sentiment of texts.

# %%
pd.set_option("display.max_colwidth",-1)

# %%
subdf[(subdf['diff']>=1) | (subdf['diff']<=-1)]
# Out:
#                                                                                                                                   s_clean  s_emo   s_senti  s_emo_senti      diff
# 0        lemme come over bro                                                                                                               [:(]   1.000000 -1            2.000000
# 144     When u go to buy your first lottery ticket and they don't even ID you                                                              [:(]   0.000000 -1            1.000000
# 201       you need to see this                                                                                                             [:)]   0.000000  1           -1.000000
# 228      tiling is a solution to zooming too. You get a content scale. Or: when you zoom in, the content gets bigger                       [;-)]  0.000000  1           -1.000000
# 232      Well, no but I did Rebecca                                                                                                        [:)]   0.000000  1           -1.000000
# 412      I'm not just a Paige fan. I'm a fan of everyone.                                                                                  [:P]   1.000000  0            1.000000
# 561     If someone could suction off all my face fat that would be nice                                                                    [:)]   0.000000  1           -1.000000
# 675       I need to be in a team, but I'm way below y'alls tiers, I bet.                                                                   [:(]   0.000000 -1            1.000000
# 803      how are u?                                                                                                                        [:)]   0.000000  1           -1.000000
# 861      please answer me                                                                                                                  [:)]   0.000000  1           -1.000000
# 986     Dislikelooks like every other car on the market                                                                                    [:(]   1.000000 -1            2.000000
# 1127     Come home                                                                                                                         [:(]   1.000000 -1            2.000000
# 1191    My movie date cancelled on me                                                                                                      [:(]   0.000000 -1            1.000000
# 1215    But now I can watch the Pats game                                                                                                  [:)]   0.000000  1           -1.000000
# 1359     6 figures and comfy job.                                                                                                          [;-P]  1.000000  0            1.000000
# 1377    I'm proud of being Japanese  The mask of the Yoroi was weird and funny though!#museums2015 #Boston #art #Japanese                  [:)]  -0.333333  1           -1.333333
# 1578     wow you really posted that  thx Ilu 2                                                                                             [:/]   1.000000  0            1.000000
# 1610    #mitalum soooowho is asking questions around here?                                                                                 [:)]  -1.000000  1           -2.000000
# 1796     You forgot 'Tonic'.                                                                                                               [:)]   0.000000  1           -1.000000
# 1828      I bet he appreciates that.                                                                                                       [:P]   1.000000  0            1.000000
# 1869     i go to school and you go soft on me??                                                                                            [:(]   1.000000 -1            2.000000
# 2119     I'm just going to put on a Miles Davis record and make some breakfast                                                             [:p]   1.000000  0            1.000000
# 2203    This #SupplyChain #job might be a great fit for you: Planning and S&amp Business Process Expert (Director) -  #Hiring              [;OP]  1.000000  0            1.000000
# 2343     thank you, I should be working, now I'm watching SB49 end of game highlights on YouTube                                           [:P]   1.000000  0            1.000000
# 2368    Aspect Software: R&amp;amp Internship Apprenticeship (#Chelmsford, MA)  #IT #applynow #Job #Jobs #Hiring                           [;D]   0.000000  1           -1.000000
# 2461    Lol and I get fucked over again ))                                                                                                 [:)]   0.000000  1           -1.000000
# 2521    To be honest                                                                                                                       [:/]   1.000000  0            1.000000
# 2534     I would tell you who I love, but I'm stuck on verification issues, so I can't benefit.                                            [:(]   0.000000 -1            1.000000
# 2557    Nationwide Tropical Island Dating Reality Show Singles CastingPaid)  Recruiting singles for a Mark…                                [:(]   0.000000 -1            1.000000
# 2623    My professor's mic turned off and no ONE TOLD HIM. We just let him keep going even tho no one could hear him                       [:/]   1.000000  0            1.000000
# ...                                                                                                               ...                       ...        ... ..                 ...
# 135124  Pro Tip: When drinking have someone take away your phone. That way yo avoid doing something stupid )))))                           [:)]  -1.000000  1           -2.000000
# 135177   I know that feel                                                                                                                  [:(]   0.000000 -1            1.000000
# 135184   I want the peri-peri chicken Dom from Looking makes;  actually, hold the chicken                                                  [:D]   0.000000  1           -1.000000
# 135337       who doesnt Chanda                                                                                                             [;)]   0.000000  1           -1.000000
# 135342  I'm not from Boston                                                                                                                [:)]   0.000000  1           -1.000000
# 135378  See our latest #Boston, MA #job and click to apply: Director R&amp - Chocolate Confectionery -  #GeneralScience                    [;D]   0.000000  1           -1.000000
# 135440   so, "fearfully" is definitely not the adverb I'D be using                                                                         [:)]   0.000000  1           -1.000000
# 135495   see every weekend                                                                                                                 [:)]   0.000000  1           -1.000000
# 135581    gotcha deniz! thx sis                                                                                                            [:)]   0.000000  1           -1.000000
# 135596    have some ibuprofen?                                                                                                             [:(]   0.000000 -1            1.000000
# 135910  Don't take it personally. I am sure someone will eventually tell you  (sorry, could not resist)                                    [:-)] -0.333333  1           -1.333333
# 136066  Wish I could pull off glasses cause I can feel my eyesight getting worse                                                           [:/]  -1.000000  0           -1.000000
# 136121  Are you on #Instagram??? Let's connect! #Follow   #photography #boston #newyork #istanbul #losangeles                              [:)]   0.000000  1           -1.000000
# 136263   you can't my spiciness.                                                                                                           [;D]   0.000000  1           -1.000000
# 136319  Found my cup  @ Faneuil Hall Marketplace                                                                                           [:)]   0.000000  1           -1.000000
# 136715  What's happening today? NY car has a fuel leak.                                                                                    [:p]  -1.000000  0           -1.000000
# 136772    it me ((                                                                                                                         [:(]   0.000000 -1            1.000000
# 136804  #lunch is the smokehouse on an egg bagel  @ Faneuil Hall Marketplace                                                               [:)]   0.000000  1           -1.000000
# 137020   What's easy to look forward to is collecting random shit.                                                                         [:D]  -0.333333  1           -1.333333
# 137098   We should picket about it outside of 's house.                                                                                    [:P]  -1.000000  0           -1.000000
# 137248   The things in find in my research while figuring out what to collect. Again, thanks a lot, .                                      [:P]   1.000000  0            1.000000
# 137311   Well, that's the issue still. Not really sure where to start with wrestling either.                                               [:P]  -1.000000  0           -1.000000
# 137406  Psst! Seducing Chaos is only $0.99 for Cyber Monday! Fun, smexy PNR. You know you want it \n                                       [;D]   0.000000  1           -1.000000
# 137530   he destroyed your star last night tho                                                                                             [:/]  -1.000000  0           -1.000000
# 137558   So, you're German. Should I get a Bayern Munich shirt at Christmas time or a Dortmund shirt?                                      [:P]   1.000000  0            1.000000
# 137604   That works. Any particular season I should look for through my vintage distributors?                                              [:P]   1.000000  0            1.000000
# 138085  I saw this video  and thought of u. You could maybe be the judge but sounds more like Russian to me.                               [:P]   1.000000  0            1.000000
# 138148  I will try to.                                                                                                                     [;-)]  0.000000  1           -1.000000
# 138178  I really hate tech week but I gotta say I love my job, not many people can say hey I get paid to do hair/makeup/wigs for theatre   [:)]   0.000000  1           -1.000000
# 138309   Time to price out bookshelves. And hope they are easy enough to put together.                                                     [:P]   1.000000  0            1.000000
#
# [974 rows x 5 columns]

# %%
def comb(r):
    if np.isnan(r.s_senti):
        if np.isnan(r.s_emo_senti):
            return None
        else:
            return r.s_emo_senti
    else:
        if np.isnan(r.s_emo_senti):
            return r.s_senti
        else:
            return 0.5*r.s_emo_senti+0.5*r.s_senti
        
subdftokens['s_comb']=subdftokens.apply(lambda r: comb(r),axis=1)
# Out:
# /Users/Jing/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.hist(subdftokens['s_comb'])
# Out:
# (array([ 19997.,     83.,   1365.,   3407.,    612.,  49023.,   5709.,
#           2443.,   1030.,  54727.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Since some tweets have quoted text, we also looked at the sentiment of quoted text, and combine the score if it has emoticons.

# %%
def quote_senti(r):
    senti=wordmatch(r.q_tokens,poslist2,neglist2)
    emo_senti=proccessemo(r.q_emo)
    if emo_senti==None:
        return senti
    else:
        return 0.5*emo_senti + 0.5*senti


mask=subdftokens['q_clean'].isnull()
quotedf=subdftokens[~mask]
quotedf['q_comb']=quotedf.apply(lambda r:quote_senti(r),axis=1)
# Out:
# /Users/Jing/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
quotedf['diff']=quotedf['s_comb']-quotedf['q_comb']
plt.hist(quotedf['diff'].values)
# Out:
# /Users/Jing/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# (array([  352.,   137.,  1652.,   328.,   277.,  3036.,   325.,  1643.,
#           160.,   381.]),
#  array([-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ]),
#  <a list of 10 Patch objects>)

# %%
quotedf[['s_clean','s_comb','q_clean','q_comb']][(quotedf['diff']<=-1) | (quotedf['diff']>=1) ]
# Out:
#                                                                                                                                       s_clean    s_comb                                                                                                                                 q_clean  q_comb
# 7       No, seasons change, people don't                                                                                                       1.000000  Love is rare, Life is strange, Nothing last, people change.                                                                             0
# 110     Used to be one of my favs                                                                                                              1.000000  Madeline (1993-2001)                                                                                                                    0
# 139     This is a must read.                                                                                                                   0.000000  Might want to keep this in mind when the next 12,300 polls come out.                                                                    1
# 147     CRYING FACE., Boston needs more of this ,                                                                                             -1.000000  #ChocolateWomenAppreciation                                                                                                             0
# 160     Low key baeeee. Like side bae or whatever                                                                                              1.000000   he tells a joke and stares blankly and no one gets it then he laughs lmaoooo so quirky and adorable                                    0
# 247     The NFL is a joke.                                                                                                                    -1.000000  NFL statement on Rams' QB Case Keenum: "Promptly after the conclusion of yesterday’s game, we began a review to                         1
# 269     What?!?                                                                                                                                0.000000  WR Aaron Dobson has been added to the injury report with a back injury. He is questionable for tonight’s game. #BUFvsNE                -1
# 308     Yeah i figured                                                                                                                         0.000000   in the one I read though it said that those words aren't directly from his mouth though but from a close friend                        1
# 375     Mitt would be ok I think. Honestly I do. But yah Palin was a DISASTER                                                                  0.000000  They gave us Bitch Romney in 2012 and Sarah Palin in 2008 as a VP. No.                                                                 -1
# 397     Can I help!!!!                                                                                                                         1.000000  What dating app will I find myself a tall dark handsome man ?                                                                           0
# 425     It's so fucking lit                                                                                                                   -1.000000  .'s going on tour in 2016 and she's taking ,  and :                                                                                     0
# 432     Price is going to Cubs and Greinke may stay in NL. Doubt Sox get either                                                               -1.000000  MOTHER OF GOD. THEY WANT BOTH?? SPEND ALL OF JOHN HENRY'S MONEY!! ALL OF IT, I SAY!!                                                    0
# 650     How the fuck do we have an ignorant piece of shit running for president #donalddump #bernie2016                                       -1.000000  Via  9/18/01. I want an apology! Many people have tweeted that I am right!                                                              1
# 793     WHAT!!!! I CRIED FOR THIS MAN AND NOW THEY ARE TELLING ME HES ALIVE!!                                                                 -1.000000  Jon Snow? Jon Snow!? Maybe Jon Snow!?  #GameOfThrones #GoT                                                                              0
# 821     That would b a grave mistake if they mis treat you                                                                                    -1.000000  . reports that  getting ready to treat me unfairly—big spending planned against me. That wasn’t the deal!                               0
# 823     The term 'mulatto' has a long historical trajectory outside of the U.S. as well                                                       -1.000000  TUNE IN: A look at the new film  in mixed-race America:  via                                                                            0
# 837     Miss this show                                                                                                                        -1.000000  When Laura got told to go back to Africa &amp; the N word written on her locker                                                         0
# 838     Welp                                                                                                                                   0.000000  slack's down, thanksgiving starts early                                                                                                -1
# 851     LOUDLY CRYING FACE.FIRE.This is beautiful ,,                                                                                          -0.333333  FIRE.Now this is basketball ,\n\n*get free iohawk hoverboard in bio*\n\n                                                                1
# 862     Lmfaoooo, whoops.                                                                                                                      0.000000  UNAMUSED FACE.I swear yall females LOVE doing this ,                                                                                    1
# 906     Looks like mi papa                                                                                                                     1.000000  Ferf                                                                                                                                    0
# 942     TWO HEARTS.Such a beautiful #muse ,                                                                                                    1.000000  Lauryn. Throwback.                                                                                                                      0
# 971     Holy mother of Christ it is mi papa                                                                                                    1.000000  They call meFERF                                                                                                                        0
# 1018    they get blocked                                                                                                                       0.000000  There is nothing more annoying than a slow texter.                                                                                     -1
# 1084    SMILING FACE WITH HALO.HEAVY BLACK HEART.Love the scene ,️ she's enjoying\nGod bless po,\nmore fun @ Kalye Serye\n#ALDUBPleaseDontGo   1.000000  #ALDUBPleaseDontGo     patay tayo dyan.                                                                                                 0
# 1172    Ken is on his way to suk her babes pussy                                                                                               0.000000  “Didn’t we pass Batman already?” Our store map finds what you’re looking for!                                                          -1
# 1175    Did you guy contact the raffle winners yet?                                                                                            1.000000  Nike Foamposite One 'Hologram' will be releasing on Wednesday 11/25. More info + pictures:                                              0
# 1203    CONFUSED FACE.I know ,                                                                                                                -1.000000  that's going to be harder than ever right now                                                                                           1
# 1247    Lol wtf                                                                                                                                1.000000  When he catches you poking holes in the condoms.                                                                                        0
# 1264    Annoying lol                                                                                                                           0.000000  Houston cops ain't got no chill                                                                                                        -1
# ...                ...                                                                                                                              ...                               ...                                                                                                       ..
# 136785  Talk about high-pressure                                                                                                               0.000000  . will personally interview the engineers he needs for self-driving  cars                                                               1
# 136786  FINALLY                                                                                                                                0.000000  HOT BEVERAGE.Espresso drinks now at the Tower Cafe! ,️,️                                                                                1
# 136794  I'M ALIVE                                                                                                                              0.000000  COLOURPOP IS HAVING A 20% OFF SALE!! so instead of 6$ liquid lippies, they are now $4.80!!!  happy shopping!                            1
# 136810  It's a good this she's a grown woman and can do whatever tf she wants                                                                  0.000000  DASH SYMBOL.7 months ago was Gigi and Cody\n3 months ago was Gigi and Joe\nAnd now was Zayn and Gigi\n\nBREEZY GIRL ,                   1
# 136903  I’d jump.                                                                                                                              0.000000  imagine being a worker on a cruise ship where every passenger believed this ad                                                          1
# 136932  Super Bowl is theirs                                                                                                                   1.000000  Panthers signed former Rams, Titans and Dolphins  Cortland Finnegan.                                                                    0
# 136972  What about #COY11? Hashtag for the most visionary climate leadership.                                                                  1.000000  . has created new emojis to mark the beginning of the UN Climate Conference in Paris. #COP21                                            0
# 137074  Headline of the day                                                                                                                    0.000000  Bill Belichick annihilates reporter with death stare                                                                                   -1
# 137129  EYES.Where ,                                                                                                                           0.000000  CONFOUNDED FACE.SEE-NO-EVIL MONKEY.WEARY FACE.Nudes on my TL ,,,,,,,                                                                   -1
# 137168  So awesome!!                                                                                                                           1.000000  Serena Williams, Patti Smith and Amy Schumer strip off for Pirelli                                                                      0
# 137239    BALL DON'T LIE.                                                                                                                     -1.000000  Sheed still got it                                                                                                                      0
# 137288  Excellent Smithers good luck to you!                                                                                                   1.000000  Made it!!!                                                                                                                              0
# 137365  It always is                                                                                                                           0.000000  Is the idea better than the real thing                                                                                                  1
# 137375  Damn right hoe                                                                                                                         0.000000  I'm an Aquarius which means I'm the water bearer  Which means I am the wave bitch                                                      -1
# 137388   I'm in love with this vine                                                                                                            1.000000  When you open a shit gift at Christmas but you don't want to be rude:\n                                                                 0
# 137408  DOPE                                                                                                                                  -1.000000  SPARKLING HEART.Paris Hilton on the cover of Paper Magazine. Looking absolutely sick! ,                                                 0
# 137440  LMFAOOO                                                                                                                                0.000000  FACE WITH TEARS OF JOY.OK HAND SIGN.EMOJI MODIFIER FITZPATRICK TYPE-4.When you were ,, close ,,,                                        1
# 137480  Mom "ha Mel that's you"\nChris "yeah but your hot husband is behind you taking a picture of your butt"                                 1.000000  "Where do you see yourself in 10 years?"                                                                                                0
# 137552  Here we go                                                                                                                             0.000000  Jason Van Dyke, the officer charged with the death of #LaQuanMcDonald, has pled Not Guilty:                                            -1
# 137606  Congrats team!      #gbl                                                                                                               0.000000  Best Apps for Kids Ages 5-8. #zoombinis makes the cut!  via                                                                             1
# 137665  To taking curry or Reggie out Gotta say Ray and it pains me to                                                                        -1.000000  Choose one for last second shot (3 pointer)                                                                                             0
# 137748  Accurate                                                                                                                               1.000000  Me at the beginning of this year vs now                                                                                                 0
# 137883  I don't                                                                                                                                0.000000  i love you all                                                                                                                          1
# 137900  Better off talking to yourself lol                                                                                                     1.000000   so they can talk trash and not take the heat obvi                                                                                     -1
# 138038  Might as well talk to yourself                                                                                                         0.000000  Heavy shit talkers                                                                                                                     -1
# 138162  She's so weird lmfaoo                                                                                                                 -1.000000  PERSEVERING FACE.Omg I asked sky what she was eating and she lifted up her shirt and there was a Bon Bon in her belly button LMAOOOO,,  0
# 138267  Breathe easy New England.                                                                                                              1.000000  Sounds like #Patriots TE Rob Gronkowski (knee) is unlikely to miss more than one game, I'm told. In fact, he may not even miss that.    0
# 138351  I've always wanted to be two degrees from #Bono working on critical issues. Looks like Christmas came early                            0.000000  Our Fisher Family Fellow,  becomes adviser to 's #Bono as they look to tackle global #poverty                                          -1
# 138380  Basically my sneeze if it were more high pitched                                                                                       0.000000  FLUSHED FACE.Bless you ,                                                                                                                1
# 138385   when we realized we have the bio project                                                                                              1.000000  Thinkin bout all the homework I still have to do                                                                                        0
#
# [4278 rows x 4 columns]

# %% [markdown]
# After take a look at the quoted texts, we decide not to consider them when analyze texts. Sometimes texts agree with quoted texts, but sometimes they do not. Adding quoted texts would make the analysis more complicated but not necessarily more accurate.

# %% [markdown]
# ### 2. Sentiment Analysis using `Pattern`
#
# The `sentiment` function from `pattern` package evaluate the sentiment of a sentence. Based on the adjectives a given sentence contains, the function returns a `(polarity,subjectivity)` tuple for the sentence. Here we are only interested in polarity, which is a value between -1.0 and +1.0: +1.0 being positive; -1.0 being negative.
#
# The problem of using this function is that twitter language is very messy, and we do not know how well the function handle messy texts.

# %%
from pattern.en import sentiment
print sentiment("Breathe easy New England")
# Out:
# (0.28484848484848485, 0.6439393939393939)

# %%
subdftokens['s_senti_2'] = subdftokens['s_clean'].apply(lambda r: sentiment(r)[0])
subdftokens[['s_clean','s_senti','s_senti_2','s_comb']].head()
# Out:
# /Users/Jing/anaconda/lib/python2.7/site-packages/pattern/text/__init__.py:1943: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if w in imap(lambda e: e.lower(), e):
# /Users/Jing/anaconda/lib/python2.7/site-packages/pattern/text/__init__.py:979: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   and tokens[j] in ("'", "\"", u"”", u"’", "...", ".", "!", "?", ")", EOS):
# /Users/Jing/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                                                                      s_clean  s_senti  s_senti_2  s_comb
# 0   lemme come over bro                                                                                       1        0.00       0
# 1  I've been in a bad mood since like 2010                                                                    0       -0.70       0
# 2  what's the appropriate age for me to start acting like an adult?                                           1        0.20       1
# 3     I assume your dad works at your school?)                                                                1        0.00       1
# 4   I'm watching River (BBC) on netflix, I think you'd like it. A bit creepy &amp; really really well acted.  0       -0.15       0

# %%
subdftokens[['s_clean','s_senti','s_senti_2','s_comb']]\
[abs(subdftokens['s_senti']-subdftokens['s_senti_2'])>1]
# Out:
#                                                                                                                                                                                    s_clean   s_senti  s_senti_2    s_comb
# 76      Senior Agile Product Owner - Ericsson: (#Waltham, Massachusetts)  #Job #Jobs #Hiring                                                                                                1.000000 -0.125000   1.000000
# 90      Customer Service Rep Phys - Lahey Health: (#Burlington, MA)  #Clerical #Job #Jobs #Hiring                                                                                           1.000000 -0.750000   1.000000
# 117     FACE WITH TEARS OF JOY.Yoo  so I went to the kitchen and I saw my 10 year old little sister watching your NBA video can you BELIVE that ,                                           1.000000 -0.043750   1.000000
# 121     Clinical Project Managers/Sr Clinical Project Managers, - Quintiles: (#Boston, Massachusetts)  #Pharmaceutical                                                                      1.000000 -0.750000   1.000000
# 136     Steven Gerrard to play for #Liverpool in January… in Legends game                                                                                                                   1.000000 -0.400000   1.000000
# 147     CRYING FACE., Boston needs more of this ,                                                                                                                                          -1.000000  0.150000  -1.000000
# 280     Just got yelled at by my boss for yelling vulgar things at bills fans in the hotel lobby #worthit                                                                                   0.333333 -0.700000   0.333333
# 282     HEAVY BLACK HEART.So thankful for  ,️                                                                                                                                               1.000000 -0.183333   1.000000
# 288     Manager Special Projects¸ Personal Insurance Benefits - Liberty Mutual Insurance: (#Boston, MA)  #BusinessMgmt #Job                                                                 1.000000 -0.130952   1.000000
# 305     Seriously? Seriously? Some people don't have enough to do or worry about. Absolute, mind-boggling stupidity.                                                                       -1.000000  0.091667  -1.000000
# 323     AMERICAN FOOTBALL.So many injured players in the NFL,                                                                                                                              -1.000000  0.250000  -1.000000
# 343     Our AARP Caregiving Resource Center has information and resources to help family caregivers:  #iheartcaregivers                                                                     1.000000 -0.100000   1.000000
# 378      i find this wicked funny                                                                                                                                                          -1.000000  0.250000  -1.000000
# 409     HAHAHAHAHA bruh you scared?                                                                                                                                                        -1.000000  0.200000  -1.000000
# 421     ew I suck I forgive people way too easily                                                                                                                                          -1.000000  0.433333  -1.000000
# 422     I miss Liz so much                                                                                                                                                                 -1.000000  0.200000  -1.000000
# 426     Ben Carson and Donald Trump are not real candidates. If you count yourself as a Republican you cannot allow them to represent your party                                            1.000000 -0.100000   1.000000
# 429      I close my eyes and see the teenagers , the little kids,  thank you for your courage and truth.                                                                                    1.000000 -0.187500   1.000000
# 437      a real loss for us all                                                                                                                                                            -1.000000  0.200000  -1.000000
# 557       when Female Black Twitter is finally defeated                                                                                                                                     1.000000 -0.055556   1.000000
# 564     FACE WITH NO GOOD GESTURE.HUNDRED POINTS SYMBOL.EMOJI MODIFIER FITZPATRICK TYPE-5.I'm From Boston #Mattapan No Other Place ,,,                                                      1.000000 -0.143750   1.000000
# 575     I fucks with your new album.                                                                                                                                                       -1.000000  0.136364  -1.000000
# 627     All these Trump people keep retweeting my Carson tweet. Hey I hate Trump's platform too so                                                                                          0.333333 -0.800000   0.333333
# 679        I'm not sure she does believe it. But she knows her followers will.                                                                                                              1.000000 -0.250000   1.000000
# 691     #BusinessMgmt alert: Internal Audit Manager (International) | Robert Half Finance &amp; Accounting | #Watertown, MA                                                                 1.000000 -0.055556   1.000000
# 692     Game Day got me like!!!  christopherivess #patriots #patsnation #Bostonian #redhot @ Faneuil…                                                                                       1.000000 -0.781250   1.000000
# 701     BLACK SUN WITH RAYS.Take me back,️ @ Scusset Beach State Reservation                                                                                                                1.000000 -0.166667   1.000000
# 718     The  messed up with #Keenum and his concussion. The league is now many yrs old now? There is no room for a learning curve here. SMH                                                -1.000000  0.300000  -1.000000
# 730     The  messed up with #Keenum and his concussion. The league is how many yrs old now? There is no room for a learning curve here. SMH                                                -1.000000  0.300000  -1.000000
# 732     Feeling higher than the dirt sitting on Zeus's shouldersss                                                                                                                         -1.000000  0.250000  -1.000000
# ...                                                            ...                                                                                                                               ...       ...        ...
# 137763  I don't mind the Chris Young signing as long as he's a 4th outfielder. I wouldn't mind trading JBJ or Castillo but Betts is untouchable.                                           -1.000000  0.025000  -1.000000
# 137779  Patient Services Representative - Aspen Dental: (#Saugus, MA)  #IT #Job #Jobs #Hiring #CareerArc                                                                                    1.000000 -0.750000   1.000000
# 137843  “Let us rise up and be thankful, for if we didn’t learn a lot today, at least we learned a little,…                                                                                 1.000000 -0.300000   1.000000
# 137875  And "Puzzle &amp; Dragons" is back as Japan's top mobile app revenue generator; puzzle app longevity is far beyond what anyone forecast in -14                                     -1.000000  0.200000  -1.000000
# 137891  Michael doesn't love these hoes.                                                                                                                                                    1.000000 -0.250000   1.000000
# 137897  I really need a blunt                                                                                                                                                              -1.000000  0.200000  -1.000000
# 137906   how often do you get restocks? I was hoping to get the sea foam green hoodie for a Christmas gift!                                                                                 1.000000 -0.250000   1.000000
# 137940  Great  in :Alan Gross’s Improbable Tales on 60 Minutes   #alangross #CubanFive                                                                                                     -0.333333  0.800000  -0.333333
# 137951   I haven't been following this year very closely but I bet  or  have the early contenders                                                                                          -1.000000  0.100000  -1.000000
# 137953  Where there's a hustle there's a way, don't hate                                                                                                                                   -1.000000  0.400000  -1.000000
# 137970       We already know that deer make good prey. It's the Aussies who're in question.                                                                                                -0.333333  0.700000  -0.333333
# 137999  Beijing air pollution reaches extremely hazardous levels                                                                                                                           -1.000000  0.600000  -1.000000
# 138008  Sort of wild that Alan Ladd's son had such a central role in Star Wars franchise.                                                                                                  -1.000000  0.033333  -1.000000
# 138019  HEAVY BLACK HEART.OK HAND SIGN.EMOJI MODIFIER FITZPATRICK TYPE-5.Thanks babe ,️,,                                                                                                   1.000000 -0.183333   1.000000
# 138030  FACE WITH TEARS OF JOY.HEAVY BLACK HEART.  I WAS GONNA SAY THAT NEXT ,,,️                                                                                                           1.000000 -0.083333   1.000000
# 138034   East Coast Comics And Toys on Facebook and  for #CyberMonday deals on Comics Action Figures and more!                                                                             -1.000000  0.362500  -1.000000
# 138052  The Cheesecake Factory: Server - Military (#Natick, MA)  #Hospitality #Veterans #Job #Jobs #Hiring #CareerArc                                                                       1.000000 -0.100000   1.000000
# 138071  k I'm done with ho disrespectful kids these days are to older adults it makes me wanna start slapping everyone                                                                     -1.000000  0.166667  -1.000000
# 138127   hmmm this is why my older brother is infinitely tougher than his little sister!                                                                                                    1.000000 -0.033854   1.000000
# 138174  FACE WITH COLD SWEAT. She probably laughed at me ,                                                                                                                                 -1.000000  0.050000  -1.000000
# 138181  In an age of movement, nothing is more critical than stillness. #quotestoliveby #quote #quotes…                                                                                    -1.000000  0.500000  -1.000000
# 138223   There are some exclusions on the discount, make sure to add the code at checkout to see which styles it applies on.                                                               -1.000000  0.500000  -1.000000
# 138232  CLAPPING HANDS SIGN.WRAPPED PRESENT.EMOJI MODIFIER FITZPATRICK TYPE-1-2.CHRISTMAS TREE.THUMBS UP SIGN.FATHER CHRISTMAS.Just a few #christmasmovies ,,,,,,,,,,,,,, @ Fields Corner   1.000000 -0.200000   1.000000
# 138295   It's okay to admit you forgot his name. It's overwhelming, I get it.                                                                                                              -1.000000  0.500000  -1.000000
# 138312   Well, it shouldn't ever be opened nor should it be one of your choices when selecting a beer. Keep it closed!\n#BeerSnob                                                           1.000000 -0.125000   1.000000
# 138329  When people tell you the elevator is going up: I can see the arrows, it's obviously going back down after                                                                           1.000000 -0.051852   1.000000
# 138332  SVP, Head of Customer Strategy and Innovation - John Hancock: (#Boston, MA)  #Marketing #insurance #Job #Jobs #Hiring                                                               1.000000 -0.750000   1.000000
# 138356  Black women. We rise by lifting others. Dipped in the richest chocolate,drizzled in the finest gold &amp; honey and kissed by a thousand suns                                       1.000000 -0.166667   1.000000
# 138362   just made an #advent scarf using the #Cozy #Lodge pins set!                                                                                                                        1.000000 -0.250000   1.000000
# 138381  Help Desk/ Desktop Analyst- Frisco, TX - Kelly Services: (#Tewksbury, MA)  #SkilledTrade #KellyJobs #KellyServices                                                                  1.000000 -0.750000   1.000000
#
# [6168 rows x 4 columns]

# %%
print "Total number of tweets:", subdftokens.shape[0]
mask=abs(subdftokens['s_senti']-subdftokens['s_senti_2'])>1
print "Number of tweets that have a sentiment differed by at least 1 measured by two methods:",subdftokens[mask].shape[0]
# Out:
# Total number of tweets: 138396
# Number of tweets that have a sentiment differed by at least 1 measured by two methods: 6168

# %% [markdown]
# We conduct a paired two-sample t-test to test whether the difference of two methods is zero.
#
# $H_0: \delta=0$
#
# $H_A: \delta\neq0$

# %%
from scipy import stats
diff=subdftokens['s_senti'].values-subdftokens['s_senti_2'].values
t,p=stats.ttest_1samp(diff,0)
print "The t-value is :", t
print "The calculate p-value is approximate to:" ,p
plt.hist(diff)
# Out:
# The t-value is : 98.8043279153
# The calculate p-value is approximate to: 0.0
# (array([    78.,    940.,  12286.,   9732.,  13603.,  50706.,  21782.,
#          27912.,   1059.,    298.]),
#  array([-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Since the calulated p-value is less than 0.05, we reject the null hypothesis, and conclude that the result of two methods is different.
#
# We also compare the `s_comb` and `s_senti_2`, and conclude that they are different.

# %%
from scipy import stats
diff2=subdftokens['s_comb'].values-subdftokens['s_senti_2'].values
t,p=stats.ttest_1samp(diff2,0)
print "The t-value is :", t
print "The calculate p-value is approximate to:" ,p
plt.hist(diff)
# Out:
# The t-value is : 99.9780338326
# The calculate p-value is approximate to: 0.0
# (array([    78.,    940.,  12286.,   9732.,  13603.,  50706.,  21782.,
#          27912.,   1059.,    298.]),
#  array([-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Unfortunately, we do not know the sentiment of a tweet and cannot draw a conclusion on which method is better. By just going through tweets that rated differently by two methods, we find that sometimes `wordmatch` function gives a more reasonable sentiment score, while sometimes `sentiment` function gives a more reasonble score. Therefore, we decide to take the average of two methods as our final sentiment score for all tweets.
